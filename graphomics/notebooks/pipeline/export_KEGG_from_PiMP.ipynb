# %% [markdown]
# # Export Pathway Info from the KEGG Database in PiMP

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from collections import OrderedDict

# %%
import xmltodict
import json
import os

from rpy2 import robjects
from rpy2.robjects import pandas2ri
from bioservices.kegg import KEGG

pandas2ri.activate()

# %% [markdown]
# ### Define some useful methods

# %%
def get_pw_cmpd_dict(path):
    robjects.r['load'](path + '/PiMP/data/pathways2Compounds.RData')
    a = robjects.r['pathways2Compounds']
    pw_cmpd_dict = OrderedDict(zip(a.names, map(list, list(a))))

    pathway_cmpd_dict = OrderedDict()
    for pathway, cmpd_list in pw_cmpd_dict.items():
        pw = pathway.replace("path:", "")
        pathway_cmpd_dict[pw] = cmpd_list

    return pathway_cmpd_dict

def get_pw_dict(path):
    robjects.r['load'](path + '/PiMP/data/pathways.RData')
    a = robjects.r['pathways']
    filtered_ids = _filter_pathway_name(a['id'].values)
    pw_dict = dict(zip(filtered_ids, a.name.values))
    return pw_dict

def _filter_pathway_name(p):
    return [x.replace('path:', '') for x in p]

def get_cmpid_pathway_dict(path):
    robjects.r['load'](path + '/PiMP/data/compounds2Pathways.RData')
    a = robjects.r['compounds2Pathways']
    compound_names = a.names
    compound_pathways = list(map(lambda x: _filter_pathway_name(x), list(a)))
    cmpd_pw_dict = OrderedDict(zip(compound_names, compound_pathways))
    return cmpd_pw_dict

def _produce_kegg_dict(path, param):
    kegg_location = path + '/PiMP/inst/dbs/kegg.xml'
    with open(kegg_location) as kegg_cmpd_file:
        cmpd_dict = xmltodict.parse(kegg_cmpd_file.read())

    kegg_dict = {}
    for compound in cmpd_dict['compounds']['compound']:
        kegg_dict[compound[param]] = compound['formula']
    return kegg_dict

def get_cmpd_name_formula_dict(path):
    return _produce_kegg_dict(path, 'name')

def get_cmpd_id_formula_dict(path):
    return _produce_kegg_dict(path, 'id')

def load_json(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)
    return data

def save_json(data, json_file):
    with open(json_file, 'w') as f:
        json.dump(data, f)

# %%
path = '/home/joewandy/git/pimp'

# %%
pw_dict = get_pw_dict(path)
pathway_cmpd_dict = dict(get_pw_cmpd_dict(path))
cmpd_formula_dict = get_cmpd_name_formula_dict(path)
cmpd_id_formula_dict = get_cmpd_id_formula_dict(path)
cmpd_id_pw_dict = dict(get_cmpid_pathway_dict(path))

# %%
pw_dict
# Out:
# {'map00010': 'Glycolysis / Gluconeogenesis',
#  'map00020': 'Citrate cycle (TCA cycle)',
#  'map00030': 'Pentose phosphate pathway',
#  'map00040': 'Pentose and glucuronate interconversions',
#  'map00051': 'Fructose and mannose metabolism',
#  'map00052': 'Galactose metabolism',
#  'map00053': 'Ascorbate and aldarate metabolism',
#  'map00061': 'Fatty acid biosynthesis',
#  'map00062': 'Fatty acid elongation',
#  'map00071': 'Fatty acid degradation',
#  'map00072': 'Synthesis and degradation of ketone bodies',
#  'map00073': 'Cutin, suberine and wax biosynthesis',
#  'map00100': 'Steroid biosynthesis',
#  'map00120': 'Primary bile acid biosynthesis',
#  'map00121': 'Secondary bile acid biosynthesis',
#  'map00130': 'Ubiquinone and other terpenoid-quinone biosynthesis',
#  'map00140': 'Steroid hormone biosynthesis',
#  'map00190': 'Oxidative phosphorylation',
#  'map00195': 'Photosynthesis',
#  'map00230': 'Purine metabolism',
#  'map00231': 'Puromycin biosynthesis',
#  'map00232': 'Caffeine metabolism',
#  'map00240': 'Pyrimidine metabolism',
#  'map00250': 'Alanine, aspartate and glutamate metabolism',
#  'map00253': 'Tetracycline biosynthesis',
#  'map00254': 'Aflatoxin biosynthesis',
#  'map00260': 'Glycine, serine and threonine metabolism',
#  'map00270': 'Cysteine and methionine metabolism',
#  'map00280': 'Valine, leucine and isoleucine degradation',
#  'map00281': 'Geraniol degradation',
#  'map00290': 'Valine, leucine and isoleucine biosynthesis',
#  'map00300': 'Lysine biosynthesis',
#  'map00310': 'Lysine degradation',
#  'map00311': 'Penicillin and cephalosporin biosynthesis',
#  'map00312': 'beta-Lactam resistance',
#  'map00330': 'Arginine and proline metabolism',
#  'map00331': 'Clavulanic acid biosynthesis',
#  'map00340': 'Histidine metabolism',
#  'map00350': 'Tyrosine metabolism',
#  'map00351': 'DDT degradation',
#  'map00360': 'Phenylalanine metabolism',
#  'map00361': 'Chlorocyclohexane and chlorobenzene degradation',
#  'map00362': 'Benzoate degradation',
#  'map00363': 'Bisphenol degradation',
#  'map00364': 'Fluorobenzoate degradation',
#  'map00365': 'Furfural degradation',
#  'map00380': 'Tryptophan metabolism',
#  'map00400': 'Phenylalanine, tyrosine and tryptophan biosynthesis',
#  'map00401': 'Novobiocin biosynthesis',
#  'map00402': 'Benzoxazinoid biosynthesis',
#  'map00410': 'beta-Alanine metabolism',
#  'map00430': 'Taurine and hypotaurine metabolism',
#  'map00440': 'Phosphonate and phosphinate metabolism',
#  'map00450': 'Selenocompound metabolism',
#  'map00460': 'Cyanoamino acid metabolism',
#  'map00471': 'D-Glutamine and D-glutamate metabolism',
#  'map00472': 'D-Arginine and D-ornithine metabolism',
#  'map00473': 'D-Alanine metabolism',
#  'map00480': 'Glutathione metabolism',
#  'map00500': 'Starch and sucrose metabolism',
#  'map00510': 'N-Glycan biosynthesis',
#  'map00512': 'Mucin type O-Glycan biosynthesis',
#  'map00513': 'Various types of N-glycan biosynthesis',
#  'map00520': 'Amino sugar and nucleotide sugar metabolism',
#  'map00521': 'Streptomycin biosynthesis',
#  'map00522': 'Biosynthesis of 12-, 14- and 16-membered macrolides',
#  'map00523': 'Polyketide sugar unit biosynthesis',
#  'map00524': 'Butirosin and neomycin biosynthesis',
#  'map00531': 'Glycosaminoglycan degradation',
#  'map00532': 'Glycosaminoglycan biosynthesis - chondroitin sulfate / dermatan sulfate',
#  'map00534': 'Glycosaminoglycan biosynthesis - heparan sulfate / heparin',
#  'map00540': 'Lipopolysaccharide biosynthesis',
#  'map00550': 'Peptidoglycan biosynthesis',
#  'map00561': 'Glycerolipid metabolism',
#  'map00562': 'Inositol phosphate metabolism',
#  'map00563': 'Glycosylphosphatidylinositol(GPI)-anchor biosynthesis',
#  'map00564': 'Glycerophospholipid metabolism',
#  'map00565': 'Ether lipid metabolism',
#  'map00590': 'Arachidonic acid metabolism',
#  'map00591': 'Linoleic acid metabolism',
#  'map00592': 'alpha-Linolenic acid metabolism',
#  'map00600': 'Sphingolipid metabolism',
#  'map00601': 'Glycosphingolipid biosynthesis - lacto and neolacto series',
#  'map00603': 'Glycosphingolipid biosynthesis - globo series',
#  'map00604': 'Glycosphingolipid biosynthesis - ganglio series',
#  'map00620': 'Pyruvate metabolism',
#  'map00621': 'Dioxin degradation',
#  'map00622': 'Xylene degradation',
#  'map00623': 'Toluene degradation',
#  'map00624': 'Polycyclic aromatic hydrocarbon degradation',
#  'map00625': 'Chloroalkane and chloroalkene degradation',
#  'map00626': 'Naphthalene degradation',
#  'map00627': 'Aminobenzoate degradation',
#  'map00630': 'Glyoxylate and dicarboxylate metabolism',
#  'map00633': 'Nitrotoluene degradation',
#  'map00640': 'Propanoate metabolism',
#  'map00642': 'Ethylbenzene degradation',
#  'map00643': 'Styrene degradation',
#  'map00650': 'Butanoate metabolism',
#  'map00660': 'C5-Branched dibasic acid metabolism',
#  'map00670': 'One carbon pool by folate',
#  'map00680': 'Methane metabolism',
#  'map00710': 'Carbon fixation in photosynthetic organisms',
#  'map00720': 'Carbon fixation pathways in prokaryotes',
#  'map00730': 'Thiamine metabolism',
#  'map00740': 'Riboflavin metabolism',
#  'map00750': 'Vitamin B6 metabolism',
#  'map00760': 'Nicotinate and nicotinamide metabolism',
#  'map00770': 'Pantothenate and CoA biosynthesis',
#  'map00780': 'Biotin metabolism',
#  'map00785': 'Lipoic acid metabolism',
#  'map00790': 'Folate biosynthesis',
#  'map00791': 'Atrazine degradation',
#  'map00830': 'Retinol metabolism',
#  'map00860': 'Porphyrin and chlorophyll metabolism',
#  'map00900': 'Terpenoid backbone biosynthesis',
#  'map00901': 'Indole alkaloid biosynthesis',
#  'map00902': 'Monoterpenoid biosynthesis',
#  'map00903': 'Limonene and pinene degradation',
#  'map00904': 'Diterpenoid biosynthesis',
#  'map00905': 'Brassinosteroid biosynthesis',
#  'map00906': 'Carotenoid biosynthesis',
#  'map00908': 'Zeatin biosynthesis',
#  'map00909': 'Sesquiterpenoid and triterpenoid biosynthesis',
#  'map00910': 'Nitrogen metabolism',
#  'map00920': 'Sulfur metabolism',
#  'map00930': 'Caprolactam degradation',
#  'map00940': 'Phenylpropanoid biosynthesis',
#  'map00941': 'Flavonoid biosynthesis',
#  'map00942': 'Anthocyanin biosynthesis',
#  'map00943': 'Isoflavonoid biosynthesis',
#  'map00944': 'Flavone and flavonol biosynthesis',
#  'map00945': 'Stilbenoid, diarylheptanoid and gingerol biosynthesis',
#  'map00950': 'Isoquinoline alkaloid biosynthesis',
#  'map00960': 'Tropane, piperidine and pyridine alkaloid biosynthesis',
#  'map00965': 'Betalain biosynthesis',
#  'map00966': 'Glucosinolate biosynthesis',
#  'map00970': 'Aminoacyl-tRNA biosynthesis',
#  'map00980': 'Metabolism of xenobiotics by cytochrome P450',
#  'map00981': 'Insect hormone biosynthesis',
#  'map00982': 'Drug metabolism - cytochrome P450',
#  'map00983': 'Drug metabolism - other enzymes',
#  'map00984': 'Steroid degradation',
#  'map01040': 'Biosynthesis of unsaturated fatty acids',
#  'map01051': 'Biosynthesis of ansamycins',
#  'map01052': 'Type I polyketide structures',
#  'map01053': 'Biosynthesis of siderophore group nonribosomal peptides',
#  'map01054': 'Nonribosomal peptide structures',
#  'map01055': 'Biosynthesis of vancomycin group antibiotics',
#  'map01056': 'Biosynthesis of type II polyketide backbone',
#  'map01057': 'Biosynthesis of type II polyketide products',
#  'map01058': 'Acridone alkaloid biosynthesis',
#  'map02010': 'ABC transporters',
#  'map02020': 'Two-component system',
#  'map02030': 'Bacterial chemotaxis',
#  'map02060': 'Phosphotransferase system (PTS)',
#  'map03013': 'RNA transport',
#  'map03018': 'RNA degradation',
#  'map03070': 'Bacterial secretion system',
#  'map03320': 'PPAR signaling pathway',
#  'map04010': 'MAPK signaling pathway',
#  'map04012': 'ErbB signaling pathway',
#  'map04014': 'Ras signaling pathway',
#  'map04015': 'Rap1 signaling pathway',
#  'map04020': 'Calcium signaling pathway',
#  'map04062': 'Chemokine signaling pathway',
#  'map04064': 'NF-kappa B signaling pathway',
#  'map04066': 'HIF-1 signaling pathway',
#  'map04068': 'FoxO signaling pathway',
#  'map04070': 'Phosphatidylinositol signaling system',
#  'map04075': 'Plant hormone signal transduction',
#  'map04080': 'Neuroactive ligand-receptor interaction',
#  'map04111': 'Cell cycle - yeast',
#  'map04112': 'Cell cycle - Caulobacter',
#  'map04113': 'Meiosis - yeast',
#  'map04114': 'Oocyte meiosis',
#  'map04122': 'Sulfur relay system',
#  'map04140': 'Regulation of autophagy',
#  'map04141': 'Protein processing in endoplasmic reticulum',
#  'map04142': 'Lysosome',
#  'map04144': 'Endocytosis',
#  'map04145': 'Phagosome',
#  'map04150': 'mTOR signaling pathway',
#  'map04151': 'PI3K-Akt signaling pathway',
#  'map04260': 'Cardiac muscle contraction',
#  'map04261': 'Adrenergic signaling in cardiomyocytes',
#  'map04270': 'Vascular smooth muscle contraction',
#  'map04310': 'Wnt signaling pathway',
#  'map04340': 'Hedgehog signaling pathway',
#  'map04360': 'Axon guidance',
#  'map04370': 'VEGF signaling pathway',
#  'map04380': 'Osteoclast differentiation',
#  'map04510': 'Focal adhesion',
#  'map04512': 'ECM-receptor interaction',
#  'map04530': 'Tight junction',
#  'map04540': 'Gap junction',
#  'map04610': 'Complement and coagulation cascades',
#  'map04614': 'Renin-angiotensin system',
#  'map04621': 'NOD-like receptor signaling pathway',
#  'map04623': 'Cytosolic DNA-sensing pathway',
#  'map04626': 'Plant-pathogen interaction',
#  'map04640': 'Hematopoietic cell lineage',
#  'map04650': 'Natural killer cell mediated cytotoxicity',
#  'map04660': 'T cell receptor signaling pathway',
#  'map04662': 'B cell receptor signaling pathway',
#  'map04664': 'Fc epsilon RI signaling pathway',
#  'map04666': 'Fc gamma R-mediated phagocytosis',
#  'map04670': 'Leukocyte transendothelial migration',
#  'map04672': 'Intestinal immune network for IgA production',
#  'map04710': 'Circadian rhythm',
#  'map04713': 'Circadian entrainment',
#  'map04720': 'Long-term potentiation',
#  'map04721': 'Synaptic vesicle cycle',
#  'map04722': 'Neurotrophin signaling pathway',
#  'map04723': 'Retrograde endocannabinoid signaling',
#  'map04724': 'Glutamatergic synapse',
#  'map04725': 'Cholinergic synapse',
#  'map04726': 'Serotonergic synapse',
#  'map04727': 'GABAergic synapse',
#  'map04728': 'Dopaminergic synapse',
#  'map04730': 'Long-term depression',
#  'map04740': 'Olfactory transduction',
#  'map04742': 'Taste transduction',
#  'map04744': 'Phototransduction',
#  'map04745': 'Phototransduction - fly',
#  'map04810': 'Regulation of actin cytoskeleton',
#  'map04910': 'Insulin signaling pathway',
#  'map04911': 'Insulin secretion',
#  'map04912': 'GnRH signaling pathway',
#  'map04913': 'Ovarian steroidogenesis',
#  'map04914': 'Progesterone-mediated oocyte maturation',
#  'map04915': 'Estrogen signaling pathway',
#  'map04916': 'Melanogenesis',
#  'map04917': 'Prolactin signaling pathway',
#  'map04918': 'Thyroid hormone synthesis',
#  'map04919': 'Thyroid hormone signaling pathway',
#  'map04920': 'Adipocytokine signaling pathway',
#  'map04930': 'Type II diabetes mellitus',
#  'map04932': 'Non-alcoholic fatty liver disease (NAFLD)',
#  'map04940': 'Type I diabetes mellitus',
#  'map04960': 'Aldosterone-regulated sodium reabsorption',
#  'map04961': 'Endocrine and other factor-regulated calcium reabsorption',
#  'map04962': 'Vasopressin-regulated water reabsorption',
#  'map04964': 'Proximal tubule bicarbonate reclamation',
#  'map04966': 'Collecting duct acid secretion',
#  'map04970': 'Salivary secretion',
#  'map04971': 'Gastric acid secretion',
#  'map04972': 'Pancreatic secretion',
#  'map04973': 'Carbohydrate digestion and absorption',
#  'map04974': 'Protein digestion and absorption',
#  'map04975': 'Fat digestion and absorption',
#  'map04976': 'Bile secretion',
#  'map04977': 'Vitamin digestion and absorption',
#  'map04978': 'Mineral absorption',
#  'map05010': "Alzheimer's disease",
#  'map05012': "Parkinson's disease",
#  'map05014': 'Amyotrophic lateral sclerosis (ALS)',
#  'map05016': "Huntington's disease",
#  'map05020': 'Prion diseases',
#  'map05030': 'Cocaine addiction',
#  'map05031': 'Amphetamine addiction',
#  'map05032': 'Morphine addiction',
#  'map05033': 'Nicotine addiction',
#  'map05034': 'Alcoholism',
#  'map05110': 'Vibrio cholerae infection',
#  'map05111': 'Vibrio cholerae pathogenic cycle',
#  'map05120': 'Epithelial cell signaling in Helicobacter pylori infection',
#  'map05130': 'Pathogenic Escherichia coli infection',
#  'map05131': 'Shigellosis',
#  'map05132': 'Salmonella infection',
#  'map05133': 'Pertussis',
#  'map05134': 'Legionellosis',
#  'map05140': 'Leishmaniasis',
#  'map05142': 'Chagas disease (American trypanosomiasis)',
#  'map05143': 'African trypanosomiasis',
#  'map05144': 'Malaria',
#  'map05145': 'Toxoplasmosis',
#  'map05146': 'Amoebiasis',
#  'map05150': 'Staphylococcus aureus infection',
#  'map05152': 'Tuberculosis',
#  'map05160': 'Hepatitis C',
#  'map05162': 'Measles',
#  'map05164': 'Influenza A',
#  'map05166': 'HTLV-I infection',
#  'map05169': 'Epstein-Barr virus infection',
#  'map05200': 'Pathways in cancer',
#  'map05204': 'Chemical carcinogenesis',
#  'map05205': 'Proteoglycans in cancer',
#  'map05211': 'Renal cell carcinoma',
#  'map05212': 'Pancreatic cancer',
#  'map05213': 'Endometrial cancer',
#  'map05214': 'Glioma',
#  'map05215': 'Prostate cancer',
#  'map05217': 'Basal cell carcinoma',
#  'map05218': 'Melanoma',
#  'map05220': 'Chronic myeloid leukemia',
#  'map05221': 'Acute myeloid leukemia',
#  'map05222': 'Small cell lung cancer',
#  'map05223': 'Non-small cell lung cancer',
#  'map05310': 'Asthma',
#  'map05320': 'Autoimmune thyroid disease',
#  'map05322': 'Systemic lupus erythematosus',
#  'map05323': 'Rheumatoid arthritis',
#  'map05330': 'Allograft rejection',
#  'map05332': 'Graft-versus-host disease',
#  'map05410': 'Hypertrophic cardiomyopathy (HCM)',
#  'map05412': 'Arrhythmogenic right ventricular cardiomyopathy (ARVC)',
#  'map05414': 'Dilated cardiomyopathy',
#  'map07011': 'Penicillins',
#  'map07012': 'Cephalosporins - parenteral agents',
#  'map07013': 'Cephalosporins - oral agents',
#  'map07014': 'Quinolones',
#  'map07015': 'Local analgesics',
#  'map07016': 'Sulfonamide derivatives - sulfa drugs',
#  'map07017': 'Sulfonamide derivatives - diuretics',
#  'map07018': 'Sulfonamide derivatives - hypoglycemic agents',
#  'map07019': 'Tetracyclines',
#  'map07020': 'Macrolides and ketolides',
#  'map07021': 'Aminoglycosides',
#  'map07023': 'Rifamycins',
#  'map07024': 'HMG-CoA reductase inhibitors',
#  'map07025': 'Quinolines',
#  'map07026': 'Antifungal agents',
#  'map07027': 'Antidepressants',
#  'map07028': 'Antipsychotics',
#  'map07029': 'Phenothiazines',
#  'map07030': 'Anxiolytics',
#  'map07031': 'Butyrophenones',
#  'map07032': 'Hypnotics',
#  'map07033': 'Anticonvulsants',
#  'map07034': 'Eicosanoids',
#  'map07035': 'Prostaglandins',
#  'map07036': 'Calcium channel blocking drugs',
#  'map07037': 'Antiarrhythmic drugs',
#  'map07038': 'Antiulcer drugs',
#  'map07039': 'Opioid analgesics',
#  'map07040': 'Antineoplastics - alkylating agents',
#  'map07041': 'Antineoplastics - antimetabolic agents',
#  'map07042': 'Antineoplastics - agents from natural products',
#  'map07043': 'Antineoplastics - hormones',
#  'map07044': 'Antiviral agents',
#  'map07045': 'Antineoplastics - protein kinases inhibitors',
#  'map07046': 'Immunosuppressive agents',
#  'map07047': 'Osteoporosis drugs',
#  'map07048': 'Antimigraines',
#  'map07049': 'Antithrombosis agents',
#  'map07050': 'Antirheumatics - DMARDs and biological agents',
#  'map07051': 'Antidiabetics',
#  'map07052': 'Antidyslipidemic agents',
#  'map07053': 'Anti-HIV agents',
#  'map07054': 'Antiglaucoma agents',
#  'map07055': 'Sulfonamide derivatives - overview',
#  'map07056': 'Agents for Alzheimer-type dementia',
#  'map07057': 'Antiparkinsonian agents',
#  'map07110': 'Benzoic acid family',
#  'map07112': '1,2-Diphenyl substitution family',
#  'map07114': 'Naphthalene family',
#  'map07117': 'Benzodiazepine family',
#  'map07211': 'Serotonin receptor agonists/antagonists',
#  'map07212': 'Histamine H1 receptor antagonists',
#  'map07213': 'Dopamine receptor agonists/antagonists',
#  'map07214': 'beta-Adrenergic receptor agonists/antagonists',
#  'map07215': 'alpha-Adrenergic receptor agonists/antagonists',
#  'map07216': 'Catecholamine transferase inhibitors',
#  'map07217': 'Renin-angiotensin system inhibitors',
#  'map07218': 'HIV protease inhibitors',
#  'map07219': 'Cyclooxygenase inhibitors',
#  'map07220': 'Cholinergic and anticholinergic drugs',
#  'map07221': 'Nicotinic cholinergic receptor antagonists',
#  'map07222': 'Peroxisome proliferator-activated receptor (PPAR) agonists',
#  'map07223': 'Retinoic acid receptor (RAR) and retinoid X receptor (RXR) agonists/antagonists',
#  'map07224': 'Opioid receptor agonists/antagonists',
#  'map07225': 'Glucocorticoid and meneralocorticoid receptor agonists/antagonists',
#  'map07226': 'Progesterone, androgen and estrogen receptor agonists/antagonists',
#  'map07227': 'Histamine H2/H3 receptor agonists/antagonists',
#  'map07228': 'Eicosanoid receptor agonists/antagonists',
#  'map07229': 'Angiotensin receptor and endothelin receptor antagonists',
#  'map07230': 'GABA-A receptor agonists/antagonists',
#  'map07231': 'Sodium channel blocking drugs',
#  'map07232': 'Potassium channel blocking and opening drugs',
#  'map07233': 'Ion transporter inhibitors',
#  'map07234': 'Neurotransmitter transporter inhibitors',
#  'map07235': 'N-Metyl-D-aspartic acid receptor antagonists',
#  'ingenza00001': 'Glycerol Utilisation',
#  'ingenza00002': '1,2-Propanediol',
#  'ingenza00003': 'KIV Synthesis',
#  'ingenza00004': 'BMA Synthesis',
#  'ingenza00005': 'Valine Degradation',
#  'ingenza00006': 'IG-Amino-acid Biosynthesis 1',
#  'ingenza00007': 'IG-Amino-acid Biosynthesis 2',
#  'ingenza00008': 'IBA biosynthesis',
#  'ingenza00009': 'Pantathenoate biosynthesis'}

# %%
pathway_cmpd_dict
# Out:
# {'map00010': ['Pyruvate',
#   'Acetyl-CoA',
#   'D-Glucose',
#   'Acetate',
#   'Oxaloacetate',
#   'Thiamin diphosphate',
#   'Phosphoenolpyruvate',
#   'Acetaldehyde',
#   'D-Glucose 1-phosphate',
#   'Glycerone phosphate',
#   'D-Glyceraldehyde 3-phosphate',
#   '(S)-Lactate',
#   '3-Phospho-D-glycerate',
#   'beta-D-Glucose',
#   '3-Phospho-D-glyceroyl phosphate',
#   'alpha-D-Glucose',
#   'Ethanol',
#   '2-Phospho-D-glycerate',
#   'alpha-D-Glucose 6-phosphate',
#   '2,3-Bisphospho-D-glycerate',
#   'beta-D-Glucose 6-phosphate',
#   'Salicin',
#   '2-(alpha-Hydroxyethyl)thiamine diphosphate',
#   'beta-D-Fructose 6-phosphate',
#   'beta-D-Fructose 1,6-bisphosphate',
#   'Arbutin',
#   'Arbutin 6-phosphate',
#   'Salicin 6-phosphate',
#   'Enzyme N6-(lipoyl)lysine',
#   'Enzyme N6-(dihydrolipoyl)lysine',
#   '[Dihydrolipoyllysine-residue acetyltransferase] S-acetyldihydrolipoyllysine'],
#  'map00020': ['Pyruvate',
#   'Acetyl-CoA',
#   '2-Oxoglutarate',
#   'Oxaloacetate',
#   'Succinate',
#   'Thiamin diphosphate',
#   'Phosphoenolpyruvate',
#   'Succinyl-CoA',
#   'Fumarate',
#   '(S)-Malate',
#   'Citrate',
#   'Isocitrate',
#   'cis-Aconitate',
#   '2-(alpha-Hydroxyethyl)thiamine diphosphate',
#   'Oxalosuccinate',
#   '3-Carboxy-1-hydroxypropyl-ThPP',
#   'Enzyme N6-(lipoyl)lysine',
#   'Enzyme N6-(dihydrolipoyl)lysine',
#   '[Dihydrolipoyllysine-residue succinyltransferase] S-succinyldihydrolipoyllysine',
#   '[Dihydrolipoyllysine-residue acetyltransferase] S-acetyldihydrolipoyllysine'],
#  'map00030': ['Pyruvate',
#   'D-Glucose',
#   'D-Ribose 5-phosphate',
#   'D-Glyceraldehyde 3-phosphate',
#   '5-Phospho-alpha-D-ribose 1-diphosphate',
#   'D-Ribose',
#   'D-Glucono-1,5-lactone',
#   'D-Ribulose 5-phosphate',
#   '2-Dehydro-3-deoxy-D-gluconate',
#   'beta-D-Glucose',
#   'D-Xylulose 5-phosphate',
#   'D-Gluconic acid',
#   'D-Glycerate',
#   'D-Erythrose 4-phosphate',
#   '6-Phospho-D-gluconate',
#   'D-Glyceraldehyde',
#   'alpha-D-Ribose 1-phosphate',
#   '2-Phospho-D-glycerate',
#   'alpha-D-Glucose 6-phosphate',
#   '2-Deoxy-D-ribose 1-phosphate',
#   '2-Deoxy-D-ribose 5-phosphate',
#   'D-Ribose 1,5-bisphosphate',
#   'beta-D-Glucose 6-phosphate',
#   '6-Phospho-2-dehydro-D-gluconate',
#   'D-Glucono-1,5-lactone 6-phosphate',
#   'Deoxyribose',
#   '2-Amino-2-deoxy-D-gluconate',
#   '2-Dehydro-3-deoxy-6-phospho-D-gluconate',
#   'beta-D-Fructose 6-phosphate',
#   'beta-D-Fructose 1,6-bisphosphate',
#   'Sedoheptulose 7-phosphate',
#   'D-arabino-Hex-3-ulose 6-phosphate',
#   '2-Keto-D-gluconic acid',
#   'D-Glucosaminate-6-phosphate'],
#  'map00040': ['Pyruvate',
#   '2-Oxoglutarate',
#   'UDP-glucose',
#   'D-Glucose 1-phosphate',
#   'Glycerone phosphate',
#   'UDP-glucuronate',
#   'D-Xylose',
#   'D-Glucuronate',
#   'D-Ribulose 5-phosphate',
#   '2-Dehydro-3-deoxy-D-gluconate',
#   'D-Xylulose 5-phosphate',
#   'L-Arabinose',
#   'Glycolaldehyde',
#   'D-Ribulose',
#   'D-Xylulose',
#   'L-Xylulose',
#   'D-Galacturonate',
#   'Xylitol',
#   '2,5-Dioxopentanoate',
#   'Pectate',
#   'Ribitol',
#   'D-Lyxose',
#   'D-Xylonate',
#   'L-Ribulose',
#   'D-Mannonate',
#   'L-Arabitol',
#   'D-Tagaturonate',
#   '3-Dehydro-L-gulonate',
#   'Pectin',
#   'CDP-ribitol',
#   'L-Gulonate',
#   'D-Altronate',
#   'D-Fructuronate',
#   'D-Ribitol 5-phosphate',
#   'L-Ribulose 5-phosphate',
#   'L-Lyxose',
#   'D-Arabitol',
#   'D-Xylonolactone',
#   'Digalacturonate',
#   'beta-D-Glucuronoside',
#   'L-Xylulose 5-phosphate',
#   '2-Dehydro-3-deoxy-D-xylonate',
#   '5-Dehydro-4-deoxy-D-glucuronate',
#   '(4S)-4,6-Dihydroxy-2,5-dioxohexanoate',
#   '(4R,5S)-4,5,6-Trihydroxy-2,3-dioxohexanoate',
#   'D-Glucuronate 1-phosphate',
#   'L-Xylonate',
#   'L-Lyxonate',
#   '4-(4-Deoxy-alpha-D-gluc-4-enuronosyl)-D-galacturonate',
#   'L-Xylulose 1-phosphate',
#   '3-Dehydro-L-gulonate 6-phosphate'],
#  'map00051': ['D-Fructose',
#   'GDP-mannose',
#   'Glycerone phosphate',
#   'D-Glyceraldehyde 3-phosphate',
#   'D-Mannose',
#   'L-Sorbose',
#   'alpha-D-Glucose',
#   'D-Mannose 6-phosphate',
#   'GDP-L-fucose',
#   'Mannitol',
#   '(S)-Lactaldehyde',
#   'Mannan',
#   'L-Rhamnose',
#   'D-Glyceraldehyde',
#   'D-Mannose 1-phosphate',
#   'D-Mannitol 1-phosphate',
#   'beta-D-Fructose 2,6-bisphosphate',
#   'D-Sorbitol',
#   'L-Rhamnulose',
#   '(R)-Lactaldehyde',
#   'GDP-D-mannuronate',
#   '6-Deoxy-L-galactose',
#   'D-Fructose 1-phosphate',
#   'Sorbitol 6-phosphate',
#   'L-Fuculose 1-phosphate',
#   'L-Rhamnulose 1-phosphate',
#   'GDP-4-dehydro-6-deoxy-D-mannose',
#   'Fructan',
#   'D-Allose',
#   'D-Fuconate',
#   'L-Fuculose',
#   '(Alginate)n',
#   'L-Rhamnonate',
#   'L-Rhamnofuranose',
#   '1,4-beta-D-Mannan',
#   'Sorbose 1-phosphate',
#   'D-Allose 6-phosphate',
#   'GDP-6-deoxy-D-talose',
#   'L-Fucose 1-phosphate',
#   'L-Rhamnono-1,4-lactone',
#   'GDP-6-deoxy-D-mannose',
#   'beta-D-Fructose 2-phosphate',
#   '2-Dehydro-3-deoxy-L-rhamnonate',
#   'beta-D-Fructose 6-phosphate',
#   'beta-D-Fructose 1,6-bisphosphate',
#   'Oligouronide with 4-deoxy-alpha-L-erythro-hex-4-enopyranuronosyl group',
#   '2-Dehydro-3-deoxy-D-fuconate',
#   'ADP-mannose',
#   '2-(alpha-D-Mannosyl)-3-phosphoglycerate',
#   '2(alpha-D-Mannosyl)-D-glycerate',
#   'D-Allulose 6-phosphate'],
#  'map00052': ['UDP-glucose',
#   'D-Glucose',
#   'UDP-alpha-D-galactose',
#   'Sucrose',
#   'D-Fructose',
#   'D-Glucose 1-phosphate',
#   'Glycerone phosphate',
#   'Glycerol',
#   'D-Glyceraldehyde 3-phosphate',
#   'D-Galactose',
#   'myo-Inositol',
#   'D-Mannose',
#   'Lactose',
#   'alpha-D-Glucose',
#   'alpha-D-Galactose 1-phosphate',
#   'Raffinose',
#   'alpha-D-Glucose 6-phosphate',
#   'D-Sorbitol',
#   'D-Tagatose',
#   'D-Galactonate',
#   'D-Tagatose 6-phosphate',
#   'D-Galactose 6-phosphate',
#   'N-Acetyl-D-galactosamine',
#   '2-Dehydro-3-deoxy-D-galactonate',
#   'alpha-D-Galactosyl-(1->3)-1D-myo-inositol',
#   '2-Dehydro-3-deoxy-6-phosphate-D-galactonate',
#   'Stachyose',
#   'Galactitol',
#   'D-Galactosamine',
#   'D-Galactono-1,4-lactone',
#   'D-Tagatose 1,6-bisphosphate',
#   'Lactose 6-phosphate',
#   'Melibiitol',
#   'Epimelibiose',
#   '3-beta-D-Galactosyl-sn-glycerol',
#   'Melibiose',
#   'D-Gal alpha 1->6D-Gal alpha 1->6D-Glucose',
#   'Galactan',
#   'Galactitol 1-phosphate',
#   'N-Acetyl-D-galactosamine 6-phosphate',
#   'D-Galactosamine 6-phosphate'],
#  'map00053': ['Pyruvate',
#   '2-Oxoglutarate',
#   'UDP-glucose',
#   'Ascorbate',
#   'GDP-mannose',
#   'myo-Inositol',
#   'UDP-glucuronate',
#   'D-Glucuronate',
#   'D-Xylulose 5-phosphate',
#   'L-Arabinose',
#   'D-Galacturonate',
#   '2,5-Dioxopentanoate',
#   'L-Arabinonate',
#   '3-Dehydro-L-gulonate',
#   '5-Dehydro-4-deoxy-D-glucarate',
#   '2-Dehydro-3-deoxy-L-arabinonate',
#   'L-Gulonate',
#   'D-Glucarate',
#   'D-Galactarate',
#   'L-Gulono-1,4-lactone',
#   'Monodehydroascorbate',
#   'L-Ribulose 5-phosphate',
#   'L-Arabinono-1,4-lactone',
#   'L-Galactono-1,4-lactone',
#   '2-Hydroxy-3-oxopropanoate',
#   'Threonate',
#   'L-Galactose',
#   'GDP-L-galactose',
#   'D-Glucuronolactone',
#   '3-Dehydro-L-threonate',
#   'L-xylo-Hexulonolactone',
#   'L-Xylulose 5-phosphate',
#   '2-Dehydro-3-deoxy-D-xylonate',
#   '2-Dehydro-3-deoxy-D-glucarate',
#   '(4R,5S)-4,5,6-Trihydroxy-2,3-dioxohexanoate',
#   'D-Glucuronate 1-phosphate',
#   '5-Hydroxy-2,4-dioxopentanoate',
#   'L-Xylonate',
#   'L-Lyxonate',
#   'Dehydroascorbate',
#   '3-Dehydro-L-gulonate 6-phosphate',
#   'L-Gulose',
#   'L-Gulose 1-phosphate',
#   'GDP-L-gulose',
#   'L-Galactose 1-phosphate',
#   'L-Galactonate',
#   'L-Ascorbate 6-phosphate'],
#  'map00061': ['Acetyl-CoA',
#   'Malonyl-CoA',
#   'Acyl-carrier protein',
#   'Hexadecanoic acid',
#   '(9Z)-Octadecenoic acid',
#   'Oleoyl-[acyl-carrier protein]',
#   'Malonyl-[acyl-carrier protein]',
#   'Octadecanoic acid',
#   'Decanoic acid',
#   'Dodecanoic acid',
#   'Acetyl-[acyl-carrier protein]',
#   'Octadecanoyl-[acyl-carrier protein]',
#   'But-2-enoyl-[acyl-carrier protein]',
#   'Carboxybiotin-carboxyl-carrier protein',
#   '(3R)-3-Hydroxybutanoyl-[acyl-carrier protein]',
#   '(3R)-3-Hydroxydecanoyl-[acyl-carrier protein]',
#   '(3R)-3-Hydroxyoctanoyl-[acyl-carrier protein]',
#   '(3R)-3-Hydroxypalmitoyl-[acyl-carrier protein]',
#   '(3R)-3-Hydroxytetradecanoyl-[acyl-carrier protein]',
#   'Dodecanoyl-[acyl-carrier protein]',
#   'Acetoacetyl-[acp]',
#   'Butyryl-[acp]',
#   '3-Oxohexanoyl-[acp]',
#   '(R)-3-Hydroxyhexanoyl-[acp]',
#   'trans-Hex-2-enoyl-[acp]',
#   'Hexanoyl-[acp]',
#   '3-Oxooctanoyl-[acp]',
#   'trans-Oct-2-enoyl-[acp]',
#   'Octanoyl-[acp]',
#   '3-Oxodecanoyl-[acp]',
#   'trans-Dec-2-enoyl-[acp]',
#   'Decanoyl-[acp]',
#   '3-Oxododecanoyl-[acp]',
#   '(R)-3-Hydroxydodecanoyl-[acp]',
#   'trans-Dodec-2-enoyl-[acp]',
#   '3-Oxotetradecanoyl-[acp]',
#   'trans-Tetradec-2-enoyl-[acp]',
#   'Tetradecanoyl-[acp]',
#   '3-Oxohexadecanoyl-[acp]',
#   'trans-Hexadec-2-enoyl-[acp]',
#   'Hexadecanoyl-[acp]',
#   'Holo-[carboxylase]',
#   'Octanoic acid',
#   'Tetradecanoic acid',
#   '(9Z)-Hexadecenoic acid',
#   '3-Oxostearoyl-[acp]',
#   '3-Hydroxyoctadecanoyl-[acp]',
#   '(2E)-Octadecenoyl-[acp]',
#   'Hexadecenoyl-[acyl-carrier protein]'],
#  'map00062': ['Acetyl-CoA',
#   'Acyl-CoA',
#   'Malonyl-CoA',
#   'Butanoyl-CoA',
#   'Palmitoyl-CoA',
#   'Fatty acid',
#   'Hexadecanoic acid',
#   '3-Oxoacyl-CoA',
#   '2,3-Dehydroacyl-CoA',
#   'Long-chain fatty acid',
#   '(3S)-3-Hydroxyacyl-CoA',
#   'trans-2,3-Dehydroacyl-CoA',
#   'Lauroyl-CoA',
#   'Octanoyl-CoA',
#   'Tetradecanoyl-CoA',
#   'Long-chain acyl-CoA',
#   '2-trans-Dodecenoyl-CoA',
#   '(S)-3-Hydroxyhexadecanoyl-CoA',
#   '3-Oxopalmitoyl-CoA',
#   '(S)-3-Hydroxytetradecanoyl-CoA',
#   '3-Oxotetradecanoyl-CoA',
#   '(S)-3-Hydroxydodecanoyl-CoA',
#   '3-Oxododecanoyl-CoA',
#   '(S)-Hydroxydecanoyl-CoA',
#   '3-Oxodecanoyl-CoA',
#   '(S)-3-Hydroxyoctanoyl-CoA',
#   '3-Oxooctanoyl-CoA',
#   '(S)-Hydroxyhexanoyl-CoA',
#   '3-Oxohexanoyl-CoA',
#   'Hexanoyl-CoA',
#   'trans-Hex-2-enoyl-CoA',
#   'trans-Hexadec-2-enoyl-CoA',
#   'trans-Tetradec-2-enoyl-CoA',
#   'Decanoyl-CoA',
#   'trans-Dec-2-enoyl-CoA',
#   'trans-Oct-2-enoyl-CoA'],
#  'map00071': ['CoA',
#   'Acetyl-CoA',
#   'Aldehyde',
#   'Butanoyl-CoA',
#   'Palmitoyl-CoA',
#   'Fatty acid',
#   'Primary alcohol',
#   'Acyl-carrier protein',
#   'Hexadecanoic acid',
#   'Acetoacetyl-CoA',
#   'Reduced rubredoxin',
#   'Oxidized rubredoxin',
#   'Glutarate',
#   'Hexadecanal',
#   'Glutaryl-CoA',
#   'Long-chain fatty acid',
#   '1-Hexadecanol',
#   'Crotonoyl-CoA',
#   '(S)-3-Hydroxybutanoyl-CoA',
#   'Alkane',
#   'Lauroyl-CoA',
#   'Octanoyl-CoA',
#   'Tetradecanoyl-CoA',
#   'L-Palmitoylcarnitine',
#   '2-trans-Dodecenoyl-CoA',
#   'omega-Hydroxy fatty acid',
#   '(R)-3-Hydroxybutanoyl-CoA',
#   'alpha-Hydroxy fatty acid',
#   '(S)-3-Hydroxyhexadecanoyl-CoA',
#   '3-Oxopalmitoyl-CoA',
#   '(S)-3-Hydroxytetradecanoyl-CoA',
#   '3-Oxotetradecanoyl-CoA',
#   '(S)-3-Hydroxydodecanoyl-CoA',
#   '3-Oxododecanoyl-CoA',
#   '(S)-Hydroxydecanoyl-CoA',
#   '3-Oxodecanoyl-CoA',
#   '(S)-3-Hydroxyoctanoyl-CoA',
#   '3-Oxooctanoyl-CoA',
#   '(S)-Hydroxyhexanoyl-CoA',
#   '3-Oxohexanoyl-CoA',
#   'Hexanoyl-CoA',
#   'trans-Hex-2-enoyl-CoA',
#   'trans-Hexadec-2-enoyl-CoA',
#   'trans-Tetradec-2-enoyl-CoA',
#   'Decanoyl-CoA',
#   'trans-Dec-2-enoyl-CoA',
#   'trans-Oct-2-enoyl-CoA',
#   'trans,cis-Lauro-2,6-dienoyl-CoA',
#   'cis,cis-3,6-Dodecadienoyl-CoA',
#   'Long-chain acyl-[acyl-carrier protein]'],
#  'map00072': ['Acetyl-CoA',
#   'Acetoacetate',
#   'Acetone',
#   'Acetoacetyl-CoA',
#   '(S)-3-Hydroxy-3-methylglutaryl-CoA',
#   '(R)-3-Hydroxybutanoate'],
#  'map00073': ['Primary alcohol',
#   'Hexadecanoic acid',
#   'Feruloyl-CoA',
#   'Long-chain aldehyde',
#   '(9Z)-Octadecenoic acid',
#   'Alkane',
#   'Ketone',
#   'Secondary alcohol',
#   'Wax ester',
#   'Long-chain acyl-CoA',
#   'Docosanoic acid',
#   '10,16-Dihydroxyhexadecanoic acid',
#   '16-Feruloyloxypalmitate',
#   '16-Hydroxypalmitate',
#   'cis-9,10-Epoxystearic acid',
#   '16-Oxo-palmitate',
#   'Hexadecanedioate',
#   '18-Hydroxyoleate',
#   '18-Oxooleate',
#   'Octadec-9-ene-1,18-dioic-acid',
#   '9,10-Epoxy-18-hydroxystearate',
#   '9,10,18-Trihydroxystearate',
#   '9,10-Dihydroxystearate',
#   '22-Hydroxydocosanoate',
#   '22-Oxo-docosanoate',
#   'Docosanedioate',
#   'Diketone'],
#  'map00100': ['Cholesterol',
#   'trans,trans-Farnesyl diphosphate',
#   'Squalene',
#   '(S)-2,3-Epoxysqualene',
#   '7-Dehydrocholesterol',
#   'Lathosterol',
#   'Calcidiol',
#   'Calcitriol',
#   'Ergosterol',
#   'Lanosterol',
#   'beta-Sitosterol',
#   'Campesterol',
#   'Desmosterol',
#   'Cycloartenol',
#   'Obtusifoliol',
#   'Cycloeucalenol',
#   'Cholesterol ester',
#   'Presqualene diphosphate',
#   '5alpha-Cholest-8-en-3beta-ol',
#   'Fecosterol',
#   '4alpha-Methylzymosterol',
#   '7-Dehydrodesmosterol',
#   '14-Demethyllanosterol',
#   '24,25-Dihydrolanosterol',
#   'Zymosterol',
#   '5alpha-Cholesta-7,24-dien-3beta-ol',
#   'Ergosta-5,7,22,24(28)-tetraen-3beta-ol',
#   'Vitamin D2',
#   'Stigmasterol',
#   'Vitamin D3',
#   'Secalciferol',
#   'Isofucosterol',
#   '24-Methylenecycloartanol',
#   '4,4-Dimethyl-5alpha-cholesta-8,14,24-trien-3beta-ol',
#   '4alpha-Methyl-5alpha-ergosta-8,14,24(28)-trien-3beta-ol',
#   '24-Methylenelophenol',
#   '24-Ethylidenelophenol',
#   '4alpha-Methylfecosterol',
#   'Episterol',
#   '5,7,24(28)-Ergostatrienol',
#   '5-Dehydroepisterol',
#   '24-Methylenecholesterol',
#   'delta7-Avenasterol',
#   '5-Dehydroavenasterol',
#   '4alpha-Methylzymosterol-4-carboxylate',
#   '3-Keto-4-methylzymosterol',
#   '4,4-Dimethyl-5alpha-cholesta-8-en-3beta-ol',
#   'Calcitetrol'],
#  'map00120': ['Glycine',
#   'Cholesterol',
#   'Taurine',
#   'Cholic acid',
#   '3alpha,7alpha,12alpha-Trihydroxy-5beta-cholestan-26-al',
#   'Choloyl-CoA',
#   'Glycocholate',
#   'Chenodeoxycholate',
#   '7alpha-Hydroxycholesterol',
#   '3alpha,7alpha-Dihydroxy-5beta-cholestanate',
#   '3alpha,7alpha,12alpha-Trihydroxy-5beta-cholestanoate',
#   'Taurocholate',
#   'Chenodeoxycholoyl-CoA',
#   '3alpha,7alpha,26-Trihydroxy-5beta-cholestane',
#   '3alpha,7alpha-Dihydroxy-5beta-cholestan-26-al',
#   '3alpha,7alpha,12alpha,26-Tetrahydroxy-5beta-cholestane',
#   '3alpha,7alpha-Dihydroxy-5beta-cholest-24-enoyl-CoA',
#   '3alpha,7alpha,24-Trihydroxy-5beta-cholestanoyl-CoA',
#   '3alpha,7alpha-Dihydroxy-5beta-24-oxocholestanoyl-CoA',
#   '3alpha,7alpha,12alpha,24-Tetrahydroxy-5beta-cholestanoyl-CoA',
#   '7alpha-Hydroxy-5beta-cholestan-3-one',
#   '3alpha,7alpha-Dihydroxy-5beta-cholestane',
#   '7alpha,12alpha-Dihydroxy-5beta-cholestan-3-one',
#   '3alpha,7alpha,12alpha-Trihydroxy-5beta-cholestane',
#   '7alpha-Hydroxycholest-4-en-3-one',
#   '3alpha,7alpha,12alpha-Trihydroxy-5beta-cholest-24-enoyl-CoA',
#   'Taurochenodeoxycholate',
#   'Glycochenodeoxycholate',
#   '3alpha,7alpha,12alpha-Trihydroxy-5beta-24-oxocholestanoyl-CoA',
#   '5beta-Cyprinolsulfate',
#   '7alpha,27-Dihydroxycholesterol',
#   'Cerebrosterol',
#   '(24S)-Cholest-5-ene-3beta,7alpha,24-triol',
#   '25-Hydroxycholesterol',
#   'Cholest-5-ene-3beta,7alpha,25-triol',
#   'Cholest-5-ene-3beta,26-diol',
#   '(25R)-3alpha,7alpha,12alpha-Trihydroxy-5beta-cholestan-26-oyl-CoA',
#   '7alpha,24-Dihydroxy-4-cholesten-3-one',
#   '7alpha,25-Dihydroxy-4-cholesten-3-one',
#   '3beta-Hydroxy-5-cholestenoate',
#   '3beta,7alpha-Dihydroxy-5-cholestenoate',
#   '7alpha,26-Dihydroxy-4-cholesten-3-one',
#   '7alpha-Hydroxy-3-oxo-4-cholestenoate',
#   '4-Cholesten-7alpha,12alpha-diol-3-one',
#   '(25S)-3alpha,7alpha,12alpha-Trihydroxy-5beta-cholestan-26-oyl-CoA',
#   '(25R)-3alpha,7alpha-Dihydroxy-5beta-cholestanoyl-CoA',
#   '(25S)-3alpha,7alpha-Dihydroxy-5beta-cholestanoyl-CoA'],
#  'map00121': ['Cholic acid',
#   'Glycocholate',
#   'Chenodeoxycholate',
#   'Lithocholic acid',
#   'Deoxycholic acid',
#   'Taurocholate',
#   'Chenodeoxycholoyl-CoA',
#   'Taurochenodeoxycholate',
#   'Glycochenodeoxycholate',
#   'Ursodiol',
#   'Murideoxycholic acid',
#   'Hyodeoxycholate',
#   'Ursocholate',
#   '12-Epideoxycholic acid',
#   'alpha-Muricholate',
#   'Hyocholate',
#   'Vulpecholate',
#   'alpha-Phocaecholic acid',
#   'beta-Phocaecholate',
#   'Bitocholate',
#   'Isolithocholate',
#   'Isochenodeoxycholate',
#   'Isodeoxycholate',
#   'Isoursodeoxycholate',
#   'Allochenodeoxycholate',
#   'Avicholate',
#   'Haemulcholate',
#   'Allodeoxycholate',
#   'Ursodeoxycholoyl-CoA',
#   'beta-Muricholate',
#   'omega-Muricholate',
#   'Allocholic acid'],
#  'map00130': ['L-Tyrosine',
#   '4-Hydroxybenzoate',
#   'p-Coumaroyl-CoA',
#   'Chorismate',
#   'Geranyl diphosphate',
#   'Ubiquinone',
#   'Homogentisate',
#   '4-Coumarate',
#   'Menaquinone',
#   'Isochorismate',
#   '3-(4-Hydroxyphenyl)pyruvate',
#   'all-trans-Hexaprenyl diphosphate',
#   'Ubiquinone-9',
#   'Phylloquinone',
#   'alpha-Tocopherol',
#   'gamma-Tocopherol',
#   '2-Succinylbenzoate',
#   '4-Hydroxybenzoyl-CoA',
#   '2-Succinylbenzoyl-CoA',
#   'Phylloquinol',
#   '1,4-Dihydroxy-2-naphthoate',
#   '3-(4-Hydroxyphenyl)lactate',
#   '3-Nonaprenyl-4-hydroxybenzoate',
#   '4-(beta-D-Glucosyloxy)benzoate',
#   'all-trans-Nonaprenyl diphosphate',
#   'all-trans-Octaprenyl diphosphate',
#   '3-Hexaprenyl-4,5-dihydroxybenzoate',
#   '3-Hexaprenyl-4-hydroxy-5-methoxybenzoate',
#   'Phytyl diphosphate',
#   '2-Hexaprenyl-6-methoxyphenol',
#   '2-Hexaprenyl-6-methoxy-1,4-benzoquinone',
#   '2-Hexaprenyl-3-methyl-6-methoxy-1,4-benzoquinone',
#   '2-Hexaprenyl-3-methyl-5-hydroxy-6-methoxy-1,4-benzoquinone',
#   '2-Polyprenylphenol',
#   '3-Octaprenyl-4-hydroxybenzoate',
#   '2-Octaprenylphenol',
#   '2-Octaprenyl-6-hydroxyphenol',
#   '2-Octaprenyl-6-methoxyphenol',
#   '2-Octaprenyl-6-methoxy-1,4-benzoquinone',
#   '2-Octaprenyl-3-methyl-6-methoxy-1,4-benzoquinone',
#   '2-Octaprenyl-3-methyl-5-hydroxy-6-methoxy-1,4-benzoquinone',
#   '(1R,6R)-6-Hydroxy-2-succinylcyclohexa-2,4-diene-1-carboxylate',
#   '2-Demethylmenaquinone',
#   'Menaquinol',
#   'all-trans-Polyprenyl diphosphate',
#   '4-Hydroxy-3-polyprenylbenzoate',
#   'Vitamin K1 epoxide',
#   'Spirodilactone',
#   'Plastoquinone-9',
#   'Geranylhydroquinone',
#   '2-Phytyl-1,4-naphthoquinone',
#   '3-Hexaprenyl-4-hydroxybenzoate',
#   'delta-Tocopherol',
#   'beta-Tocopherol',
#   '1,4-Dihydroxy-2-naphthoyl-CoA',
#   '2-Methyl-6-phytylquinol',
#   '2,3-Dimethyl-5-phytylquinol',
#   '2-Succinyl-5-enolpyruvyl-6-hydroxy-3-cyclohexene-1-carboxylate',
#   'Futalosine',
#   'de-Hypoxanthine futalosine',
#   'Cyclic de-hypoxanthine futalosine',
#   '1,4-Dihydroxy-6-naphthoate',
#   'Shikonin',
#   'all-trans-Decaprenyl diphosphate',
#   '2-Polyprenyl-6-hydroxyphenol',
#   '2-Polyprenyl-6-methoxyphenol',
#   '3-Polyprenyl-4,5-dihydroxybenzoate',
#   '3-Polyprenyl-4-hydroxy-5-methoxybenzoate',
#   '2-Polyprenyl-6-methoxy-1,4-benzoquinone',
#   '2-Polyprenyl-3-methyl-6-methoxy-1,4-benzoquinone',
#   '2-Polyprenyl-3-methyl-5-hydroxy-6-methoxy-1,4-benzoquinone',
#   'Ubiquinone-6',
#   'Ubiquinone-8',
#   '2-Methyl-6-solanyl-1,4-benzoquinol',
#   'Geranyl-hydroxybenzoate',
#   "3''-Hydroxy-geranylhydroquinone",
#   'Deoxyshikonin',
#   'Dihydroechinofuran',
#   'Dihydroshikonofuran',
#   '2,3-Epoxymenaquinone'],
#  'map00140': ['Cholesterol',
#   'Androstenedione',
#   'Progesterone',
#   'Estrone',
#   'Androsterone',
#   'Testosterone',
#   '5alpha-Androstane-3,17-dione',
#   'Cortisol',
#   'Cortisone',
#   'Estradiol-17beta',
#   '18-Hydroxycorticosterone',
#   '17alpha-Hydroxyprogesterone',
#   'Dehydroepiandrosterone',
#   'Aldosterone',
#   'Pregnenolone',
#   'Corticosterone',
#   '4-Methylpentanal',
#   'Estradiol-17alpha',
#   'Estrone 3-sulfate',
#   '11-Deoxycorticosterone',
#   '5alpha-Pregnane-3,20-dione',
#   '11alpha-Hydroxyprogesterone',
#   '5beta-Androstane-3,17-dione',
#   'Androstan-3alpha,17beta-diol',
#   'Dihydrotestosterone',
#   '6beta-Hydroxy-17beta-estradiol',
#   '20alpha-Hydroxy-4-pregnen-3-one',
#   'Androstenediol',
#   'Etiocholanolone',
#   '17alpha,20alpha-Dihydroxypregn-4-en-3-one',
#   'Dehydroepiandrosterone sulfate',
#   'Testololactone',
#   '17alpha-Hydroxypregnenolone',
#   '16alpha-Hydroxydehydroepiandrosterone',
#   '16alpha-Hydroxyandrost-4-ene-3,17-dione',
#   'Estriol',
#   '11beta-Hydroxyandrost-4-ene-3,17-dione',
#   'Adrenosterone',
#   '19-Hydroxyandrost-4-ene-3,17-dione',
#   '7alpha-Hydroxytestosterone',
#   '5beta-Dihydrotestosterone',
#   '19-Hydroxytestosterone',
#   '19-Oxotestosterone',
#   '7alpha-Hydroxyandrost-4-ene-3,17-dione',
#   '19-Oxoandrost-4-ene-3,17-dione',
#   '2-Hydroxyestrone',
#   '2-Methoxyestrone',
#   '16alpha-Hydroxyestrone',
#   '2-Hydroxyestradiol',
#   '2-Methoxy-17beta-estradiol',
#   '17alpha,21-Dihydroxy-5beta-pregnane-3,11,20-trione',
#   'Tetrahydrocortisone',
#   '11beta,17alpha,21-Trihydroxy-5beta-pregnane-3,20-dione',
#   'Urocortisol',
#   '11beta,21-Dihydroxy-3,20-oxo-5beta-pregnan-18-al',
#   '3alpha,11beta,21-Trihydroxy-20-oxo-5beta-pregnan-18-al',
#   '11beta,21-Dihydroxy-5beta-pregnane-3,20-dione',
#   'Tetrahydrocorticosterone',
#   '21-Hydroxy-5beta-pregnane-3,11,20-trione',
#   '3alpha,21-Dihydroxy-5beta-pregnane-11,20-dione',
#   '5beta-Pregnane-3,20-dione',
#   '3alpha-Hydroxy-5beta-pregnane-20-one',
#   'Cortolone',
#   'Cortol',
#   '3alpha,20alpha,21-Trihydroxy-5beta-pregnane-11-one',
#   'Pregnanediol',
#   '21-Hydroxypregnenolone',
#   '17alpha,21-Dihydroxypregnenolone',
#   '11-Deoxycortisol',
#   '11beta,17alpha,21-Trihydroxypregnenolone',
#   '11-Dehydrocorticosterone',
#   '21-Deoxycortisol',
#   '11beta-Hydroxyprogesterone',
#   '17alpha,20alpha-Dihydroxycholesterol',
#   '20alpha-Hydroxycholesterol',
#   '20alpha,22beta-Dihydroxycholesterol',
#   '22(R)-Hydroxycholesterol',
#   'Estradiol-17beta 3-glucuronide',
#   '16-Glucuronide-estriol',
#   'Estradiol-17beta 3-sulfate',
#   '2-Methoxyestrone 3-sulfate',
#   '2-Methoxyestradiol-17beta 3-sulfate',
#   '2-Methoxy-estradiol-17beta 3-glucuronide',
#   '2-Methoxyestrone 3-glucuronide',
#   'Estrone glucuronide',
#   'Testosterone glucuronide',
#   'Androsterone glucuronide',
#   'Etiocholan-3alpha-ol-17-one 3-glucuronide',
#   '3alpha-Hydroxy-5alpha-pregnan-20-one',
#   'Allotetrahydrodeoxycorticosterone',
#   '7alpha-Hydroxypregnenolone',
#   'Aldosterone hemiacetal',
#   '5alpha-Dihydrodeoxycorticosterone',
#   '5alpha-Pregnan-20alpha-ol-3-one',
#   '5alpha-Pregnane-3alpha,20alpha-diol',
#   'Cholesterol sulfate',
#   '3beta-Hydroxypregn-5-en-20-one sulfate',
#   '7alpha-Hydroxydehydroepiandrosterone',
#   '11beta,17beta-Dihydroxy-4-androsten-3-one'],
#  'map00190': ['H2O',
#   'ATP',
#   'NAD+',
#   'NADH',
#   'Oxygen',
#   'ADP',
#   'Orthophosphate',
#   'Diphosphate',
#   'Succinate',
#   'FMN',
#   'H+',
#   'Fumarate',
#   'Ubiquinol',
#   'Ubiquinone',
#   'Cytochrome c',
#   'Triphosphate'],
#  'map00195': ['H2O',
#   'ATP',
#   'NADPH',
#   'NADP+',
#   'Oxygen',
#   'ADP',
#   'Orthophosphate',
#   'Manganese',
#   'H+',
#   'Plastoquinone',
#   'Plastoquinol-1'],
#  'map00230': ['ATP',
#   'ADP',
#   'CO2',
#   'Ammonia',
#   'AMP',
#   'GDP',
#   'Glycine',
#   'DNA',
#   'GTP',
#   'RNA',
#   'Glyoxylate',
#   "3'-Phosphoadenylyl sulfate",
#   "Adenosine 3',5'-bisphosphate",
#   'Sulfate',
#   'L-Glutamine',
#   'ITP',
#   'Urea',
#   'IDP',
#   'D-Ribose 5-phosphate',
#   '5-Phospho-alpha-D-ribose 1-diphosphate',
#   'IMP',
#   'dATP',
#   'GMP',
#   'Adenine',
#   'Carbamoyl phosphate',
#   'dADP',
#   'Adenosine',
#   'Adenylyl sulfate',
#   'Guanine',
#   'Hypoxanthine',
#   'dGTP',
#   'Inosine',
#   'ADP-ribose',
#   'Deoxyguanosine',
#   'dAMP',
#   'dGDP',
#   'dGMP',
#   'Urate',
#   'Xanthine',
#   'Guanosine',
#   'Allantoate',
#   'Deoxyadenosine',
#   "3',5'-Cyclic AMP",
#   '(-)-Ureidoglycolate',
#   'alpha-D-Ribose 1-phosphate',
#   "Xanthosine 5'-phosphate",
#   'XTP',
#   'Oxalureate',
#   "3',5'-Cyclic GMP",
#   "Guanosine 3',5'-bis(diphosphate)",
#   "P1,P4-Bis(5'-adenosyl) tetraphosphate",
#   "P1,P4-Bis(5'-guanosyl) tetraphosphate",
#   'dIDP',
#   'dITP',
#   "3'-AMP",
#   'Xanthosine',
#   '(S)-Ureidoglycine',
#   '(R)(-)-Allantoin',
#   '(S)(+)-Allantoin',
#   "2',3'-Cyclic AMP",
#   'N-Formiminoglycine',
#   '5-Phosphoribosylamine',
#   'Aminoimidazole ribotide',
#   'Adenosine tetraphosphate',
#   "Inosine 5'-tetraphosphate",
#   'N6-(1,2-Dicarboxyethyl)-AMP',
#   "5'-Phosphoribosylglycinamide",
#   '5-Amino-4-imidazolecarboxyamide',
#   "5'-Phosphoribosyl-N-formylglycinamide",
#   "P1,P4-Bis(5'-xanthosyl) tetraphosphate",
#   "Guanosine 3'-diphosphate 5'-triphosphate",
#   "2-(Formamido)-N1-(5'-phosphoribosyl)acetamidine",
#   "1-(5'-Phosphoribosyl)-5-amino-4-imidazolecarboxamide",
#   "1-(5'-Phosphoribosyl)-5-formamido-4-imidazolecarboxamide",
#   '1-(5-Phospho-D-ribosyl)-5-amino-4-imidazolecarboxylate',
#   "1-(5'-Phosphoribosyl)-5-amino-4-(N-succinocarboxamide)-imidazole",
#   '5-Aminoimidazole',
#   'Deoxyinosine',
#   'Urate-3-ribonucleoside',
#   '5-Ureido-4-imidazole carboxylate',
#   '5-Amino-4-imidazole carboxylate',
#   'Acetyl adenylate',
#   "Guanosine 3'-phosphate",
#   "2',3'-Cyclic GMP",
#   'Imidazolone',
#   "2'-Deoxyinosine 5'-phosphate",
#   "P1,P3-Bis(5'-adenosyl) triphosphate",
#   "5'-Benzoylphosphoadenosine",
#   "5'-Butyrylphosphoinosine",
#   '5-Hydroxyisourate',
#   '5-Hydroxy-2-oxo-4-ureido-2,5-dihydro-1H-imidazole-5-carboxylate',
#   '5-Carboxyamino-1-(5-phospho-D-ribosyl)imidazole'],
#  'map00231': ['ATP',
#   'L-Tyrosine',
#   'Puromycin',
#   "3'-Keto-3'-deoxy-ATP",
#   "3'-Keto-3'-deoxy-AMP",
#   "3'-Amino-3'-deoxy-AMP",
#   "N6,N6,O-Tridemethylpuromycin-5'-phosphate",
#   "N-Acetyl-N6,N6,O-tridemethylpuromycin-5'-phosphate",
#   "N-Acetyl-N6,O-didemethylpuromycin-5'-phosphate",
#   "N-Acetyl-O-demethylpuromycin-5'-phosphate",
#   'N-Acetyl-O-demethylpuromycin',
#   'N-Acetylpuromycin'],
#  'map00232': ['Glyoxylate',
#   'Xanthine',
#   'Xanthosine',
#   'Theophylline',
#   'Theobromine',
#   'Caffeine',
#   '1,7-Dimethylxanthine',
#   '7-Methylxanthosine',
#   '7-Methylxanthine',
#   '7-Methyluric acid',
#   '1,7-Dimethyluric acid',
#   '3-Methylxanthine',
#   '1-Methylxanthine',
#   '1-Methyluric acid',
#   '3,7-Dimethyluric acid',
#   '1,3,7-Trimethyluric acid',
#   '3,6,8-Trimethylallantoin',
#   'N-Methylurea',
#   "N,N'-Dimethylurea",
#   '5-Acetylamino-6-formylamino-3-methyluracil',
#   '5-Acetylamino-6-amino-3-methyluracil'],
#  'map00240': ['UDP',
#   'UDP-glucose',
#   'DNA',
#   'RNA',
#   'CMP',
#   'CTP',
#   'L-Glutamine',
#   'UTP',
#   'Urea',
#   'beta-Alanine',
#   'UMP',
#   'Uracil',
#   'CDP',
#   '5-Phospho-alpha-D-ribose 1-diphosphate',
#   'Carbamoyl phosphate',
#   'Thymine',
#   'Thymidine',
#   '3-Oxopropanoate',
#   'dCMP',
#   'Orotate',
#   'Uridine',
#   '(S)-Dihydroorotate',
#   'Thioredoxin',
#   'Thioredoxin disulfide',
#   'dTDP',
#   'dTMP',
#   'dUMP',
#   'Cytosine',
#   'Malonate',
#   '5,6-Dihydrouracil',
#   'N-Carbamoyl-L-aspartate',
#   'dCTP',
#   'dTTP',
#   'dUTP',
#   'Cytidine',
#   'Deoxyuridine',
#   '2-Deoxy-D-ribose 1-phosphate',
#   'dCDP',
#   'Barbiturate',
#   'Deoxycytidine',
#   '5,6-Dihydrothymine',
#   '3-Hydroxypropanoate',
#   "Orotidine 5'-phosphate",
#   "Pseudouridine 5'-phosphate",
#   'dUDP',
#   "3'-UMP",
#   'Carbamate',
#   'Pseudouridine',
#   'Methylmalonate',
#   "2',3'-Cyclic CMP",
#   "2',3'-Cyclic UMP",
#   '5-Methylcytosine',
#   '3-Ureidopropionate',
#   '5-Hydroxymethyldeoxycytidylate',
#   '3-Ureidoisobutyrate',
#   '3-Aminoisobutyric acid',
#   '5-Methylbarbiturate',
#   "3'-CMP",
#   "P1,P4-Bis(5'-uridyl) tetraphosphate",
#   "2'-Deoxy-5-hydroxymethylcytidine-5'-diphosphate",
#   "2'-Deoxy-5-hydroxymethylcytidine-5'-triphosphate",
#   '3-Oxo-3-ureidopropanoate',
#   '(Z)-3-Ureidoacrylate peracid',
#   '(Z)-3-Peroxyaminoacrylate',
#   'Aminoacrylate',
#   'Ureidoacrylate'],
#  'map00250': ['Ammonia',
#   'Pyruvate',
#   'L-Glutamate',
#   '2-Oxoglutarate',
#   'Oxaloacetate',
#   'L-Alanine',
#   'Succinate',
#   'L-Aspartate',
#   'L-Glutamine',
#   'Fumarate',
#   'L-Asparagine',
#   'Carbamoyl phosphate',
#   'Succinate semialdehyde',
#   '4-Aminobutanoate',
#   'D-Glucosamine 6-phosphate',
#   'D-Aspartate',
#   'N-Carbamoyl-L-aspartate',
#   '2-Oxoglutaramate',
#   'N-Acetyl-L-aspartate',
#   '2-Oxosuccinamate',
#   '5-Phosphoribosylamine',
#   'N-(L-Arginino)succinate',
#   'N6-(1,2-Dicarboxyethyl)-AMP',
#   '(S)-1-Pyrroline-5-carboxylate'],
#  'map00253': ['Acetyl-CoA',
#   'Malonyl-CoA',
#   'Anhydrotetracycline',
#   '5a,11a-Dehydrotetracycline',
#   'Tetracycline',
#   'Chlortetracycline',
#   'Oxytetracycline',
#   'Malonamoyl-CoA',
#   '4-Ketoanhydrochlortetracycline',
#   '4-Keto-anhydrotetracycline',
#   '4-Hydroxy-6-methylpretetramide',
#   '6-Methylpretetramide',
#   '4-Amino-anhydrotetracycline',
#   'Nonaketamide',
#   'C-9 Reduced nonaketamide',
#   'Nonaketamide monocyclic intermediate',
#   'Nonaketamide tricyclic intermediate',
#   'Pretetramid',
#   '5a,11a-Dehydrooxytetracycline',
#   'Anhydrochlortetracycline',
#   '5a,11a-Dehydrochlortetracycline',
#   '4-Aminoanhydrochlortetracycline'],
#  'map00254': ['Acetyl-CoA',
#   'Malonyl-CoA',
#   'Sterigmatocystin',
#   '6-Demethylsterigmatocystin',
#   'O-Methylsterigmatocystin',
#   'Dihydro-O-methylsterigmatocystin',
#   'Aflatoxin B1',
#   'Aflatoxin B2',
#   'Aflatoxin G2',
#   'Aflatoxin G1',
#   'Dihydrodemethylsterigmatocystin',
#   'Dihydrosterigmatocystin',
#   'Norsolorinic acid',
#   'Norsolorinic acid anthrone',
#   "(1'S)-Averantin",
#   "(1'S,5'S)-5'-Hydroxyaverantin",
#   "(1'S,5'R)-5'-Hydroxyaverantin",
#   "5'-Oxoaverantin",
#   "1'-Hydroxyversicolorone",
#   'Versicolorone',
#   'Versiconal hemiacetal acetate',
#   'Versiconol acetate',
#   'Versiconal',
#   'Versiconol',
#   "(1'S,5'S)-Averufin",
#   'Versicolorin B',
#   'Versicolorin A'],
#  'map00260': ['CO2',
#   'Ammonia',
#   'Pyruvate',
#   'Glycine',
#   'Glyoxylate',
#   'L-Aspartate',
#   'L-Serine',
#   'L-Tryptophan',
#   'L-Cysteine',
#   'Tetrahydrofolate',
#   '2-Oxobutanoate',
#   'Choline',
#   '5,10-Methylenetetrahydrofolate',
#   'Hydroxypyruvate',
#   'L-Threonine',
#   '3-Phospho-D-glycerate',
#   'Sarcosine',
#   'D-Glycerate',
#   'L-Homoserine',
#   'Creatine',
#   '5-Aminolevulinate',
#   'L-Aspartate 4-semialdehyde',
#   'Methylglyoxal',
#   'Betaine aldehyde',
#   'Guanidinoacetate',
#   '2-Phospho-D-glycerate',
#   'Betaine',
#   'D-Serine',
#   '1,3-Diaminopropane',
#   'O-Phospho-L-serine',
#   'N,N-Dimethylglycine',
#   'O-Phospho-L-homoserine',
#   'S-Aminomethyldihydrolipoylprotein',
#   'D-Lombricine',
#   'Aminoacetone',
#   'Lipoylprotein',
#   'L-Cystathionine',
#   'Phosphatidylserine',
#   'N-Phospho-D-lombricine',
#   'Dihydrolipoylprotein',
#   '4-Phospho-L-aspartate',
#   '(R)-1-Aminopropan-2-ol',
#   '3-Phosphonooxypyruvate',
#   'L-2,4-Diaminobutanoate',
#   'L-2-Amino-3-oxobutanoic acid',
#   'Hydroxyacetone',
#   'L-Allothreonine',
#   'Ectoine',
#   'N(gamma)-Acetyldiaminobutyrate',
#   '5-Hydroxyectoine',
#   'N-alpha-Acetyl-L-2,4-diaminobutyrate'],
#  'map00270': ['S-Adenosyl-L-methionine',
#   'S-Adenosyl-L-homocysteine',
#   'Pyruvate',
#   'L-Alanine',
#   'L-Aspartate',
#   'Glutathione',
#   'Sulfate',
#   'L-Serine',
#   'L-Methionine',
#   'Sulfite',
#   'L-Cysteine',
#   '2-Oxobutanoate',
#   'L-Homocysteine',
#   "5'-Methylthioadenosine",
#   'L-Homoserine',
#   'Hydrogen sulfide',
#   'Thiosulfate',
#   'Methanethiol',
#   'L-Aspartate 4-semialdehyde',
#   'L-Cystine',
#   'L-Cysteate',
#   '3-Sulfino-L-alanine',
#   'D-Cysteine',
#   'Mercaptopyruvate',
#   'O-Acetyl-L-serine',
#   'O-Phospho-L-serine',
#   'O-Acetyl-L-homoserine',
#   'O-Succinyl-L-homoserine',
#   'S-Adenosylmethioninamine',
#   '4-Methylthio-2-oxobutanoic acid',
#   '1-Aminocyclopropane-1-carboxylate',
#   'Homocystine',
#   'Thiocysteine',
#   'Dehydroalanine',
#   'L-Cystathionine',
#   'L-Methionine S-oxide',
#   '4-Phospho-L-aspartate',
#   '5-Methylthio-D-ribose',
#   'N-Formylmethionine',
#   'S-Ribosyl-L-homocysteine',
#   'S-Methyl-5-thio-D-ribose 1-phosphate',
#   'S-Methyl-5-thio-D-ribulose 1-phosphate',
#   'Aminoacyl-L-methionine',
#   'S-Glutathionyl-L-cysteine',
#   '3-Sulfinylpyruvate',
#   '3-Sulfopyruvate',
#   '3-Mercaptolactate',
#   'S-Sulfo-L-cysteine',
#   'Ethylene',
#   '3-(Methylthio)propionic acid',
#   'Sulfur dioxide',
#   'HSO3-',
#   '(S)-3-Sulfolactate',
#   '(2R)-3-Sulfolactate',
#   '1,2-Dihydroxy-5-(methylthio)pent-1-en-3-one',
#   '2,3-Diketo-5-methylthiopentyl-1-phosphate',
#   '2-Hydroxy-3-keto-5-methylthiopentenyl-1-phosphate'],
#  'map00280': ['Acetyl-CoA',
#   'Thiamin diphosphate',
#   'Succinyl-CoA',
#   'Propanoyl-CoA',
#   'L-Leucine',
#   '3-Methyl-2-oxobutanoic acid',
#   'Acetoacetate',
#   'L-Valine',
#   '4-Methyl-2-oxopentanoate',
#   'Acetoacetyl-CoA',
#   '(S)-3-Hydroxy-3-methylglutaryl-CoA',
#   'L-Isoleucine',
#   '2-Methylpropanoyl-CoA',
#   '(S)-3-Methyl-2-oxopentanoic acid',
#   '(S)-Methylmalonyl-CoA',
#   '(R)-Methylmalonyl-CoA',
#   'Methylmalonate',
#   '(3R)-beta-Leucine',
#   '3-Methylbutanoyl-CoA',
#   '3-Methylcrotonyl-CoA',
#   '3-Methylglutaconyl-CoA',
#   'L-3-Amino-isobutanoate',
#   '2-Methylacetoacetyl-CoA',
#   '2-Methylbut-2-enoyl-CoA',
#   '2-Methylprop-2-enoyl-CoA',
#   'beta-Ketoisocaproate',
#   '(2S,3S)-3-Hydroxy-2-methylbutanoyl-CoA',
#   'Branched chain fatty acid',
#   '3-Hydroxyisovaleryl-CoA',
#   '(S)-3-Hydroxyisobutyryl-CoA',
#   '(S)-3-Hydroxyisobutyrate',
#   '(S)-Methylmalonate semialdehyde',
#   'Enzyme N6-(lipoyl)lysine',
#   'Enzyme N6-(dihydrolipoyl)lysine',
#   '3-Methyl-1-hydroxybutyl-ThPP',
#   '[Dihydrolipoyllysine-residue (2-methylpropanoyl)transferase] S-(3-methylbutanoyl)dihydrolipoyllysine',
#   '2-Methyl-1-hydroxypropyl-ThPP',
#   '[Dihydrolipoyllysine-residue (2-methylpropanoyl)transferase] S-(2-methylpropanoyl)dihydrolipoyllysine',
#   '2-Methyl-1-hydroxybutyl-ThPP',
#   '[Dihydrolipoyllysine-residue (2-methylpropanoyl)transferase] S-(2-methylbutanoyl)dihydrolipoyllysine',
#   '(S)-2-Methylbutanoyl-CoA'],
#  'map00281': ['3-(4-Methylpent-3-en-1-yl)pent-2-enedioyl-CoA',
#   'Geranial',
#   'Geraniol',
#   'Geranoyl-CoA',
#   '3-Methylcrotonyl-CoA',
#   '3-Hydroxy-3-(4-methylpent-3-en-1-yl)glutaryl-CoA',
#   'cis-Citral',
#   '(R)-(+)-Citronellal',
#   'beta-Citronellol',
#   'Nerol',
#   '(S)-(-)-Citronellal',
#   '(-)-Citronellol',
#   'Geranic acid',
#   'Citronellate',
#   'Citronellyl-CoA',
#   'trans-Geranyl-CoA',
#   '7-Methyl-3-oxo-6-octenoyl-CoA',
#   '(2E)-5-Methylhexa-2,4-dienoyl-CoA',
#   '3-Hydroxy-5-methylhex-4-enoyl-CoA',
#   '5-Methylhex-4-enoyl-CoA',
#   '5-Methyl-3-oxo-4-hexenoyl-CoA'],
#  'map00290': ['Pyruvate',
#   'Acetyl-CoA',
#   '2-Oxobutanoate',
#   'L-Leucine',
#   '3-Methyl-2-oxobutanoic acid',
#   'L-Valine',
#   'L-Threonine',
#   '4-Methyl-2-oxopentanoate',
#   'L-Isoleucine',
#   '(S)-3-Methyl-2-oxopentanoic acid',
#   '2-Methylmaleate',
#   'alpha-Isopropylmalate',
#   '(R)-2-Methylmalate',
#   '2-Isopropylmaleate',
#   '3-Hydroxy-3-methyl-2-oxobutanoic acid',
#   '(2S)-2-Isopropyl-3-oxosuccinate',
#   '(R)-2,3-Dihydroxy-3-methylbutanoate',
#   '(2R,3S)-3-Isopropylmalate',
#   '(S)-2-Aceto-2-hydroxybutanoate',
#   '(R)-2,3-Dihydroxy-3-methylpentanoate',
#   '(S)-2-Acetolactate',
#   'D-erythro-3-Methylmalate',
#   '(R)-3-Hydroxy-3-methyl-2-oxopentanoate'],
#  'map00300': ['Acetyl-CoA',
#   '2-Oxoglutarate',
#   'L-Lysine',
#   'L-Aspartate',
#   'L-Homoserine',
#   '2-Oxoadipate',
#   'L-Aspartate 4-semialdehyde',
#   'N6-(L-1,3-Dicarboxypropyl)-L-lysine',
#   'LL-2,6-Diaminoheptanedioate',
#   'meso-2,6-Diaminoheptanedioate',
#   'L-2-Aminoadipate',
#   '(R)-2-Hydroxybutane-1,2,4-tricarboxylate',
#   '4-Phospho-L-aspartate',
#   'L-2-Amino-6-oxoheptanedioate',
#   '2,3,4,5-Tetrahydrodipicolinate',
#   '(Z)-But-1-ene-1,2,4-tricarboxylate',
#   'L-2-Aminoadipate 6-semialdehyde',
#   'N6-Acetyl-LL-2,6-diaminoheptanedioate',
#   'N-Succinyl-LL-2,6-diaminoheptanedioate',
#   'N-Succinyl-2-L-amino-6-oxoheptanedioate',
#   'UDP-N-acetylmuramoyl-L-alanyl-D-gamma-glutamyl-meso-2,6-diaminopimelate',
#   'UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-6-carboxy-L-lysyl-D-alanyl-D-alanine',
#   'alpha-Aminoadipoyl-S-acyl enzyme',
#   'N-Acetyl-L-2-amino-6-oxopimelate',
#   'L-2-Aminoadipate adenylate',
#   'Homoisocitrate',
#   'L-Pyrrolysine',
#   'LysW-gamma-L-alpha-aminoadipate',
#   'LysW-gamma-L-alpha-aminoadipyl-6-phosphate',
#   'LysW-gamma-L-alpha-aminoadipate 6-semialdehyde',
#   'LysW-gamma-L-lysine',
#   '(2S,4S)-4-Hydroxy-2,3,4,5-tetrahydrodipicolinate',
#   '(2R,3R)-3-Methylornithine',
#   '(2R,3R)-3-Methylornithinyl-N6-lysine',
#   '(2R,3R)-3-Methylglutamyl-5-semialdehyde-N6-lysine'],
#  'map00310': ['Acetyl-CoA',
#   'Glycine',
#   'L-Lysine',
#   '2-Oxoadipate',
#   'Acetoacetyl-CoA',
#   'L-Pipecolate',
#   '5-Aminopentanoate',
#   'N6-(L-1,3-Dicarboxypropyl)-L-lysine',
#   '(S)-2,3,4,5-Tetrahydropyridine-2-carboxylate',
#   'Carnitine',
#   'Glutarate',
#   'Glutaryl-CoA',
#   'D-Lysine',
#   'Crotonoyl-CoA',
#   'L-2-Aminoadipate',
#   '5-Aminopentanamide',
#   'N6-Hydroxy-L-lysine',
#   '(3S)-3,6-Diaminohexanoate',
#   '(S)-3-Hydroxybutanoyl-CoA',
#   '4-Trimethylammoniobutanal',
#   '4-Trimethylammoniobutanoate',
#   '(3S,5S)-3,5-Diaminohexanoate',
#   'Procollagen 5-hydroxy-L-lysine',
#   '3-Hydroxy-N6,N6,N6-trimethyl-L-lysine',
#   'Cadaverine',
#   'Protein lysine',
#   'N6-Acetyl-L-lysine',
#   '5-Acetamidopentanoate',
#   '6-Amino-2-oxohexanoate',
#   '5-Oxopentanoate',
#   '(S)-5-Amino-3-oxohexanoic acid',
#   'N6,N6,N6-Trimethyl-L-lysine',
#   'N6-Acetyl-N6-hydroxy-L-lysine',
#   'D-Lysopine',
#   'L-2-Aminoadipate 6-semialdehyde',
#   'delta1-Piperideine-2-carboxylate',
#   '5-(D-Galactosyloxy)-L-lysine-procollagen',
#   '2,5-Diaminohexanoate',
#   'Protein N6-methyl-L-lysine',
#   'Protein N6,N6-dimethyl-L-lysine',
#   'Protein N6,N6,N6-trimethyl-L-lysine',
#   '6-Acetamido-2-oxohexanoate',
#   'Aerobactin',
#   '2-Amino-5-oxohexanoate',
#   '[Dihydrolipoyllysine-residue succinyltransferase] S-glutaryldihydrolipoyllysine',
#   'Piperideine',
#   'N2-citryl-N6-acetyl-N6-hydroxy-L-lysine'],
#  'map00311': ['L-Cysteine',
#   'L-Valine',
#   'Penicillin',
#   'Cephalosporin C',
#   'L-2-Aminoadipate',
#   '6-Aminopenicillanate',
#   'Deacetylcephalosporin C',
#   '(7R)-7-(5-Carboxy-5-oxopentanoyl)aminocephalosporinate',
#   'delta-(L-2-Aminoadipyl)-L-cysteinyl-D-valine',
#   'Isopenicillin N',
#   'Penicillin N',
#   'Deacetoxycephalosporin C',
#   'Cephamycin C',
#   'Penicilloic acid',
#   'O-Carbamoyl-deacetylcephalosporin C',
#   '7a-Hydroxy-O-carbamoyl-deacetylcephalosporin C',
#   '7-Aminocephalosporanic acid',
#   '(7R)-7-(4-Carboxybutanamido)cephalosporanate'],
#  'map00312': ['DNA', 'beta-Lactam antibiotics'],
#  'map00330': ['CO2',
#   'Peptide',
#   'Ammonia',
#   'S-Adenosyl-L-methionine',
#   'Pyruvate',
#   'L-Glutamate',
#   'Glyoxylate',
#   'L-Aspartate',
#   'L-Arginine',
#   'L-Glutamine',
#   'L-Ornithine',
#   'Urea',
#   'Fumarate',
#   'Putrescine',
#   'L-Proline',
#   'Carbamoyl phosphate',
#   'Agmatine',
#   'Sarcosine',
#   'p-Coumaroyl-CoA',
#   'Creatine',
#   'Spermidine',
#   'L-Citrulline',
#   '4-Aminobutanoate',
#   'Feruloyl-CoA',
#   '5-Aminopentanoate',
#   '2,5-Dioxopentanoate',
#   'N-Carbamoylputrescine',
#   'N-Acetylornithine',
#   'L-Aspartate 4-semialdehyde',
#   'Nitric oxide',
#   '4-Aminobutyraldehyde',
#   'Guanidinoacetate',
#   'N-Acetyl-L-glutamate',
#   'Spermine',
#   'D-Proline',
#   'Creatinine',
#   'Homocarnosine',
#   '1,3-Diaminopropane',
#   'Urea-1-carboxylate',
#   '4-Guanidinobutanoate',
#   'N-Carbamoylsarcosine',
#   '5-Amino-2-oxopentanoic acid',
#   'S-Adenosylmethioninamine',
#   'Hydroxyproline',
#   'L-Glutamate 5-semialdehyde',
#   'N-Acetyl-L-glutamate 5-semialdehyde',
#   'Nopaline',
#   '4-Oxoproline',
#   'Phosphocreatine',
#   'N-Methylhydantoin',
#   '4-Guanidinobutanal',
#   'N-Acetylputrescine',
#   '4-Acetamidobutanoate',
#   '4-Guanidinobutanamide',
#   'Phosphoguanidinoacetate',
#   'L-Glutamyl 5-phosphate',
#   'N2-Succinyl-L-arginine',
#   'Norspermidine',
#   'N-(L-Arginino)succinate',
#   'N2-Succinyl-L-ornithine',
#   'cis-4-Hydroxy-D-proline',
#   '1-Pyrroline-2-carboxylate',
#   '5-Guanidino-2-oxopentanoate',
#   '(S)-1-Pyrroline-5-carboxylate',
#   'N-Acetyl-L-glutamate 5-phosphate',
#   'D-Octopine',
#   'L-1-Pyrroline-3-hydroxy-5-carboxylate',
#   '1-Pyrroline-4-hydroxy-2-carboxylate',
#   'p-Coumaroylagmatine',
#   'N-Succinyl-L-glutamate',
#   'N-Succinyl-L-glutamate 5-semialdehyde',
#   'N(omega)-Hydroxyarginine',
#   'N4-Acetylaminobutanal',
#   'L-4-Hydroxyglutamate semialdehyde',
#   'Linatine',
#   '2-Oxo-4-hydroxy-5-aminovalerate',
#   'Pyrrole-2-carboxylate',
#   'L-Arginine phosphate',
#   'D-4-Hydroxy-2-oxoglutarate',
#   'L-erythro-4-Hydroxyglutamate',
#   'Feruloylputrescine',
#   'N-Acetyl-L-citrulline',
#   'gamma-L-Glutamylputrescine',
#   'gamma-Glutamyl-gamma-aminobutyraldehyde',
#   '4-(L-gamma-Glutamylamino)butanoate',
#   'N-Succinyl-L-citrulline',
#   'Carboxyspermidine',
#   'Carboxynorspermidine',
#   'Feruloylagmatine',
#   'p-Coumaroylputrescine'],
#  'map00331': ['L-Arginine',
#   'D-Glyceraldehyde 3-phosphate',
#   'L-N2-(2-Carboxyethyl)arginine',
#   'Deoxyguanidinoproclavaminic acid',
#   'Guanidinoproclavaminic acid',
#   'Proclavaminic acid',
#   'Dihydroclavaminic acid',
#   'Clavaminic acid',
#   'Clavulanate-9-aldehyde',
#   'Clavulanic acid'],
#  'map00340': ['L-Glutamate',
#   '2-Oxoglutarate',
#   'L-Aspartate',
#   '5-Phospho-alpha-D-ribose 1-diphosphate',
#   'L-Histidine',
#   'Carnosine',
#   'Histamine',
#   'N-Formimino-L-glutamate',
#   'Urocanate',
#   'L-Histidinol',
#   'N-Formyl-L-aspartate',
#   'N-Formyl-L-glutamate',
#   'L-Histidinol phosphate',
#   'N(pi)-Methyl-L-histidine',
#   'beta-Alanyl-N(pi)-methyl-L-histidine',
#   '3-(Imidazol-4-yl)-2-oxopropyl phosphate',
#   'L-Histidinal',
#   '1-(5-Phospho-D-ribosyl)-ATP',
#   'Phosphoribosyl-AMP',
#   'Imidazole-4-acetate',
#   'Imidazol-5-yl-pyruvate',
#   'N-Formimino-L-aspartate',
#   '4-Imidazolone-5-propanoate',
#   '1-(5-Phosphoribosyl)imidazole-4-acetate',
#   'D-erythro-1-(Imidazol-4-yl)glycerol 3-phosphate',
#   "1-(5'-Phosphoribosyl)-5-amino-4-imidazolecarboxamide",
#   '5-(5-Phospho-D-ribosylaminoformimino)-1-(5-phosphoribosyl)-imidazole-4-carboxamide',
#   "N-(5'-Phospho-D-1'-ribulosylformimino)-5-amino-1-(5''-phospho-D-ribosyl)-4-imidazolecarboxamide",
#   'N-Methylhistamine',
#   'Imidazole-4-acetaldehyde',
#   '(1-Ribosylimidazole)-4-acetate',
#   '4-Imidazolone-5-acetate',
#   '4-(beta-Acetylaminoethyl)imidazole',
#   'Hydantoin-5-propionate',
#   'Imidazole lactate',
#   'Ergothioneine',
#   'Thiourocanic acid',
#   '4-Oxoglutaramate',
#   'Hercynine',
#   'Methylimidazole acetaldehyde',
#   'Methylimidazoleacetic acid',
#   'N-Carbamyl-L-glutamate',
#   'Isoglutamine',
#   'Formylisoglutamine',
#   'Dihydrourocanate'],
#  'map00350': ['Pyruvate',
#   'Succinate',
#   'L-Tyrosine',
#   'Fumarate',
#   'Phenol',
#   'Acetoacetate',
#   'Succinate semialdehyde',
#   '3,4-Dihydroxy-L-phenylalanine',
#   'Tyramine',
#   'Hydroquinone',
#   'Homogentisate',
#   'L-Noradrenaline',
#   '2,5-Dihydroxybenzoate',
#   '4-Hydroxyphenylacetate',
#   'L-Adrenaline',
#   'Dopaquinone',
#   '4-Maleylacetoacetate',
#   '3,5-Diiodo-L-tyrosine',
#   '4-Fumarylacetoacetate',
#   '3,4-Dihydroxyphenylacetate',
#   '3-(4-Hydroxyphenyl)pyruvate',
#   '3-(3,4-Dihydroxyphenyl)lactate',
#   'L-Dopachrome',
#   'Thyroxine',
#   'Rosmarinate',
#   'Maleylpyruvate',
#   'N-Methyltyramine',
#   'Triiodothyronine',
#   '3-Fumarylpyruvate',
#   '3-Iodo-L-tyrosine',
#   '2-Oxohept-3-enedioate',
#   '4-Chlorophenylacetate',
#   '3-(4-Hydroxyphenyl)lactate',
#   'Dopamine',
#   '4-Hydroxyphenylacetaldehyde',
#   '3,4-Dihydroxyphenylacetaldehyde',
#   '3-(3,4-Dihydroxyphenyl)pyruvate',
#   '5-Carboxy-2-oxohept-3-enedioate',
#   '5,6-Dihydroxyindole-2-carboxylate',
#   '5-Carboxymethyl-2-hydroxymuconate',
#   '3-Amino-3-(4-hydroxyphenyl)propanoate',
#   '2-Hydroxy-5-carboxymethylmuconate semialdehyde',
#   '4-(L-Alanin-3-yl)-2-hydroxy-cis,cis-muconate 6-semialdehyde',
#   '5-(L-Alanin-3-yl)-2-hydroxy-cis,cis-muconate 6-semialdehyde',
#   '4-Hydroxyphenylacetyl-CoA',
#   '2-Hydroxy-3-(4-hydroxyphenyl)propenoate',
#   '3,4-Dihydroxyphenylethyleneglycol',
#   '3,4-Dihydroxymandelaldehyde',
#   '5,6-Dihydroxyindole',
#   'Indole-5,6-quinone',
#   '3,4-Dihydroxymandelate',
#   '3-Methoxy-4-hydroxyphenylacetaldehyde',
#   'Homovanillate',
#   '3-Methoxy-4-hydroxyphenylglycolaldehyde',
#   '3-Methoxy-4-hydroxymandelate',
#   'Gentisate aldehyde',
#   '3-Methoxytyramine',
#   'L-Metanephrine',
#   'L-Normetanephrine',
#   '3-Hydroxyphenylacetate',
#   '3-Methoxy-4-hydroxyphenylethyleneglycol',
#   '4-Hydroxyphenylacetylglutamic acid',
#   'p-Hydroxyphenylacetylglycine',
#   '2-Hydroxyhepta-2,4-dienedioate',
#   '2-Carboxy-2,3-dihydro-5,6-dihydroxyindole',
#   '4-Hydroxyphenylethanol',
#   'Salidroside',
#   'Stizolobate',
#   'Stizolobinate',
#   'Hordenine',
#   '2,4-Dihydroxyhept-2-enedioate',
#   '3,4-Dihydroxyphenylpropanoate',
#   'Cysteinyldopa',
#   'Phaeomelanin',
#   'Eumelanin',
#   '5,6-Indolequinone-2-carboxylic acid'],
#  'map00351': ['4-Chlorobenzoate',
#   '4-Chlorophenylacetate',
#   '1,1-Dichloro-2,2-bis(4-chlorophenyl)ethylene',
#   'DDT',
#   'TDE',
#   "1-Chloro-2,2-bis(4'-chlorophenyl)ethylene",
#   "1-Chloro-2,2-bis(4'-chlorophenyl)ethane",
#   "2,2-Bis(4'-chlorophenyl)ethanol",
#   "Bis(4'-chlorophenyl)acetate",
#   "Bis(4'-chlorophenyl)methane",
#   "unsym-Bis(4'-chlorophenyl)ethylene",
#   "4,4'-Dichlorobenzophenone",
#   "1,1-Dichloro-2-(dihydroxy-4'-chlorophenyl)-2-(4'-chlorophenyl)ethylene",
#   "6-Oxo-2-hydroxy-7-(4'-chlorophenyl)-3,8,8-trichloroocta-2E,4E,7E-trienoate",
#   "2-(4'-Chlorophenyl)-3,3-dichloropropenoate",
#   '4-Chloroacetophenone',
#   '4-Chlorobenzaldehyde',
#   "cis-2,3-Dihydrodiol 1,1,1-Trichloro-2,2-bis(4'-chlorophenyl)ethane",
#   "2,3-Dihydroxy 1,1,1-Trichloro-2,2-bis(4'-chlorophenyl)ethane",
#   "6-Oxo-2-hydroxy-7-(4'-chlorophenyl)-3,8,8,8-tetrachloroocta-2E,4E-dienoate"],
#  'map00360': ['Pyruvate',
#   'Acetyl-CoA',
#   'Succinate',
#   'L-Phenylalanine',
#   'L-Tyrosine',
#   'Malonyl-CoA',
#   'Acetaldehyde',
#   'Succinyl-CoA',
#   'Fumarate',
#   '4-Hydroxybenzoate',
#   'Phenylpyruvate',
#   'Benzoate',
#   'p-Coumaroyl-CoA',
#   'Caffeoyl-CoA',
#   'Feruloyl-CoA',
#   'trans-Cinnamate',
#   'S-Benzoate coenzyme A',
#   'Phenylacetyl-CoA',
#   '2-Hydroxy-2,4-pentadienoate',
#   'Phenylacetaldehyde',
#   '2-Methylpropanoyl-CoA',
#   '4-Hydroxyphenylacetate',
#   '4-Hydroxy-3-methoxy-benzaldehyde',
#   'Salicylate',
#   '4-Coumarate',
#   '3-(2-Hydroxyphenyl)propanoate',
#   'Ephedrine',
#   'Hippurate',
#   'trans-2-Hydroxycinnamate',
#   'alpha-Oxo-benzeneacetic acid',
#   '3-Oxoadipyl-CoA',
#   'D-Phenylalanine',
#   '2-Phenylacetamide',
#   '2-Hydroxy-3-phenylpropenoate',
#   '(+)-Pseudoephedrine',
#   'N-Acetyl-L-phenylalanine',
#   '4-Hydroxy-2-oxopentanoate',
#   '3-(2,3-Dihydroxyphenyl)propanoate',
#   'Phenylacetylglutamine',
#   '(R)-2-Methylimino-1-phenylpropan-1-ol',
#   '2-Hydroxy-6-oxonona-2,4-diene-1,9-dioate',
#   'Phenethylamine',
#   '3-Hydroxyphenylacetate',
#   'Phenylacetylglycine',
#   'Phenyllactate',
#   'N-Acetyl-D-phenylalanine',
#   'Phenylpropanoate',
#   '2-Hydroxyphenylacetate',
#   'Phenylethyl alcohol',
#   '2,6-Dihydroxyphenylacetate',
#   'Capsaicin',
#   'Phenylacetic acid',
#   '4-Hydroxy-3-methoxyphenyl-beta-hydroxypropanoyl-CoA',
#   'D-Cathine',
#   'D-Cathinone',
#   '3-(3-Hydroxyphenyl)propanoic acid',
#   'cis-3-(Carboxy-ethyl)-3,5-cyclo-hexadiene-1,2-diol',
#   'trans-3-Hydroxycinnamate',
#   'cis-3-(3-Carboxyethenyl)-3,5-cyclohexadiene-1,2-diol',
#   'trans-2,3-Dihydroxycinnamate',
#   '2-Hydroxy-6-ketononatrienedioate',
#   '5-Carboxy-2-pentenoyl-CoA',
#   '(3S)-3-Hydroxyadipyl-CoA',
#   'Phenylglyoxylyl-CoA',
#   'Vanillylamine',
#   '(-)-Norephedrine',
#   'Pyruvophenone',
#   '8-Methyl-6-nonenoic acid',
#   '3-Oxo-5,6-dehydrosuberyl-CoA',
#   '3-Oxo-5,6-dehydrosuberyl-CoA semialdehyde',
#   '2-Oxepin-2(3H)-ylideneacetyl-CoA',
#   '2-(1,2-Epoxy-1,2-dihydrophenyl)acetyl-CoA'],
#  'map00361': ['CO2',
#   'Succinate',
#   'Catechol',
#   'Phenol',
#   'Glycolate',
#   'Hydroquinone',
#   '2-Hydroxymuconate semialdehyde',
#   'Benzene',
#   'Resorcinol',
#   '4-Chlorophenol',
#   '2-Maleylacetate',
#   '4-Chlorocatechol',
#   'Pentachlorophenol',
#   '2,4-Dichlorophenol',
#   'Benzene-1,2,4-triol',
#   '3,5-Dichlorocatechol',
#   'Tetrachlorohydroquinone',
#   '2-Chloro-cis,cis-muconate',
#   '3-Chloro-cis,cis-muconate',
#   '2,4-Dichlorophenoxyacetate',
#   '2,4-Dichloro-cis,cis-muconate',
#   'cis-1,2-Dihydrobenzene-1,2-diol',
#   'cis-4-Carboxymethylenebut-2-en-4-olide',
#   '2-Chloro-2,5-dihydro-5-oxofuran-2-acetate',
#   'cis-2-Chloro-4-carboxymethylenebut-2-en-1,4-olide',
#   'trans-2-Chloro-4-carboxymethylenebut-2-en-1,4-olide',
#   '3-Chlorocatechol',
#   '6-Chlorobenzene-1,2,4-triol',
#   '2-Chloromaleylacetate',
#   '1,2,4-Trichlorobenzene',
#   'gamma-Pentachlorocyclohexene',
#   '1,3,4,6-Tetrachloro-1,4-cyclohexadiene',
#   '2,4,5-Trichloro-2,5-cyclohexadiene-1-ol',
#   '2,5-Dichloro-2,5-cyclohexadiene-1,4-diol',
#   '2,5-Dichlorohydroquinone',
#   'Chlorohydroquinone',
#   '2,5-Dichlorophenol',
#   'cis,cis-4-Hydroxymuconic semialdehyde',
#   'Chloroacetic acid',
#   'beta-1,2,3,4,5,6-Hexachlorocyclohexane',
#   'delta-3,4,5,6-Tetrachlorocyclohexene',
#   'Chlorobenzene',
#   'Lindane',
#   '4-Chlorophenoxyacetate',
#   '5-Chloro-2-hydroxymuconic semialdehyde',
#   'Protoanemonin',
#   'cis-Acetylacrylate',
#   '1,4-Dichlorobenzene',
#   '3,6-Dichloro-cis-1,2-dihydroxycyclohexa-3,5-diene',
#   '3,6-Dichlorocatechol',
#   '2,5-Dichloro-cis,cis-muconate',
#   '2,6-Dichlorophenol',
#   '2,6-Dichlorohydroquinone',
#   '2,4,6-Trichlorophenol',
#   '2,3,6-Trichlorohydroquinone',
#   '2,4,5-Trichlorophenoxyacetic acid',
#   '2,4,5-Trichlorophenol',
#   '5-Chloro-1,2,4-trihydroxybenzene',
#   '2-Hydroxy-1,4-benzoquinone',
#   '5,6-Dichloro-1,3-cyclohexadiene',
#   '3,4,6-Trichlorocatechol',
#   '3,4,6-Trichloro-cis-1,2-dihydroxycyclohexa-3,5-diene',
#   '2,3,5-Trichloro-cis,cis-muconate',
#   '2,5-Dichloro-carboxymethylenebut-2-en-4-olide',
#   '2,5-Dichloro-4-oxohex-2-enedioate',
#   '2-Chloro-3-oxoadipate',
#   '3-Chloro-cis-1,2-dihydroxycyclohexa-3,5-diene',
#   'trans-4-Carboxymethylenebut-2-en-4-olide',
#   '2,4-Dichloroaniline',
#   '4-Chloroaniline',
#   'beta-2,3,4,5,6-Pentachlorocyclohexanol',
#   'beta-2,3,5,6-Tetrachloro-1,4-cyclohexanediol',
#   '3-Chloro-2-hydroxymuconic semialdehyde',
#   '1,2,3,4-Tetrachlorobenzene',
#   'cis-Chlorobenzene dihydrodiol',
#   'Tetrachlorocatechol',
#   'Tetrachloro-cis,cis-muconate',
#   '2,3,5-Trichlorodienelactone',
#   '2,3,5-Trichloromaleylacetate',
#   '2,4-Dichloro-3-oxoadipate'],
#  'map00362': ['Pyruvate',
#   'Acetyl-CoA',
#   'Oxaloacetate',
#   'Acetaldehyde',
#   'Catechol',
#   'Succinyl-CoA',
#   'Phenol',
#   '4-Hydroxybenzoate',
#   'Benzoate',
#   '2,3-Dihydroxybenzoate',
#   '3,4-Dihydroxybenzoate',
#   'Acetoacetyl-CoA',
#   'S-Benzoate coenzyme A',
#   'Glutaryl-CoA',
# ...
#   'Dexamethasone 21-valerate',
#   'Dexamethasone phenylpropionate',
#   'Dexamethasone phosphate',
#   'Fludrocortisone (INN)',
#   'Fluticasone (INN)',
#   'Prednisolone pivalate',
#   'Prednisolone sodium metazoate (USAN)',
#   'Prednisolone 21-(sodium tetrahydrophthalate)',
#   'Prednisolone steaglate (BAN)'],
#  'map07226': ['Progesterone',
#   'Estrone',
#   'Testosterone',
#   'Estradiol-17beta',
#   'Estriol',
#   'Progesterone (JP16/USP/INN)',
#   'Estrone (JAN/USP/INN)',
#   'Testosterone (JAN/USP)',
#   'Estradiol (JAN/USP/INN)',
#   'Norethisterone (JP16)',
#   'Estriol (JP16/USP)',
#   'Danazol (JP16/USP/INN)',
#   'Estrone sodium sulfate',
#   'Fluoxymesterone (JP16/USP/INN)',
#   'Methyltestosterone (JP16/USP/INN)',
#   'Stanozolol (JAN/USP/INN)',
#   'Oxandrolone (JAN/USP/INN)',
#   'Ethinylestradiol (JP16/INN)',
#   'Mestranol (JP16/USP/INN)',
#   'Diethylstilbestrol (USP/INN)',
#   'Mifepristone (USAN/INN)',
#   'Flutamide (JP16/USP/INN)',
#   'Fosfestrol (JAN/INN)',
#   'Hydroxyprogesterone caproate (JAN/USP/INN)',
#   'Medroxyprogesterone acetate (JAN/USP)',
#   'Norethisterone acetate (JAN)',
#   'Testosterone cypionate (USP)',
#   'Testosterone enanthate (JP16/USP)',
#   'Testosterone propionate (JP16/USP)',
#   'Bicalutamide (JAN/USP/INN)',
#   'Clomifene citrate (JP16)',
#   'Nilutamide (USAN/INN)',
#   'Tamoxifen citrate (JP16/USP)',
#   'Toremifene citrate (JAN/USAN)',
#   'Gestonorone caproate (JAN/USAN)',
#   'Fulvestrant (JAN/USAN/INN)',
#   'Dydrogesterone (JP16/USP/INN)',
#   'Epitiostanol (JAN/INN)',
#   'Cyclofenil (JAN/INN)',
#   'Chlormadinone acetate (JP16/USAN)',
#   'Oxendolone (JAN/USAN/INN)',
#   'Cyproterone acetate (JAN/USAN)',
#   'Estradiol valerate (JAN/USP/INN)',
#   'Mepitiostane (JP16/INN)',
#   'Estradiol dipropionate (JAN)',
#   'Estradiol benzoate (JP16)',
#   'Estriol tripropionate (JAN)',
#   'Estriol diacetate benzoate (JAN)',
#   'Desogestrel (USAN/INN)',
#   'Asoprisnil (USAN/INN)',
#   'Delmadinone acetate (USAN)',
#   'Estradiol acetate (USAN)',
#   'Estradiol cypionate (USP)',
#   'Estradiol enanthate (USAN)',
#   'Estradiol undecylate (USAN/INN)',
#   'Gestodene (USAN/INN)',
#   'Norgestimate (USP/INN)',
#   'Testosterone ketolaurate (USAN/INN)',
#   'Testosterone phenylacetate (USAN)',
#   'Testosterone undecanoate (USAN)',
#   'Polyestradiol phosphate (INN)',
#   'Chlormadinone (INN)',
#   'Clomifene (INN)',
#   'Cyproterone (INN)',
#   'Delmadinone (INN)',
#   'Hexestrol diphosphate sodium',
#   'Estradiol hemihydrate',
#   'Estradiol 17 beta-hemisuccinate',
#   'Estriol succinate',
#   'Estriol sodium succinate (BAN)',
#   'Ethinylestradiol propanesulfonate',
#   'Hydroxyprogesterone (INN)',
#   'Hydroxyprogesterone 17alfa-acetate',
#   'Medroxyprogesterone (INN)',
#   'Norethisterone enantate',
#   'Raloxifene (INN)',
#   'Tamoxifen (INN)',
#   'Testosterone decanoate',
#   'Testosterone phenylpropionate',
#   'Toremifene (INN)',
#   'Onapristone (INN)'],
#  'map07227': ['Histamine',
#   'Burimamide',
#   'N-Guanylhistamine',
#   'Thiaburimamide',
#   '4-Methylhistamine',
#   'Dimaprit',
#   'Imetit',
#   'Immepip',
#   'Thioperamide',
#   'Clobenpropit',
#   'Cimetidine (JP16/USP/INN)',
#   'Famotidine (JP16/USP/INN)',
#   'Ranitidine (USAN/INN)',
#   'Nizatidine (JP16/USP/INN)',
#   'Ranitidine hydrochloride (JP16/USP)',
#   'Lafutidine (JP16/INN)',
#   'Roxatidine acetate hydrochloride (JP16/USAN)',
#   'Cimetidine hydrochloride (USP)',
#   'Impromidine hydrochloride (USAN)',
#   'Metiamide (USAN/INN)',
#   'Ranitidine bismuth citrate (USAN)',
#   'Tiotidine (USAN/INN)',
#   'Niperotidine (INN)',
#   'Roxatidine (INN)',
#   'Roxatidine acetate (BAN)'],
#  'map07228': ['Dinoprostone (JAN/USP/INN)',
#   'Dinoprost (JP16/USAN/INN)',
#   'Epoprostenol (USAN/INN)',
#   'Alprostadil (JP16/USP/INN)',
#   'Latanoprost (JAN/USAN/INN)',
#   'Zafirlukast (JAN/USAN/INN)',
#   'Misoprostol (JAN/USAN/INN)',
#   'Montelukast sodium (JAN/USAN)',
#   'Carboprost tromethamine (USP)',
#   'Seratrodast (JAN/USAN/INN)',
#   'Ramatroban (JAN/INN)',
#   'Pimilprost (JAN/INN)',
#   'Epoprostenol sodium (JAN/USAN)',
#   'Dinoprost tromethamine (JAN/USP)',
#   'Ibudilast (JP16/INN)',
#   'Isopropyl unoprostone (JAN)',
#   'Beraprost sodium (JP16/USAN)',
#   'Ornoprostil (JAN/INN)',
#   'Enprostil (JAN/USAN/INN)',
#   'Travoprost (JAN/USAN/INN)',
#   'Clinprost (JAN/INN)',
#   'Gemeprost (JAN/USAN/INN)',
#   'Carboprost (USAN/INN)',
#   'Alprostadil alfadex (JP16)',
#   'Rosaprostol (INN)',
#   'Beraprost (USAN)',
#   'Iloprost (USAN/INN)',
#   'Limaprost (INN)',
#   'Bimatoprost (JAN/USAN/INN)',
#   'Sulprostone (USAN/INN)',
#   'Pranlukast hydrate (JAN)',
#   'Limaprost alfadex (JP16)',
#   'Butaprost (USAN/INN)',
#   'Dinoprostone betadex (JAN)',
#   'Carboprost methyl (USAN)',
#   'Rioprostil (USAN/INN)',
#   'Treprostinil (JAN/USAN/INN)',
#   'Tafluprost (JAN/USAN/INN)',
#   'Iloprost tromethamine',
#   'Montelukast (INN)',
#   'Pranlukast (INN)',
#   'Treprostinil monosodium salt',
#   'Unoprostone (INN)'],
#  'map07229': ['Angiotensin II',
#   'CV 2961',
#   'PD 123177',
#   'PD 123319',
#   'Losartan potassium (JP16/USAN)',
#   'Valsartan (JP16/USAN/INN)',
#   'Candesartan (USAN/INN)',
#   'Irbesartan (JAN/USAN/INN)',
#   'Candesartan cilexetil (JP16/USAN)',
#   'Telmisartan (JAN/USAN/INN)',
#   'Olmesartan medoxomil (JAN/USAN)',
#   'Bosentan hydrate (JAN)',
#   'Eprosartan mesylate (USAN)',
#   'Eprosartan (USAN/INN)',
#   'Saralasin acetate (USAN)',
#   'Olmesartan (USAN/INN)',
#   'Ambrisentan (JAN/INN)',
#   'Bosentan (INN)',
#   'Losartan (INN)'],
#  'map07230': ['Thiopental',
#   'Bicuculline',
#   'Picrotoxinin',
#   'Alprazolam (JP16/USP/INN)',
#   'Chlordiazepoxide (JP16/USP/INN)',
#   'Clonazepam (JP16/USP/INN)',
#   'Diazepam (JP16/USP/INN)',
#   'Estazolam (JP16/USAN/INN)',
#   'Flurazepam (JAN/INN)',
#   'Lorazepam (JP16/USP/INN)',
#   'Temazepam (USP/INN)',
#   'Triazolam (JAN/USP/INN)',
#   'Secobarbital (USP/INN)',
#   'Quazepam (JAN/USP/INN)',
#   'Oxazepam (JAN/USP/INN)',
#   'Prazepam (JP16/USAN/INN)',
#   'Primidone (JP16/USP/INN)',
#   'Pentobarbital (USP/INN)',
#   'Pentobarbital sodium (JAN/USP)',
#   'Phenobarbital (JP16/USP/INN)',
#   'Nitrazepam (JP16/USAN/INN)',
#   'Propofol (JAN/USAN/INN)',
#   'Midazolam (JAN/USP/INN)',
#   'Amobarbital (JP16/INN)',
#   'Chlordiazepoxide hydrochloride (JAN/USP)',
#   'Clorazepate dipotassium (JP16/USP)',
#   'Flurazepam hydrochloride (USP)',
#   'Midazolam hydrochloride (USAN)',
#   'Flumazenil (JAN/USP/INN)',
#   'Mephobarbital (JAN/USP)',
#   'Phenobarbital sodium (JAN/USP/INN)',
#   'Zolpidem tartrate (JP16/USAN)',
#   'Thiamylal sodium (JP16)',
#   'Thiopental sodium (JP16/USP/INN)',
#   'Hexobarbital (JAN/INN)',
#   'Flunitrazepam (JP16/USAN/INN)',
#   'Bromazepam (JP16/USAN/INN)',
#   'Tofisopam (JP16/INN)',
#   'Cloxazolam (JP16/INN)',
#   'Oxazolam (JP16/INN)',
#   'Flutoprazepam (JP16/INN)',
#   'Flutazolam (JAN/INN)',
#   'Medazepam (JP16/INN)',
#   'Ethyl loflazepate (JAN/INN)',
#   'Secobarbital sodium (JAN/USP)',
#   'Mexazolam (JAN/INN)',
#   'Clotiazepam (JP16/INN)',
#   'Fludiazepam (JP16/INN)',
#   'Zopiclone (JAN/INN)',
#   'Flurazepam hydrochloride (JP16)',
#   'Etizolam (JP16/INN)',
#   'Rilmazafone hydrochloride hydrate (JAN)',
#   'Nimetazepam (JAN/INN)',
#   'Lormetazepam (JAN/USAN/INN)',
#   'Barbital (JP16/INN)',
#   'Brotizolam (JP16/USAN/INN)',
#   'Haloxazolam (JP16/INN)',
#   'Amobarbital sodium (JAN/USP)',
#   'Pentobarbital calcium (JP16)',
#   'Butobarbital (BAN)',
#   'Eszopiclone (JAN/USAN/INN)',
#   'Clorazepate monopotassium (USAN)',
#   'Fospropofol disodium (USAN)',
#   'Medazepam hydrochloride (USAN)',
#   'Midazolam maleate (USAN)',
#   'Thiamylal',
#   'Pentetrazol (INN)',
#   'Phenobarbital diethylamine',
#   'Rilmazafone (INN)',
#   'Zolpidem (INN)'],
#  'map07231': ['Cocaine (USP)',
#   'Ajmaline (JP16)',
#   'Carbamazepine (JP16/USP/INN)',
#   'Disopyramide (JP16/USAN/INN)',
#   'Lamotrigine (JAN/USAN/INN)',
#   'Lidocaine (JP16/USP/INN)',
#   'Procainamide hydrochloride (JP16/USP)',
#   'Phenytoin (JP16/USP/INN)',
#   'Topiramate (JAN/USAN/INN)',
#   'Zonisamide (JAN/USAN/INN)',
#   'Tetracaine (USP/INN)',
#   'Ethyl aminobenzoate (JP16)',
#   'Propitocaine (JAN)',
#   'Bepridil hydrochloride hydrate (JAN)',
#   'Amiodarone hydrochloride (JP16/USAN)',
#   'Disopyramide phosphate (JAN/USP)',
#   'Flecainide acetate (JP16/USP)',
#   'Mexiletine hydrochloride (JP16/USP)',
#   'Propafenone hydrochloride (JP16/USP)',
#   'Quinidine gluconate (USP)',
#   'Quinidine polygalacturonate',
#   'Dibucaine (USP)',
#   'Mepivacaine hydrochloride (JP16/USP)',
#   'Procaine hydrochloride (JP16/USP)',
#   'Tetracaine hydrochloride (JP16/USP)',
#   'Levobupivacaine hydrochloride (JAN/USAN)',
#   'Aprindine hydrochloride (JP16/USAN)',
#   'Bupivacaine hydrochloride hydrate (JP16)',
#   'Cibenzoline succinate (JP16)',
#   'Ambroxol hydrochloride (JAN)',
#   'Pilsicainide hydrochloride hydrate (JAN)',
#   'Pirmenol hydrochloride hydrate (JAN)',
#   'Lidocaine injection (JP16)',
#   'Tocainide hydrochloride (USP)',
#   'Proparacaine hydrochloride (USP)',
#   'Phenytoin sodium for injection (JP16)',
#   'Cocaine hydrochloride (JP16/USP)',
#   'Dibucaine hydrochloride (JP16/USP)',
#   'Quinidine sulfate hydrate (JP16)',
#   'Dronedarone (INN)',
#   'Amiodarone (USAN/INN)',
#   'Aprindine (USAN/INN)',
#   'Cifenline (USAN)',
#   'Dronedarone hydrochloride (USAN)',
#   'Ropivacaine hydrochloride hydrate (JAN)',
#   'Tocainide (USAN/INN)',
#   'Pirmenol hydrochloride (USAN)',
#   'Ambroxol (INN)',
#   'Bepridil (INN)',
#   'Bupivacaine (USAN/INN)',
#   'Fosphenytoin sodium hydrate (JAN)',
#   'Flecainide (INN)',
#   'Fosphenytoin (INN)',
#   'Levobupivacaine (INN)',
#   'Lidocaine hydrochloride monohydrate',
#   'Mepivacaine (INN)',
#   'Mexiletine (INN)',
#   'Pilsicainide (INN)',
#   'Pirmenol (INN)',
#   'Procainamide (INN)',
#   'Procaine (INN)',
#   'Propafenone (INN)',
#   'Proxymetacaine (INN)',
#   'Quinidine (BAN)',
#   'Quinidine phenylethylbarbiturate',
#   'Ropivacaine (INN)'],
#  'map07232': ['Bretylium',
#   'Pinacidil',
#   'Clofilium',
#   'E-4031',
#   'Azimilide',
#   'Chromanol 293B',
#   'Diazoxide (JAN/USP/INN)',
#   'Glibenclamide (JP16/INN)',
#   'Tolbutamide (JP16/USP/INN)',
#   'Minoxidil (JAN/USP/INN)',
#   'Terfenadine (JAN/USAN/INN)',
#   'Amiodarone hydrochloride (JP16/USAN)',
#   'Bretylium tosylate (USP)',
#   'Dofetilide (JAN/USAN/INN)',
#   'Ibutilide fumarate (USAN)',
#   'Sotalol hydrochloride (JAN/USP)',
#   'Nicorandil (JP16/USAN/INN)',
#   'Nifekalant hydrochloride (JAN)',
#   'Levcromakalim (USAN/INN)',
#   'Dronedarone (INN)',
#   'Amiodarone (USAN/INN)',
#   'Azimilide dihydrochloride (USAN)',
#   'Clofilium phosphate (USAN/INN)',
#   'Dexsotalol hydrochloride (USAN)',
#   'Dronedarone hydrochloride (USAN)',
#   'Sematilide hydrochloride (USAN)',
#   'Pinacidil (USAN)',
#   'Tolbutamide sodium, sterile',
#   'Tedisamil (USAN)',
#   'Tedisamil sesquifumarate (USAN)',
#   'Bunaftine (INN)',
#   'Ibutilide (INN)',
#   'Sotalol (INN)',
#   'Ezogabine (USAN)',
#   'Terikalant (INN)'],
#  'map07233': ['G-Strophanthin (JAN)',
#   'Bumetanide (JP16/USP/INN)',
#   'Chlortalidone (JAN/INN)',
#   'Digitoxin (JP16/USP/INN)',
#   'Digoxin (JP16/USP)',
#   'Etacrynic acid (JP16/INN)',
#   'Furosemide (JP16/USP/INN)',
#   'Hydrochlorothiazide (JP16/USP/INN)',
#   'Indapamide (JP16/USP)',
#   'Lansoprazole (JAN/USP/INN)',
#   'Torasemide (JAN/INN)',
#   'Metolazone (JAN/USP/INN)',
#   'Omeprazole (JP16/USP/INN)',
#   'Quinethazone (JAN/INN)',
#   'Chlorothiazide (JAN/USP/INN)',
#   'Trichlormethiazide (JP16/USP/INN)',
#   'Sodium rabeprazole (JP16)',
#   'Omeprazole sodium (USAN)',
#   'Deslanoside (JP16/USP/INN)',
#   'Benzylhydrochlorothiazide (JAN)',
#   'Azosemide (JAN/USAN/INN)',
#   'Proscillaridin (JAN/USAN/INN)',
#   'Meticrane (JP16/INN)',
#   'Piretanide (JAN/USAN/INN)',
#   'Mefruside (JP16/USAN/INN)',
#   'Tripamide (JAN/USAN/INN)',
#   'Tenatoprazole (JAN/INN)',
#   'Lanatoside C (JP16/INN)',
#   'Esomeprazole magnesium hydrate (JAN)',
#   'Metildigoxin (JP16)',
#   'Pantoprazole Sodium Hydrate (JAN)',
#   'Esomeprazole sodium (USAN)',
#   'Ethacrynate sodium (USP)',
#   'Muzolimine (USAN/INN)',
#   'Omeprazole magnesium (USAN)',
#   'Omeprazole sodium injection (JAN)',
#   'Pantoprazole (USAN/INN)',
#   'Indapamide hydrate',
#   'Acetyldigitoxin (INN)',
#   'Gitoformate (INN)',
#   'Acetyldigoxin',
#   'beta-Acetyldigoxin',
#   'Esomeprazole (INN)',
#   'Sodium furosemide',
#   'Furosemide diolamine',
#   'Rabeprazole (INN)',
#   'Torasemide sodium',
#   'Esomeprazole potassium (USAN)',
#   'Metildigoxin (INN)'],
#  'map07234': ['Cocaine (USP)',
#   'Amoxapine (JP16/USP/INN)',
#   'Fluoxetine (USAN/INN)',
#   'Mazindol (JAN/USP/INN)',
#   'Trimipramine (USAN/INN)',
#   'Amitriptyline hydrochloride (JP16/USP)',
#   'Clomipramine hydrochloride (JP16/USP)',
#   'Desipramine hydrochloride (JAN/USP)',
#   'Imipramine hydrochloride (JP16/USP)',
#   'Nortriptyline hydrochloride (JP16/USP/INN)',
#   'Maprotiline hydrochloride (JP16/USP)',
#   'Trazodone hydrochloride (JAN/USP)',
#   'Venlafaxine hydrochloride (JAN/USAN)',
#   'Citalopram hydrobromide (USAN)',
#   'Fluoxetine hydrochloride (JAN/USP)',
#   'Fluvoxamine maleate (JP16/USAN)',
#   'Sertraline hydrochloride (JAN/USAN)',
#   'Milnacipran hydrochloride (JAN/USAN)',
#   'Duloxetine hydrochloride (JAN/USAN)',
#   'Lofepramine hydrochloride (JAN/USAN)',
#   'Dosulepin hydrochloride (JAN)',
#   'Amphetamine sulfate (USP)',
#   'Dextroamphetamine sulfate (USP)',
#   'Cocaine hydrochloride (JP16/USP)',
#   'Methamphetamine hydrochloride (JP16/USP)',
#   'Paroxetine hydrochloride hydrate (JAN)',
#   'Sertraline (INN)',
#   'Paroxetine (USP/INN)',
#   'Trimipramine maleate (JAN/USAN)',
#   'Maprotiline (USAN)',
#   'Escitalopram oxalate (JAN/USAN)',
#   'Desvenlafaxine succinate hydrate (JAN)',
#   'Reboxetine mesylate (USAN)',
#   'Atomoxetine hydrochloride (JAN/USAN)',
#   'Amfonelic acid (USAN)',
#   'Dextroamphetamine (USAN)',
#   'Nisoxetine (USAN/INN)',
#   'Nomifensine maleate (USAN)',
#   'Paroxetine hydrochloride (USP)',
#   'Paroxetine mesylate (USAN)',
#   'Imipraminoxide (INN)',
#   'Amfetamine (INN)',
#   'Amitriptyline (INN)',
#   'Amitriptylinoxide (INN)',
#   'Atomoxetine (INN)',
#   'Citalopram (USP/INN)',
#   'Citalopram hydrochloride',
#   'Clomipramine (INN)',
#   'Desipramine (INN)',
#   'Desvenlafaxine (INN)',
#   'Dosulepin (INN)',
#   'Duloxetine (INN)',
#   'Escitalopram (INN)',
#   'Fluvoxamine (INN)',
#   'Imipramine (INN)',
#   'Imipramine embonate',
#   'Lofepramine (INN)',
#   'Metamfetamine (INN)',
#   'Milnacipran (INN)',
#   'Nortriptyline (INN)',
#   'Reboxetine (INN)',
#   'Trazodone (INN)',
#   'Venlafaxine (INN)',
#   'Esreboxetine (USAN/INN)',
#   'Esreboxetine succinate (USAN)'],
#  'map07235': ['Phencyclidine',
#   'Dizocilpine',
#   'Ketamine hydrochloride (JP16/USP)',
#   'Amantadine hydrochloride (JP16/USP)',
#   'Dextromethorphan hydrobromide hydrate (JP16)',
#   'Ifenprodil tartrate (JP16)',
#   'Methadone hydrochloride (JAN/USP)',
#   'Besonprodil (USAN)',
#   'Dextromethorphan (USP)',
#   'Dextromethorphan polistirex (USAN)',
#   'Dextrorphan hydrochloride (USAN)',
#   'Dizocilpine maleate (USAN)',
#   'Memantine hydrochloride (JAN/USAN)',
#   'Phencyclidine hydrochloride (USAN)',
#   'Traxoprodil mesylate (USAN)',
#   'Esketamine (INN)',
#   'Amantadine (INN)',
#   'Ifenprodil (INN)',
#   'Ketamine (INN)',
#   'Levomethadone (INN)',
#   'Levomethadone hydrochloride',
#   'Memantine (INN)',
#   'Methadone (BAN)'],
#  'ingenza00001': ['Glycerol', 'Glycerone', 'Glycerone phosphate'],
#  'ingenza00002': ['Glycerone phosphate',
#   'Methylglyoxal',
#   'Hydroxyacetone',
#   'Propane-1,2-diol',
#   'Lactaldehyde'],
#  'ingenza00003': ['Pyruvate',
#   '(S)-2-Acetolactate',
#   '(R)-2,3-Dihydroxy-3-methylbutanoate',
#   '3-Methyl-2-oxobutanoic acid',
#   'Butyl acetate',
#   'Acetyl-CoA'],
#  'ingenza00004': ['3-Methyl-2-oxobutanoic acid',
#   '2-Methylpropanoyl-CoA',
#   '2-Methylprop-2-enoyl-CoA',
#   'Butylmethacrylate\xa0(+ isobutylmethacrylate)',
#   'butylisobutyrate\xa0\xa0 (+ isobutylisobutyrate)'],
#  'ingenza00005': ['(S)-3-Hydroxyisobutyryl-CoA',
#   '(S)-3-Hydroxyisobutyrate',
#   '(S)-Methylmalonate semialdehyde',
#   '(S)-Methylmalonyl-CoA',
#   '(R)-Methylmalonyl-CoA',
#   'Succinyl-CoA',
#   'Methylmalonate'],
#  'ingenza00006': ['alpha-Isopropylmalate',
#   '(2R,3S)-3-Isopropylmalate',
#   '4-Methyl-2-oxopentanoate',
#   'L-Leucine'],
#  'ingenza00007': ['L-Threonine',
#   '2-Oxobutanoate',
#   '(S)-2-Aceto-2-hydroxybutanoate',
#   '(R)-2,3-Dihydroxy-3-methylpentanoate',
#   '(S)-3-Methyl-2-oxopentanoic acid',
#   'L-Isoleucine'],
#  'ingenza00008': ['Isobutanal (Isobutyraldehyde)',
#   '2-Methylpropanoate',
#   'methacrylic acid'],
#  'ingenza00009': ['2-Dehydropantoate',
#   'L-Aspartate',
#   '(R)-Pantoate',
#   'beta-Alanine',
#   'Pantothenate']}

# %%
cmpd_formula_dict
# Out:
# {'H2O': 'H2O',
#  'ATP': 'C10H16N5O13P3',
#  'NAD+': 'C21H28N7O14P2',
#  'NADH': 'C21H29N7O14P2',
#  'NADPH': 'C21H30N7O17P3',
#  'NADP+': 'C21H29N7O17P3',
#  'Oxygen': 'O2',
#  'ADP': 'C10H15N5O10P2',
#  'Orthophosphate': 'H3PO4',
#  'CoA': 'C21H36N7O16P3S',
#  'CO2': 'CO2',
#  'Diphosphate': 'H4P2O7',
#  'Ammonia': 'NH3',
#  'UDP': 'C9H14N2O12P2',
#  'FAD': 'C27H33N9O15P2',
#  'Pyridoxal phosphate': 'C8H10NO6P',
#  'S-Adenosyl-L-methionine': 'C15H22N6O5S',
#  'AMP': 'C10H14N5O7P',
#  'S-Adenosyl-L-homocysteine': 'C14H20N6O5S',
#  'Pyruvate': 'C3H4O3',
#  'Iron': 'Fe',
#  'Acetyl-CoA': 'C23H38N7O17P3S',
#  'L-Glutamate': 'C5H9NO4',
#  '2-Oxoglutarate': 'C5H6O5',
#  'Hydrogen peroxide': 'H2O2',
#  'UDP-glucose': 'C15H24N2O17P2',
#  'D-Glucose': 'C6H12O6',
#  'Heme': 'C34H32FeN4O4',
#  'Acetate': 'C2H4O2',
#  'Manganese': 'Mn',
#  'GDP': 'C10H15N5O11P2',
#  'Oxaloacetate': 'C4H4O5',
#  'Glycine': 'C2H5NO2',
#  'Zinc cation': 'Zn',
#  'L-Alanine': 'C3H7NO2',
#  'Succinate': 'C4H6O4',
#  'UDP-N-acetyl-alpha-D-glucosamine': 'C17H27N3O17P2',
#  'GTP': 'C10H16N5O14P3',
#  'L-Lysine': 'C6H14N2O2',
#  'Glyoxylate': 'C2H2O3',
#  'L-Aspartate': 'C4H7NO4',
#  'Glutathione': 'C10H17N3O6S',
#  'UDP-alpha-D-galactose': 'C15H24N2O17P2',
#  "3'-Phosphoadenylyl sulfate": 'C10H15N5O13P2S',
#  "Adenosine 3',5'-bisphosphate": 'C10H15N5O10P2',
#  'CMP': 'C9H14N3O8P',
#  'Formate': 'CH2O2',
#  'Sulfate': 'H2SO4',
#  'FMN': 'C17H21N4O9P',
#  'L-Arginine': 'C6H14N4O2',
#  'CTP': 'C9H16N3O14P3',
#  'L-Glutamine': 'C5H10N2O3',
#  'L-Serine': 'C3H7NO3',
#  'Formaldehyde': 'CH2O',
#  'Thiamin diphosphate': 'C12H19N4O7P2S',
#  'Copper': 'Cu',
#  'Ascorbate': 'C6H8O6',
#  'L-Methionine': 'C5H11NO2S',
#  'Phosphoenolpyruvate': 'C3H5O6P',
#  'UTP': 'C9H15N2O15P3',
#  'Calcium cation': 'Ca',
#  'L-Ornithine': 'C5H12N2O2',
#  'L-Tryptophan': 'C11H12N2O2',
#  'L-Phenylalanine': 'C9H11NO2',
#  'H+': 'H',
#  'ITP': 'C10H15N4O14P3',
#  'L-Tyrosine': 'C9H11NO3',
#  'Malonyl-CoA': 'C24H38N7O19P3S',
#  'Acetaldehyde': 'C2H4O',
#  'D-Fructose 6-phosphate': 'C6H13O9P',
#  'Urea': 'CH4N2O',
#  'Sulfur': 'S',
#  'Nitrite': 'HNO2',
#  'Sucrose': 'C12H22O11',
#  'Catechol': 'C6H6O2',
#  'Succinyl-CoA': 'C25H40N7O19P3S',
#  'D-Glucose 6-phosphate': 'C6H13O9P',
#  'sn-Glycerol 3-phosphate': 'C3H9O6P',
#  'Sulfite': 'H2SO3',
#  'D-Fructose': 'C6H12O6',
#  'GDP-mannose': 'C16H25N5O16P2',
#  'L-Cysteine': 'C3H7NO2S',
#  'beta-Alanine': 'C3H7NO2',
#  'Propanoyl-CoA': 'C24H40N7O17P3S',
#  'Tetrahydrofolate': 'C19H23N7O6',
#  '2,6-Dichloroindophenol': 'C12H7Cl2NO2',
#  'D-Glucose 1-phosphate': 'C6H13O9P',
#  'IDP': 'C10H14N4O11P2',
#  'UMP': 'C9H13N2O9P',
#  'Uracil': 'C4H4N2O2',
#  'Anthranilate': 'C7H7NO2',
#  '2-Oxobutanoate': 'C4H6O3',
#  'Glycerone phosphate': 'C3H7O6P',
#  'CDP': 'C9H15N3O11P2',
#  'PQQ': 'C14H6N2O8',
#  'Choline': 'C5H14NO',
#  'Glycerol': 'C3H8O3',
#  'D-Ribose 5-phosphate': 'C5H11O8P',
#  'D-Glyceraldehyde 3-phosphate': 'C3H7O6P',
#  '5-Phospho-alpha-D-ribose 1-diphosphate': 'C5H13O14P3',
#  'Biotin': 'C10H16N2O3S',
#  'D-Ribose': 'C5H10O5',
#  'Fumarate': 'C4H4O4',
#  'L-Leucine': 'C6H13NO2',
#  'D-Galactose': 'C6H12O6',
#  'Glutathione disulfide': 'C20H32N6O12S2',
#  'CMP-N-acetylneuraminate': 'C20H31N4O16P',
#  'Isopentenyl diphosphate': 'C5H12O7P2',
#  'IMP': 'C10H13N4O8P',
#  'dATP': 'C10H16N5O12P3',
#  'Methanol': 'CH4O',
#  'D-Alanine': 'C3H7NO2',
#  'Putrescine': 'C4H12N2',
#  'L-Histidine': 'C6H9N3O2',
#  'Butanoyl-CoA': 'C25H42N7O17P3S',
#  'myo-Inositol': 'C6H12O6',
#  'N-Acetyl-D-glucosamine': 'C8H15NO6',
#  '3-Methyl-2-oxobutanoic acid': 'C5H8O3',
#  '5,10-Methylenetetrahydrofolate': 'C20H23N7O6',
#  'GMP': 'C10H14N5O8P',
#  'Phenol': 'C6H6O',
#  'Adenine': 'C5H5N5',
#  'L-Proline': 'C5H9NO2',
#  '(S)-Malate': 'C4H6O5',
#  'Molybdenum': 'Mo',
#  'L-Asparagine': 'C4H8N2O3',
#  'Nicotinamide': 'C6H6N2O',
#  'Palmitoyl-CoA': 'C37H66N7O17P3S',
#  'L-Homocysteine': 'C4H9NO2S',
#  '4-Hydroxybenzoate': 'C7H6O3',
#  'Citrate': 'C6H8O7',
#  'D-Mannose': 'C6H12O6',
#  'Glycolate': 'C2H4O3',
#  'Propanoate': 'C3H6O2',
#  'Acetoacetate': 'C4H6O3',
#  'Phenylpyruvate': 'C9H8O3',
#  'UDP-glucuronate': 'C15H22N2O18P2',
#  'Hydroxypyruvate': 'C3H4O4',
#  'Carbamoyl phosphate': 'CH4NO5P',
#  "5'-Methylthioadenosine": 'C11H15N5O3S',
#  'Cobalt ion': 'Co',
#  'Cyanide': 'CN',
#  'Thymine': 'C5H6N2O2',
#  'Agmatine': 'C5H14N4',
#  'Benzoate': 'C7H6O2',
#  'D-Xylose': 'C5H10O5',
#  'Glycogen': 'C24H42O21',
#  'L-Valine': 'C5H11NO2',
#  'Glycerone': 'C3H6O3',
#  'Cellobiose': 'C12H22O11',
#  '(S)-Lactate': 'C3H6O3',
#  'Cholesterol': 'C27H46O',
#  'L-Threonine': 'C4H9NO3',
#  'Ethanolamine': 'C2H7NO',
#  'UDP-D-xylose': 'C14H22N2O16P2',
#  'D-Glucuronate': 'C6H10O7',
#  'Hydroxylamine': 'NH3O',
#  'Aromatic aldehyde': 'C7H6O',
#  'Cobamide coenzyme': 'C72H100CoN18O17P',
#  '2,3-Dihydroxybenzoate': 'C7H6O4',
#  '3-Phospho-D-glycerate': 'C3H7O7P',
#  'D-Glucono-1,5-lactone': 'C6H10O6',
#  'D-Ribulose 5-phosphate': 'C5H11O8P',
#  'Isoflurophate': 'C6H14FO3P',
#  'UDP-N-acetyl-D-galactosamine': 'C17H27N3O17P2',
#  '2-Dehydro-3-deoxy-D-gluconate': 'C6H10O6',
#  'dADP': 'C10H15N5O9P2',
#  'Acetone': 'C3H6O',
#  'Maltose': 'C12H22O11',
#  'Oxalate': 'C2H2O4',
#  'Cobamide': 'C53H81CoN11O15P',
#  'Adenosine': 'C10H13N5O4',
#  'Sarcosine': 'C3H7NO2',
#  'Thymidine': 'C10H14N2O5',
#  'D-Arabinose': 'C5H10O5',
#  'D-Glutamate': 'C5H9NO4',
#  'Methylamine': 'CH5N',
#  'Arachidonate': 'C20H32O2',
#  'beta-D-Glucose': 'C6H12O6',
#  '3-Oxopropanoate': 'C3H4O3',
#  'p-Coumaroyl-CoA': 'C30H42N7O18P3S',
#  'Adenylyl sulfate': 'C10H14N5O10PS',
#  'Acetyl phosphate': 'C2H5O5P',
#  '3,4-Dihydroxybenzoate': 'C7H6O4',
#  'D-Xylulose 5-phosphate': 'C5H11O8P',
#  'Succinate semialdehyde': 'C4H6O3',
#  '4-Methyl-2-oxopentanoate': 'C6H10O3',
#  '10-Formyltetrahydrofolate': 'C20H23N7O7',
#  'Dimethylallyl diphosphate': 'C5H12O7P2',
#  '3-Phospho-D-glyceroyl phosphate': 'C3H8O10P2',
#  'CO': 'CO',
#  'Potassium cation': 'K',
#  'dCMP': 'C9H14N3O7P',
#  'Guanine': 'C5H5N5O',
#  'Lactose': 'C12H22O11',
#  'Nitrate': 'HNO3',
#  'Taurine': 'C2H7NO3S',
#  'Butanoic acid': 'C4H8O2',
#  'L-Sorbose': 'C6H12O6',
#  'Lipoamide': 'C8H15NOS2',
#  'Hexadecanoic acid': 'C16H32O2',
#  'Pyridoxal': 'C8H9NO3',
#  'Chorismate': 'C10H10O6',
#  'Isomaltose': 'C12H22O11',
#  'Nicotinate': 'C6H5NO2',
#  'Prephenate': 'C10H10O6',
#  'Riboflavin': 'C17H20N4O6',
#  '(R)-Lactate': 'C3H6O3',
#  'D-Gluconic acid': 'C6H12O7',
#  'D-Glycerate': 'C3H6O4',
#  'L-Arabinose': 'C5H10O5',
#  'Benzaldehyde': 'C7H6O',
#  'Hypoxanthine': 'C5H4N4O',
#  'L-Homoserine': 'C4H9NO3',
#  'Dithiothreitol': 'C4H10O2S2',
#  'Glycolaldehyde': 'C2H4O2',
#  'alpha-D-Glucose': 'C6H12O6',
#  'Dihydrobiopterin': 'C9H13N5O3',
#  'N-Acetylneuraminate': 'C11H19NO9',
#  'Tetrahydrobiopterin': 'C9H15N5O3',
#  '5-Dehydro-D-fructose': 'C6H10O6',
#  'D-Mannose 6-phosphate': 'C6H13O9P',
#  'D-Erythrose 4-phosphate': 'C4H9O7P',
#  'Androstenedione': 'C19H26O2',
#  'Hydrogen': 'H2',
#  'Hydrogen sulfide': 'H2S',
#  'EDTA': 'C10H16N2O8',
#  'dGTP': 'C10H16N5O13P3',
#  'HCO3-': 'HCO3',
#  'Nickel': 'Ni',
#  'Aniline': 'C6H7N',
#  'Inosine': 'C10H12N4O5',
#  'Orotate': 'C5H4N2O4',
#  'Quinate': 'C7H12O6',
#  'Uridine': 'C9H12N2O6',
#  'Creatine': 'C4H9N3O2',
#  'ADP-ribose': 'C15H23N5O14P2',
#  'DL-Glutamate': 'C5H9NO4',
#  'Glutamine': 'C5H10N2O3',
#  'Magnesium cation': 'Mg',
#  'Bradykinin': 'C50H73N15O11',
#  'CDP-choline': 'C14H26N4O11P2',
#  'Canavanine': 'C5H12N4O3',
#  'D-Ribulose': 'C5H10O5',
#  'D-Xylulose': 'C5H10O5',
#  'Isocitrate': 'C6H8O7',
#  'L-Xylulose': 'C5H10O5',
#  'Oxalyl-CoA': 'C23H36N7O19P3S',
#  'Pyridoxine': 'C8H11NO3',
#  'Spermidine': 'C7H19N3',
#  'Amylopectin': 'C30H52O26',
#  'L-Carnitine': 'C7H15NO3',
#  'Sphingosine': 'C18H37NO2',
#  'Thiosulfate': 'HS2O3',
#  '2-Oxoadipate': 'C6H8O5',
#  'Caffeoyl-CoA': 'C30H42N7O19P3S',
#  'Ferricyanide': 'C6FeN6',
#  'GDP-L-fucose': 'C16H25N5O15P2',
#  'L-Citrulline': 'C6H13N3O3',
#  'L-Kynurenine': 'C10H12N2O3',
#  'D-Glucosamine': 'C6H13NO5',
#  'Deoxyguanosine': 'C10H13N5O4',
#  'Indolepyruvate': 'C11H9NO3',
#  'Acetoacetyl-CoA': 'C25H40N7O18P3S',
#  'D-Galacturonate': 'C6H10O7',
#  '4-Aminobutanoate': 'C4H9NO2',
#  '(S)-Dihydroorotate': 'C5H6N2O4',
#  'Geranyl diphosphate': 'C10H20O7P2',
#  '6-Phospho-D-gluconate': 'C6H13O10P',
#  'Ethanolamine phosphate': 'C2H8NO4P',
#  'all-trans-Undecaprenyl phosphate': 'C55H91O4P',
#  '2-Methyl-3-oxopropanoate': 'C4H6O3',
#  'D-Glucosamine 6-phosphate': 'C6H14NO8P',
#  'Geranylgeranyl diphosphate': 'C20H36O7P2',
#  'D-Fructose 1,6-bisphosphate': 'C6H14O12P2',
#  '3,4-Dihydroxy-L-phenylalanine': 'C9H11NO4',
#  '(S)-3-Hydroxy-3-methylglutaryl-CoA': 'C27H44N7O20P3S',
#  'N-Acetyl-D-glucosamine 6-phosphate': 'C8H16NO9P',
#  'dAMP': 'C10H14N5O6P',
#  'dGDP': 'C10H15N5O10P2',
#  'dGMP': 'C10H14N5O7P',
#  'dTDP': 'C10H16N2O11P2',
#  'dTMP': 'C10H15N2O8P',
#  'dUMP': 'C9H13N2O8P',
#  'Urate': 'C5H4N4O3',
#  'Sterol': 'C17H28O',
#  'Zeatin': 'C10H13N5O',
#  'Retinal': 'C20H28O',
#  'Thiamine': 'C12H17N4OS',
#  'Xylitol': 'C5H12O5',
#  'Cytosine': 'C4H5N3O',
#  'Malonate': 'C3H4O4',
#  'Xanthine': 'C5H4N4O2',
#  'Carnosine': 'C9H14N4O3',
#  'Guanosine': 'C10H13N5O5',
#  'Histamine': 'C5H9N3',
#  'Quercetin': 'C15H10O7',
#  'Mannitol': 'C6H14O6',
#  'GDP-glucose': 'C16H25N5O16P2',
#  'Pyrimidine': 'C4H4N2',
#  'Tobramycin': 'C18H37N5O9',
#  'Tryptamine': 'C10H12N2',
#  '(-)-Menthol': 'C10H20O',
#  'D-Aspartate': 'C4H7NO4',
#  'Feruloyl-CoA': 'C31H44N7O19P3S',
#  'L-Isoleucine': 'C6H13NO2',
#  'L-Pipecolate': 'C6H11NO2',
#  'Methanethiol': 'CH4S',
#  'Progesterone': 'C21H30O2',
#  'Sinapoyl-CoA': 'C32H46N7O20P3S',
#  'Stearoyl-CoA': 'C39H70N7O17P3S',
#  'Streptomycin': 'C21H39N7O12',
#  'Cyclohexanone': 'C6H10O',
#  'Dihydrofolate': 'C19H21N7O6',
#  'cis-Aconitate': 'C6H6O6',
#  '(R)-Mevalonate': 'C6H12O4',
#  'trans-Cinnamate': 'C9H8O2',
#  '(S)-Lactaldehyde': 'C3H6O2',
#  'Prostaglandin H2': 'C20H32O5',
#  '5,6-Dihydrouracil': 'C4H6N2O2',
#  '5-Aminolevulinate': 'C5H9NO3',
#  '5-Aminopentanoate': 'C5H11NO2',
#  '2,5-Dioxopentanoate': 'C5H6O4',
#  'N-Carbamoylputrescine': 'C5H13N3O',
#  'N-Acetylornithine': 'C7H14N2O3',
#  'N-Carbamoyl-L-aspartate': 'C5H8N2O5',
#  'N-Formimino-L-glutamate': 'C6H10N2O4',
#  '5-Methyltetrahydrofolate': 'C20H25N7O6',
#  'L-Aspartate 4-semialdehyde': 'C4H7NO3',
#  '5,10-Methenyltetrahydrofolate': 'C20H22N7O6',
#  'alpha-D-Galactose 1-phosphate': 'C6H13O9P',
#  'Sedoheptulose 1,7-bisphosphate': 'C7H16O13P2',
#  'trans,trans-Farnesyl diphosphate': 'C15H28O7P2',
#  'N6-(L-1,3-Dicarboxypropyl)-L-lysine': 'C11H20N2O6',
#  '(S)-2,3,4,5-Tetrahydropyridine-2-carboxylate': 'C6H9NO2',
#  '(1R,2S)-1-Hydroxypropane-1,2,3-tricarboxylate': 'C6H8O7',
#  'Nicotinamide D-ribonucleotide': 'C11H15N2O8P',
#  'dCTP': 'C9H16N3O13P3',
#  'dTTP': 'C10H17N2O14P3',
#  'dUTP': 'C9H15N2O14P3',
#  'Indole': 'C8H7N',
#  'Acetoin': 'C4H8O2',
#  'Estrone': 'C18H22O2',
#  'Ethanol': 'C2H6O',
#  'p-Benzoquinone': 'C6H4O2',
#  'Retinol': 'C20H30O',
#  'Ribitol': 'C5H12O5',
#  'Cytidine': 'C9H13N3O5',
#  'D-Lyxose': 'C5H10O5',
#  'Ecdysone': 'C27H44O6',
#  'Lichenin': 'C6H10O5',
#  'Propanal': 'C3H6O',
#  'Pyrazole': 'C3H4N2',
#  'Sinapate': 'C11H12O5',
#  'Tyramine': 'C8H11NO',
#  'Bilirubin': 'C33H36N4O6',
#  'Carnitine': 'C7H16NO3',
#  'Formamide': 'CH3NO',
#  'Glutarate': 'C5H8O4',
#  'Itaconate': 'C5H6O4',
#  'L-Cystine': 'C6H12N2O4S2',
#  'Raffinose': 'C18H32O16',
#  'Shikimate': 'C7H10O5',
#  'Sisomicin': 'C19H37N5O7',
#  'Sulochrin': 'C17H16O7',
#  '(R)-Malate': 'C4H6O5',
#  'ADP-glucose': 'C16H25N5O15P2',
#  'Allantoate': 'C4H8N4O4',
#  'Biliverdin': 'C33H34N4O6',
#  'CDP-glucose': 'C15H25N3O16P2',
#  'D-Xylonate': 'C5H10O6',
#  'Erythritol': 'C4H10O4',
#  'Folate': 'C19H19N7O6',
#  'L-Cysteate': 'C3H7NO5S',
#  'L-Rhamnose': 'C6H12O5',
#  'L-Ribulose': 'C5H10O5',
#  'Naringenin': 'C15H12O5',
#  'Oleoyl-CoA': 'C39H68N7O17P3S',
#  'Acrylic acid': 'C3H4O2',
#  'S-Benzoate coenzyme A': 'C28H40N7O17P3S',
#  'CDP-glycerol': 'C12H21N3O13P2',
#  'D-Mannonate': 'C6H12O7',
#  'D-Ornithine': 'C5H12N2O2',
#  'Hexadecanal': 'C16H32O',
#  'Hypotaurine': 'C2H7NO2S',
#  '(-)-Limonene': 'C10H16',
#  '(R)-Pantoate': 'C6H12O4',
#  'Androsterone': 'C19H30O2',
#  'D-Tryptophan': 'C11H12N2O2',
#  'Deoxyuridine': 'C9H12N2O5',
#  'Glutaryl-CoA': 'C26H42N7O19P3S',
#  'Glycopeptide': 'C36H64N8O17',
#  'Hydroquinone': 'C6H6O2',
#  'Itaconyl-CoA': 'C26H40N7O19P3S',
#  'L-Arabitol': 'C5H12O5',
#  'Nitric oxide': 'NO',
#  'Pyridoxamine': 'C8H12N2O2',
#  'Testosterone': 'C19H28O2',
#  'Triphosphate': 'H5P3O10',
#  'Aromatic acid': 'C7H6O2',
#  'Cinnamoyl-CoA': 'C30H42N7O17P3S',
#  'Cob(II)alamin': 'C62H88CoN13O14P',
#  'Cystathionine': 'C7H14N2O4S',
#  'Dimethylamine': 'C2H7N',
#  'Homogentisate': 'C8H8O4',
#  'L-Arabinonate': 'C5H10O6',
#  'Methylglyoxal': 'C3H4O2',
#  'L-Noradrenaline': 'C8H11NO3',
#  'Phenyl acetate': 'C8H8O2',
#  'meso-Tartaric acid': 'C4H6O6',
#  '(+)-Neomenthol': 'C10H20O',
#  '4-Aminobutyraldehyde': 'C4H9NO',
#  'Benzyl alcohol': 'C7H8O',
#  'Cyclopentanone': 'C5H8O',
#  'D-Tagaturonate': 'C6H10O7',
#  'Deoxyadenosine': 'C10H13N5O3',
#  'Mandelonitrile': 'C8H7NO',
#  'Phosphoramidon': 'C23H34N3O10P',
#  'Trimethylamine': 'C3H9N',
#  '(3S)-Citryl-CoA': 'C27H42N7O22P3S',
#  '4-Aminobenzoate': 'C7H7NO2',
#  'CDP-ethanolamine': 'C11H20N4O11P2',
#  'Cyclohexylamine': 'C6H13N',
#  "3',5'-Cyclic AMP": 'C10H12N5O6P',
#  'Betaine aldehyde': 'C5H12NO',
#  'D-Glyceraldehyde': 'C3H6O3',
#  'Dihydrolipoamide': 'C8H17NOS2',
#  'Dimethyl sulfide': 'C2H6S',
#  'Guanidinoacetate': 'C3H7N3O2',
#  'Phenylacetyl-CoA': 'C29H42N7O17P3S',
#  'Propane-1,2-diol': 'C3H8O2',
#  'Prostaglandin E2': 'C20H32O5',
#  '2-Deoxy-D-glucose': 'C6H12O5',
#  '3-Hydroxybenzoate': 'C7H6O3',
#  'Choline phosphate': 'C5H15NO4P',
#  'Coniferyl alcohol': 'C10H12O3',
#  'Sulfoacetaldehyde': 'C2H4O4S',
#  '2-Hydroxy-2,4-pentadienoate': 'C5H6O3',
#  '3-Phospho-DL-glycerate': 'C3H7O7P',
#  'Cholest-4-en-3-one': 'C27H44O',
#  'Phenylacetaldehyde': 'C8H8O',
#  '(-)-Ureidoglycolate': 'C3H6N2O4',
#  '1,10-Phenanthroline': 'C12H8N2',
#  '3-Sulfino-L-alanine': 'C3H7NO4S',
#  'N-Acetyllactosamine': 'C14H25NO11',
#  'N1-Acetylspermidine': 'C9H21N3O',
#  'Quercetin 3-sulfate': 'C15H10O10S',
#  'UDP-D-galacturonate': 'C15H22N2O18P2',
#  '3-Dehydro-L-gulonate': 'C6H10O7',
#  '3-Oxo-delta4-steroid': 'C19H28O',
#  'alpha-D-Ribose 1-phosphate': 'C5H11O8P',
#  'sn-Glycerol 1-phosphate': 'C3H9O6P',
#  'N-Acetyl-L-glutamate': 'C7H11NO5',
#  'Pyridoxine phosphate': 'C8H12NO6P',
#  '2,5-Dihydroxybenzoate': 'C7H6O4',
#  '2-Methylpropanoyl-CoA': 'C25H42N7O17P3S',
#  '2-Phospho-D-glycerate': 'C3H7O7P',
#  '3-Hydroxyanthranilate': 'C7H7NO3',
#  '4-Hydroxybenzaldehyde': 'C7H6O2',
#  'D-Mannose 1-phosphate': 'C6H13O9P',
#  'Indole-3-acetaldehyde': 'C10H9NO',
#  'Prostaglandin F2alpha': 'C20H34O5',
#  '4-Hydroxyphenylacetate': 'C8H8O3',
#  '5-Hydroxy-L-tryptophan': 'C11H12N2O3',
#  'D-Mannitol 1-phosphate': 'C6H15O9P',
#  'N-Acetyl-D-mannosamine': 'C8H15NO6',
#  'Pyridoxamine phosphate': 'C8H13N2O5P',
#  '4-Hydroxymandelonitrile': 'C8H7NO2',
#  '4-Methylene-L-glutamate': 'C6H9NO4',
#  'D-Arabinono-1,4-lactone': 'C5H8O5',
#  "Xanthosine 5'-phosphate": 'C10H13N4O9P',
#  '2-Aceto-2-hydroxybutanoate': 'C6H10O4',
#  'DL-Glyceraldehyde 3-phosphate': 'C3H7O6P',
#  'beta-D-Glucose 1-phosphate': 'C6H13O9P',
#  '5-Formiminotetrahydrofolate': 'C20H24N8O6',
#  'beta-D-Fructose 2,6-bisphosphate': 'C6H14O12P2',
#  'LL-2,6-Diaminoheptanedioate': 'C7H14N2O4',
#  'alpha-D-Glucose 6-phosphate': 'C6H13O9P',
#  'gamma-L-Glutamyl-L-cysteine': 'C8H14N2O5S',
#  'sn-Glycero-3-phosphocholine': 'C8H21NO6P',
#  '(S)-3-Methyl-2-oxopentanoic acid': 'C6H10O3',
#  '2-Deoxy-D-ribose 1-phosphate': 'C5H11O7P',
#  '2-Deoxy-D-ribose 5-phosphate': 'C5H11O7P',
#  '5alpha-Androstane-3,17-dione': 'C19H28O2',
#  '5-Dehydro-4-deoxy-D-glucarate': 'C6H8O7',
#  'meso-2,6-Diaminoheptanedioate': 'C7H14N2O4',
#  '2-Hydroxymuconate semialdehyde': 'C6H6O4',
#  '(S)-Methylmalonyl-CoA': 'C25H40N7O19P3S',
#  '2-Dehydro-3-deoxy-L-arabinonate': 'C5H8O5',
#  'dTDP-4-dehydro-beta-L-rhamnose': 'C16H24N2O15P2',
#  "alpha,alpha'-Trehalose 6-phosphate": 'C12H23O14P',
#  '2,4,6/3,5-Pentahydroxycyclohexanone': 'C6H10O6',
#  'UDP-N-acetylmuramoyl-L-alanyl-D-glutamate': 'C28H43N5O23P2',
#  'Cholic acid': 'C24H40O5',
#  'Prostaglandin D2': 'C20H32O5',
#  'Nitrogen': 'N2',
#  'Cl-': 'Cl',
#  'XTP': 'C10H15N4O15P3',
#  'O2.-': 'O2',
#  'dCDP': 'C9H15N3O10P2',
#  'Iodide': 'I',
#  'Malate': 'C4H6O5',
#  '(9Z)-Octadecenoic acid': 'C18H34O2',
#  'Panose': 'C18H32O16',
#  'Pterin': 'C6H5N5O',
#  'DL-Serine': 'C3H7NO3',
#  'Betaine': 'C5H11NO2',
#  'Lipoate': 'C8H14O2S2',
#  'Orcinol': 'C7H8O2',
#  'Tropine': 'C8H15NO',
#  'Ubenimex': 'C16H24N2O4',
#  'Cortisol': 'C21H30O5',
#  'Cysteine': 'C3H7NO2S',
#  'D-Aldose': 'C6H12O6',
#  'D-Hexose': 'C6H12O6',
#  'D-Lysine': 'C6H14N2O2',
#  'D-Serine': 'C3H7NO3',
#  'Diacetyl': 'C4H6O2',
#  'Fluoride': 'F',
#  'Macrocin': 'C45H75NO17',
#  'Nicotine': 'C10H14N2',
#  'Oxytocin': 'C43H66N12O12S2',
#  'Pyridine': 'C5H5N',
#  'Siroheme': 'C42H44FeN4O16',
#  'Spermine': 'C10H26N4',
#  'Squalene': 'C30H50',
#  'Tungsten': 'W',
#  '4-Hydroxy-3-methoxy-benzaldehyde': 'C8H8O3',
#  '1-Octanol': 'C8H18O',
#  'Berberine': 'C20H18NO4',
#  'Bergaptol': 'C11H6O4',
#  'Coniferin': 'C16H22O8',
#  'Cortisone': 'C21H28O5',
#  'D-Proline': 'C5H9NO2',
#  'D-Sorbose': 'C6H12O6',
#  'Digitonin': 'C56H92O29',
#  'Flavanone': 'C15H12O2',
#  'Histidine': 'C6H9N3O2',
#  'L-Idonate': 'C6H12O7',
#  'Mevaldate': 'C6H10O4',
#  'Pepstatin': 'C34H63N5O9',
#  'Phloretin': 'C15H14O5',
#  'Retinoate': 'C20H28O2',
#  'Scytalone': 'C10H10O4',
#  'Serotonin': 'C10H12N2O',
#  'Tropinone': 'C8H13NO',
#  'Urocanate': 'C6H6N2O2',
#  '(-)-Vestitone': 'C16H14O5',
#  'L-Adrenaline': 'C9H13NO3',
#  'CDP-ribitol': 'C14H25N3O15P2',
#  'Creatinine': 'C4H7N3O',
#  'D-Arginine': 'C6H14N4O2',
#  'D-Cysteine': 'C3H7NO2S',
#  'D-Sorbitol': 'C6H14O6',
#  'D-Tagatose': 'C6H12O6',
#  'Dicumarol': 'C19H12O6',
#  'Ethylamine': 'C2H7N',
#  'Formyl-CoA': 'C22H36N7O17P3S',
#  'Isoflavone': 'C15H10O2',
#  'L-Gulonate': 'C6H12O7',
#  'Oxalureate': 'C3H4N2O4',
#  'Pentanoate': 'C5H10O2',
#  'Propynoate': 'C3H2O2',
#  'Salicylate': 'C7H6O3',
#  'Tryptophan': 'C11H12N2O2',
#  '(+)-Camphor': 'C10H16O',
#  '(-)-Camphor': 'C10H16O',
#  '(R)-Acetoin': 'C4H8O2',
#  '4-Coumarate': 'C9H8O3',
#  'Barbiturate': 'C4H4N2O3',
#  'Biochanin A': 'C16H12O5',
#  'Citramalate': 'C5H8O5',
#  'D-Altronate': 'C6H12O7',
#  'D-Glucarate': 'C6H10O8',
#  'D-Glutamine': 'C5H10N2O3',
#  'D-Threonine': 'C4H9NO3',
#  'Dopaquinone': 'C9H9NO4',
#  '1-Hexadecanol': 'C16H34O',
#  'Kanamycin B': 'C18H37N5O10',
#  'L-Arogenate': 'C10H13NO5',
#  'Lactoyl-CoA': 'C24H40N7O18P3S',
#  'Naphthalene': 'C10H8',
#  'Oxomalonate': 'C3H2O5',
#  'Pantetheine': 'C11H22N2O4S',
#  'Paromomycin': 'C23H45N5O14',
#  'Sepiapterin': 'C9H11N5O3',
#  'Sphinganine': 'C18H39NO2',
#  'Streptidine': 'C8H18N6O4',
#  'Xanthotoxol': 'C11H6O4',
#  'dTDP-glucose': 'C16H26N2O16P2',
#  '(-)-Menthone': 'C10H18O',
#  'Prunasin': 'C14H17NO6',
#  '2-Furoyl-CoA': 'C26H38N7O18P3S',
#  '3-Oxoadipate': 'C6H8O5',
#  '4-Pyridoxate': 'C8H9NO4',
#  '6-Oxocineole': 'C10H16O2',
#  'Ethyl acetate': 'C4H8O2',
#  'Aryl sulfate': 'C6H6O4S',
#  'Chlorogenate': 'C16H18O9',
#  'Cob(I)alamin': 'C62H89CoN13O14P',
#  'Cyclohexanol': 'C6H12O',
#  'D-Methionine': 'C5H11NO2S',
#  'Deamino-NAD+': 'C21H27N6O15P2',
#  'Formononetin': 'C16H12O4',
#  'Gibberellin A1': 'C19H24O6',
#  'L-Histidinol': 'C6H11N3O',
#  'L-Rhamnulose': 'C6H12O5',
#  'Methanofuran': 'C34H44N4O15',
#  'Pantothenate': 'C9H17NO5',
#  '2-Oxooctadecanoic acid': 'C18H34O3',
#  '4-Nitrophenol': 'C6H5NO3',
#  'Aminomalonate': 'C3H5NO4',
#  'Angiotensin I': 'C62H89N17O14',
#  'Coenzyme F420': 'C29H36N5O18P',
#  'Crotonoyl-CoA': 'C25H40N7O17P3S',
#  'D-Arabinonate': 'C5H10O6',
#  'D-Galactarate': 'C6H10O8',
#  'D-Galactonate': 'C6H12O7',
#  'Deoxycytidine': 'C9H13N3O4',
#  'Dephospho-CoA': 'C21H35N7O13P2S',
#  'Galactomannan': 'C18H32O16',
#  'Homocarnosine': 'C10H16N4O3',
#  'Isochorismate': 'C10H10O6',
#  'Nitrous oxide': 'N2O',
#  'Pentanoyl-CoA': 'C26H44N7O17P3S',
#  'Pregnan-21-al': 'C21H34O',
#  'Pregnan-21-ol': 'C21H36O',
#  'Propenoyl-CoA': 'C24H38N7O17P3S',
#  'Tos-Lys-CH2Cl': 'C14H21ClN2O3S',
#  'alpha-Maltose': 'C12H22O11',
#  '(R,R)-Tartaric acid': 'C4H6O6',
#  '11-cis-Retinol': 'C20H30O',
#  '2-Acetolactate': 'C5H8O4',
#  '2-Oxohexanoic acid': 'C6H10O3',
#  'Cinnamaldehyde': 'C9H8O',
#  'Citramalyl-CoA': 'C26H42N7O20P3S',
#  'D-Fructuronate': 'C6H10O7',
#  '5,6-Dihydrothymine': 'C5H8N2O2',
#  'Gentamicin C1a': 'C19H39N5O7',
#  'Leukotriene A4': 'C20H30O3',
#  '3-Methyladenine': 'C6H7N5',
#  'Benzyl viologen': 'C24H22N2',
#  'Cephalosporin C': 'C16H21N3O8S',
#  'Chloramphenicol': 'C11H12Cl2N2O5',
#  'Choline sulfate': 'C5H13NO4S',
#  'CoA-glutathione': 'C31H51N10O22P3S2',
#  'Dihydropteroate': 'C14H14N6O3',
#  '2,3-Dimethylmaleate': 'C6H8O4',
#  'Isonocardicin A': 'C23H24N4O9',
#  'Mercaptoethanol': 'C2H6OS',
#  'Porphobilinogen': 'C10H14N2O4',
#  'Sinapine': 'C16H24NO5',
#  'UDP-L-arabinose': 'C14H22N2O16P2',
#  'alpha-D-Mannose': 'C6H12O6',
#  '(R)-Lactaldehyde': 'C3H6O2',
#  '2-Aminoadenosine': 'C10H14N6O4',
#  '2-Oxoglutaramate': 'C5H7NO4',
#  "3',5'-Cyclic CMP": 'C9H12N3O7P',
#  "3',5'-Cyclic GMP": 'C10H12N5O7P',
#  "3',5'-Cyclic IMP": 'C10H11N4O7P',
#  '3-Dehydroquinate': 'C7H10O6',
#  "Adenosine 2'-phosphate": 'C10H14N5O7P',
#  'Dithioerythritol': 'C4H10O2S2',
#  'Estradiol-17beta': 'C18H24O2',
#  'Indole-3-acetate': 'C10H9NO2',
#  'Indole-3-ethanol': 'C10H11NO',
#  'L-2-Aminoadipate': 'C6H11NO4',
#  'Mercaptopyruvate': 'C3H4O3S',
#  'Prostaglandin B1': 'C20H32O4',
#  'Sterigmatocystin': 'C18H12O6',
#  'beta-D-Galactose': 'C6H12O6',
#  '(-)-trans-Carveol': 'C10H16O',
#  '2-Dehydropantoate': 'C6H10O4',
#  "3',5'-Cyclic dAMP": 'C10H12N5O5P',
#  '3-Hydroxypropanal': 'C3H6O2',
#  '4-Pyridoxolactone': 'C8H7NO3',
#  'Dihydrokaempferol': 'C15H12O6',
#  'Dihydroxyfumarate': 'C4H4O6',
#  'GDP-D-mannuronate': 'C16H23N5O17P2',
#  'L-Tryptophanamide': 'C11H13N3O',
#  'N-Acetylserotonin': 'C12H14N2O2',
#  'O-Acetyl-L-serine': 'C5H9NO4',
#  'Renilla luciferin': 'C26H21N3O2',
#  'alpha-D-Galactose': 'C6H12O6',
#  '1,3-Diaminopropane': 'C3H10N2',
#  '2-Phosphoglycolate': 'C2H5O6P',
#  '4-Hydroxybutanoic acid': 'C4H8O3',
#  '5-Aminopentanamide': 'C5H12N2O',
#  'Aquacob(III)alamin': 'C62H90CoN13O15P',
#  'D-Alanyl-D-alanine': 'C6H12N2O3',
#  'D-Prephenyllactate': 'C13H14O8',
#  'Formylmethanofuran': 'C35H44N4O16',
#  'Hexose 1-phosphate': 'C6H13O9P',
#  'N-Methylnicotinate': 'C7H7NO2',
#  'O-Phospho-L-serine': 'C3H8NO6P',
#  'Reduced riboflavin': 'C17H22N4O6',
#  'Trimethylsulfonium': 'C3H9S',
#  'UDP-2-deoxyglucose': 'C15H24N2O16P2',
#  'Urea-1-carboxylate': 'C2H4N2O3',
#  '(3S)-Citramalyl-CoA': 'C26H42N7O20P3S',
#  '(R)-Pantolactone': 'C6H10O3',
#  '3-Hydroxypropanoate': 'C3H6O3',
#  '3-Isopropylcatechol': 'C9H12O2',
#  'cis-4-Hydroxy-L-proline': 'C5H9NO3',
#  '5-Hydroxytryptophan': 'C11H12N2O3',
#  '6-Deoxy-D-galactose': 'C6H12O5',
#  '6-Deoxy-L-galactose': 'C6H12O5',
#  '6-Hydroxynicotinate': 'C6H5NO3',
#  'Dihydrostreptomycin': 'C21H41N7O12',
#  'Hydroxymethylbilane': 'C40H46N4O17',
#  'N,N-Dimethylglycine': 'C4H9NO2',
#  'N6-Hydroxy-L-lysine': 'C6H14N2O3',
#  'N8-Acetylspermidine': 'C9H21N3O',
#  'S-Formylglutathione': 'C11H17N3O7S',
#  '2-Methylbutanoyl-CoA': 'C26H44N7O17P3S',
#  '3-Oxo-delta5-steroid': 'C19H28O',
#  '4-Guanidinobutanoate': 'C5H11N3O2',
#  '4-Maleylacetoacetate': 'C8H8O6',
#  '7,8-Diaminononanoate': 'C9H20N2O2',
#  'L-Gulono-1,4-lactone': 'C6H10O6',
#  'Monodehydroascorbate': 'C6H7O6',
#  'N-Acetyl-L-aspartate': 'C6H9NO5',
#  'N-Carbamoylsarcosine': 'C4H8N2O3',
#  'N-Formyl-L-aspartate': 'C5H7NO5',
#  'N-Formyl-L-glutamate': 'C6H9NO5',
#  'N-Methyl-L-glutamate': 'C6H11NO4',
#  'N5-Ethyl-L-glutamine': 'C7H14N2O3',
#  'UDP-N-acetylmuramate': 'C20H31N3O19P2',
#  'Uroporphyrinogen III': 'C40H44N4O16',
#  '(R)-4-Dehydropantoate': 'C6H10O4',
#  '(S)-2,3-Epoxysqualene': 'C30H50O',
#  '(S)-6-Hydroxynicotine': 'C10H14N2O',
#  '2,5-Dihydroxypyridine': 'C5H5NO2',
#  '3,5-Diiodo-L-tyrosine': 'C9H9I2NO3',
#  '4-Fumarylacetoacetate': 'C8H8O6',
#  '5-Dehydro-D-gluconate': 'C6H10O7',
#  '6-Carboxyhexanoyl-CoA': 'C28H46N7O19P3S',
#  'Cyclohexane-1,3-dione': 'C6H8O2',
#  'D-Galactose 6-sulfate': 'C6H12O9S',
#  'D-Ribitol 5-phosphate': 'C5H13O8P',
#  'Desulfoglucotropeolin': 'C14H19NO6S',
#  'N-Acetyl-beta-alanine': 'C5H9NO3',
#  'N-Sulfo-D-glucosamine': 'C6H13NO8S',
#  'O-Acetyl-L-homoserine': 'C6H11NO4',
#  'Protoporphyrinogen IX': 'C34H40N4O4',
#  'Reduced coenzyme F420': 'C29H38N5O18P',
#  'Thiamin monophosphate': 'C12H18N4O4PS',
#  'alpha,alpha-Trehalose': 'C12H22O11',
#  '(R)-2-Hydroxyglutarate': 'C5H8O5',
#  '(R)-3,3-Dimethylmalate': 'C6H10O5',
#  '(R)-3-Hydroxybutanoate': 'C4H8O3',
#  '16alpha-Hydroxysteroid': 'C19H32O2',
#  'Deacetylvindoline': 'C23H30N2O5',
#  '8-Amino-7-oxononanoate': 'C9H17NO3',
#  'Cellobiono-1,5-lactone': 'C12H20O11',
#  'D-Fructose 1-phosphate': 'C6H13O9P',
#  'D-Ribose 5-diphosphate': 'C5H12O11P2',
#  'Sorbitol 6-phosphate': 'C6H15O9P',
#  'D-Tagatose 6-phosphate': 'C6H13O9P',
#  'L-Fuculose 1-phosphate': 'C6H13O8P',
#  'L-Histidinol phosphate': 'C6H12N3O4P',
#  'L-Ribulose 5-phosphate': 'C5H11O8P',
#  'O-Phospho-L-homoserine': 'C4H10NO6P',
#  "Orotidine 5'-phosphate": 'C10H13N2O11P',
#  'Trimethylamine N-oxide': 'C3H9NO',
#  '(R)-5-Phosphomevalonate': 'C6H13O7P',
#  '1,2,3-Trihydroxybenzene': 'C6H6O3',
#  '4-Methylene-L-glutamine': 'C6H10N2O3',
#  '5-Amino-2-oxopentanoic acid': 'C5H9NO3',
#  '7,8-Dihydroxykynurenate': 'C10H7NO5',
#  'D-Arabinose 5-phosphate': 'C5H11O8P',
#  'D-Galactose 6-phosphate': 'C6H13O9P',
#  'L-Arabinono-1,4-lactone': 'C5H8O5',
#  'L-Galactono-1,4-lactone': 'C6H10O6',
#  'O-Succinyl-L-homoserine': 'C8H13NO6',
#  'Oxidized dithiothreitol': 'C4H8O2S2',
#  'Sphinganine 1-phosphate': 'C18H40NO5P',
#  'Streptidine 6-phosphate': 'C8H19N6O7P',
#  '(-)-trans-Isopiperitenol': 'C10H16O',
#  '18-Hydroxycorticosterone': 'C21H30O5',
#  'Dihydro-4,4-dimethyl-2,3-furandione': 'C6H8O3',
#  '(2E,6E)-Farnesol': 'C15H26O',
#  '4-Hydroxy-2-oxoglutarate': 'C5H6O6',
#  'L-Rhamnulose 1-phosphate': 'C6H13O8P',
#  'N-Acetyl-D-galactosamine': 'C8H15NO6',
#  'N-Acetyl-D-glucosaminate': 'C8H15NO7',
#  "Pantetheine 4'-phosphate": 'C11H23N2O7PS',
#  'S-Acetyldihydrolipoamide': 'C10H19NO2S2',
#  'S-Adenosylmethioninamine': 'C14H23N6O3S',
#  'Streptomycin 6-phosphate': 'C21H40N7O15P',
#  '(3S)-3,6-Diaminohexanoate': 'C6H14N2O2',
#  '(R)-5-Diphosphomevalonate': 'C6H14O10P2',
#  '(S)-3-Hydroxybutanoyl-CoA': 'C25H42N7O18P3S',
#  '2-Hydroxy-3-oxopropanoate': 'C3H4O4',
#  '2-Hydroxycyclohexan-1-one': 'C6H10O2',
#  '4-Trimethylammoniobutanal': 'C7H16NO',
#  'D-Ribose 1,5-bisphosphate': 'C5H12O11P2',
#  'N(pi)-Methyl-L-histidine': 'C7H11N3O2',
#  "Quercetin 3,3'-bissulfate": 'C15H10O13S2',
#  "Quercetin 3,4'-bissulfate": 'C15H10O13S2',
#  'Hydroxyproline': 'C5H9NO3',
#  '1-O-Galloyl-beta-D-glucose': 'C13H16O10',
#  '2,3-Bisphospho-D-glycerate': 'C3H8O10P2',
#  '3,4-Dihydroxyphenylacetate': 'C8H8O4',
#  '3-(Pyrazol-1-yl)-L-alanine': 'C6H9N3O2',
#  '3-Carboxy-cis,cis-muconate': 'C7H6O6',
#  '7-Dehydrocholesterol': 'C27H44O',
#  'L-Glutamate 5-semialdehyde': 'C5H9NO3',
#  "Pseudouridine 5'-phosphate": 'C9H13N2O9P',
#  'S-Succinyldihydrolipoamide': 'C12H21NO4S2',
#  'UDP-N-acetyl-D-mannosamine': 'C17H27N3O17P2',
#  'alpha-D-Hexose 1-phosphate': 'C6H13O9P',
#  'beta-D-Glucose 6-phosphate': 'C6H13O9P',
#  '1,3,8-Naphthalenertriol': 'C10H8O3',
#  '1-O-Sinapoyl-beta-D-glucose': 'C17H22O10',
#  '17alpha-Hydroxyprogesterone': 'C21H30O3',
#  'Inositol 1-phosphate': 'C6H13O9P',
#  '3-(4-Hydroxyphenyl)pyruvate': 'C9H8O4',
#  '4-Methylthio-2-oxobutanoic acid': 'C5H8O3S',
#  '4-Trimethylammoniobutanoate': 'C7H16NO2',
#  'D-Ribulose 1,5-bisphosphate': 'C5H12O11P2',
#  'N,N-Dimethylaniline N-oxide': 'C8H11NO',
#  'Nicotinate D-ribonucleotide': 'C11H15NO9P',
#  '(3S,5S)-3,5-Diaminohexanoate': 'C6H14N2O2',
#  '3-Deoxy-D-manno-octulosonate': 'C8H14O8',
#  '3-Hydroxy-2-methylpropanoate': 'C4H8O3',
#  'Lathosterol': 'C27H46O',
#  'Palmitoylglycerone phosphate': 'C19H37O7P',
#  'Caffeate': 'C9H8O4',
#  '3-(2-Hydroxyphenyl)propanoate': 'C9H10O3',
#  'N(omega)-(ADP-D-ribosyl)-L-arginine': 'C21H35N9O15P2',
#  'Phytic acid': 'C6H18O24P6',
#  '(R)-3-Amino-2-methylpropanoate': 'C4H9NO2',
#  '3-(3,4-Dihydroxyphenyl)lactate': 'C9H10O5',
#  'N-Methylethanolamine phosphate': 'C3H10NO4P',
#  'UDP-N-acetylmuramoyl-L-alanine': 'C23H36N4O20P2',
#  '(R)-Methylmalonyl-CoA': 'C25H40N7O19P3S',
#  '1-Amino-1-deoxy-scyllo-inositol': 'C6H13NO5',
#  '2-(Acetamidomethylene)succinate': 'C7H9NO5',
#  '2-Dehydro-3-deoxy-D-galactonate': 'C6H10O6',
#  '5,6,7,8-Tetrahydromethanopterin': 'C30H45N6O16P',
#  '6-Phospho-2-dehydro-D-gluconate': 'C6H11O10P',
#  'CDP-4-dehydro-6-deoxy-D-glucose': 'C15H23N3O15P2',
#  '1D-myo-Inositol 1,4-bisphosphate': 'C6H14O12P2',
#  'Dihydrostreptomycin 6-phosphate': 'C21H42N7O15P',
#  'GDP-4-dehydro-6-deoxy-D-mannose': 'C16H23N5O15P2',
#  'Methyl 2-diazoacetamidohexonate': 'C9H16N3O3',
#  'sn-Glycero-3-phospho-1-inositol': 'C9H19O11P',
#  '12-OPDA': 'C18H28O3',
#  'Dehydroepiandrosterone': 'C19H28O2',
#  "Guanosine 3',5'-bis(diphosphate)": 'C10H17N5O17P4',
#  'all-trans-Hexaprenyl diphosphate': 'C30H52O7P2',
#  'alpha-D-Glucose 1,6-bisphosphate': 'C6H14O12P2',
#  'sn-Glycero-3-phosphoethanolamine': 'C5H14NO6P',
#  '1-Aminocyclopropane-1-carboxylate': 'C4H7NO2',
#  'alpha-D-Galactosyl-(1->3)-1D-myo-inositol': 'C12H22O11',
#  'D-Glucono-1,5-lactone 6-phosphate': 'C6H11O9P',
#  'N-Acetyl-beta-D-glucosaminylamine': 'C8H16N2O5',
#  '1D-myo-Inositol 1,3,4-trisphosphate': 'C6H15O15P3',
#  '3,5-Diiodo-4-hydroxyphenylpyruvate': 'C9H6I2O4',
#  'D-myo-Inositol 1,4,5-trisphosphate': 'C6H15O15P3',
#  '7,8-Dihydro-7,8-dihydroxykynurenate': 'C10H9NO5',
#  'N-Acetyl-L-glutamate 5-semialdehyde': 'C7H11NO4',
#  '(R)-2-Hydroxybutane-1,2,4-tricarboxylate': 'C7H10O7',
#  '4-(2-Aminophenyl)-2,4-dioxobutanoate': 'C10H9NO4',
#  'N-(6-Aminohexanoyl)-6-aminohexanoate': 'C12H24N2O3',
#  '3-Hydroxy-N6,N6,N6-trimethyl-L-lysine': 'C9H21N2O3',
#  "P1,P4-Bis(5'-adenosyl) tetraphosphate": 'C20H28N10O19P4',
#  "P1,P4-Bis(5'-guanosyl) tetraphosphate": 'C20H28N10O21P4',
#  'beta-Alanyl-N(pi)-methyl-L-histidine': 'C10H16N4O3',
#  '3,6,9-Trihydroxypterocarpan': 'C15H12O5',
#  '3,7-Di-O-methylquercetin': 'C17H14O7',
#  "3'-Deoxydihydrostreptomycin 6-phosphate": 'C21H42N7O14P',
#  '3-(Imidazol-4-yl)-2-oxopropyl phosphate': 'C6H9N2O5P',
#  "5-Amino-6-(5'-phosphoribosylamino)uracil": 'C9H15N4O9P',
#  '5-O-(1-Carboxyvinyl)-3-phosphoshikimate': 'C10H13O10P',
#  '3-Hydroxy-2-methylpyridine-5-carboxylate': 'C7H7NO3',
#  '1D-myo-Inositol 1,3,4,5-tetrakisphosphate': 'C6H16O18P4',
#  '2-Hydroxy-6-oxo-6-phenylhexa-2,4-dienoate': 'C12H10O4',
#  '5-Formyl-5,6,7,8-tetrahydromethanopterin': 'C31H45N6O17P',
#  '(3E)-4-(2-Carboxyphenyl)-2-oxobut-3-enoate': 'C11H8O5',
#  '2-Carboxy-2,5-dihydro-5-oxofuran-2-acetate': 'C7H6O6',
#  '4-Amino-5-hydroxymethyl-2-methylpyrimidine': 'C6H9N3O',
#  "Dihydrostreptomycin 3'alpha,6-bisphosphate": 'C21H43N7O18P2',
#  '1-Amino-1-deoxy-scyllo-inositol 4-phosphate': 'C6H14NO8P',
#  '1D-myo-Inositol 1,3,4,5,6-pentakisphosphate': 'C6H17O21P5',
#  '2,6-Dichlorophenol-4-(1,4-naphthoquinone imine)': 'C16H11Cl2NO2',
#  '2-Dehydro-3-deoxy-6-phosphate-D-galactonate': 'C6H11O9P',
#  'N-Acetyl-D-glucosaminyldiphosphoundecaprenol': 'C63H105NO12P2',
#  '3-(4-Methylpent-3-en-1-yl)pent-2-enedioyl-CoA': 'C32H50N7O19P3S',
#  '3alpha,7alpha-Dihydroxy-12-oxo-5beta-cholanate': 'C24H38O5',
#  '1-Guanidino-1-deoxy-scyllo-inositol 4-phosphate': 'C7H16N3O8P',
#  '2D-5-O-Methyl-2,3,5/4,6-pentahydroxycyclohexanone': 'C7H12O6',
#  '6-Hydroxypseudooxynicotine': 'C10H14N2O2',
#  '1D-1-Guanidino-3-amino-1,3-dideoxy-scyllo-inositol': 'C7H16N4O4',
#  '2-Amino-4-hydroxy-6-hydroxymethyl-7,8-dihydropteridine': 'C7H9N5O2',
#  '3alpha,7alpha,12alpha-Trihydroxy-5beta-cholestan-26-al': 'C27H46O4',
#  '1-(2-Carboxyphenylamino)-1-deoxy-D-ribulose 5-phosphate': 'C12H16NO9P',
#  '2,5-Diamino-6-(5-phospho-D-ribosylamino)pyrimidin-4(3H)-one': 'C9H16N5O8P',
#  '4-Deoxy-beta-D-gluc-4-enuronosyl-(1,3)-N-acetyl-D-galactosamine': 'C14H21NO11',
#  'Prostaglandin I2': 'C20H32O5',
#  '(S)-N-[3-(3,4-Methylenedioxyphenyl)-2-(mercaptomethyl)-1-oxoprolyl]glycine': 'C15H18N2O6S',
#  '(S)-N-[3-(3,4-Methylenedioxyphenyl)-2-(mercaptomethyl)-1-oxoprolyl]-(S)-alanine': 'C16H20N2O6S',
#  '(S)-N-[3-(3,4-Methylenedioxyphenyl)-2-(acetylthio)methyl-1-oxoprolyl]glycine benzyl ester': 'C24H26N2O7S',
#  '(S)-N-[3-(3,4-Methylenedioxyphenyl)-2-(acetylthio)methyl-1-oxoprolyl]-(S)-alanine benzyl ester': 'C25H28N2O7S',
#  'Bromide': 'Br',
#  'Hydrogen cyanide': 'CHN',
#  'Hydrochloric acid': 'HCl',
#  'HO-': 'OH',
#  'Sodium cation': 'Na',
#  'XDP': 'C10H14N4O12P2',
#  'E-64': 'C15H27N5O5',
#  'NH4+': 'NH4',
#  'dIDP': 'C10H14N4O10P2',
#  'dITP': 'C10H15N4O13P3',
#  'dUDP': 'C9H14N2O11P2',
#  'dXDP': 'C10H14N4O11P2',
#  'dXTP': 'C10H15N4O14P3',
#  'AA861': 'C21H26O3',
#  'FADH2': 'C27H35N9O15P2',
#  'Carbonic acid': 'H2CO3',
#  'PQQH2': 'C14H8N2O8',
#  "3'-AMP": 'C10H14N5O7P',
#  "3'-UMP": 'C9H13N2O9P',
#  'Tacrolimus': 'C44H69NO12',
#  'Fustin': 'C15H12O6',
#  'Ethylene glycol': 'C2H6O2',
#  'Iodine': 'I2',
#  'Maleic acid': 'C4H4O4',
#  'NH2Mec': 'C10H9NO2',
#  'Octane': 'C8H18',
#  'Phytol': 'C20H40O',
#  'Prenol': 'C5H10O',
#  'Xylose': 'C5H10O5',
#  'Arachidonyltrifluoromethane': 'C21H31F3O',
#  'Alanine': 'C3H7NO2',
#  'Anisole': 'C7H8O',
#  'Arg-OEt': 'C8H18N4O2',
#  'Aspirin': 'C9H8O4',
#  'Benzene': 'C6H6',
#  'Benzoin': 'C14H12O2',
#  'Boc-Asn': 'C9H16N2O5',
#  'Borneol': 'C10H18O',
#  'Butanal': 'C4H8O',
#  'Casbene': 'C20H32',
#  'Cocaine': 'C17H21NO4',
#  'Cyanate': 'CHNO',
#  'Cycasin': 'C8H16N2O7',
#  'Cys-Gly': 'C5H10N2O3S',
#  'Cystine': 'C6H12N2O4S2',
#  'Daphnin': 'C15H16O9',
#  'Gallate': 'C7H6O5',
#  'Glutamyl-glutamic acid': 'C10H16N2O7',
#  'Lactate': 'C3H6O3',
#  'Loganin': 'C17H26O10',
#  'Methane': 'CH4',
#  'Neamine': 'C12H26N4O6',
#  'Ouabain': 'C29H44O12',
#  'Oxamate': 'C2H3NO3',
#  'Questin': 'C16H12O5',
#  'Queuine': 'C12H15N5O3',
#  'Salicin': 'C13H18O7',
#  'Sorbose': 'C6H12O6',
#  'Tacrine': 'C13H14N2',
#  'Toluate': 'C8H8O2',
#  'Toluene': 'C7H8',
#  'Tropate': 'C9H10O3',
#  'Tylosin': 'C46H77NO17',
#  'Tyr-OEt': 'C11H15NO3',
#  'Vitexin': 'C21H20O10',
#  'Xanthan': 'C13H10O',
#  '3-Cresol': 'C7H8O',
#  '4-Cresol': 'C7H8O',
#  'Acacetin': 'C16H12O5',
#  'Acrolein': 'C3H4O',
#  'Alizarin': 'C14H8O4',
#  'Apigenin': 'C15H10O5',
#  'Arsenic acid': 'H3AsO4',
#  'Atropine': 'C17H23NO3',
#  'Chalcone': 'C15H12O',
#  'Chloric acid': 'HClO3',
#  'Chlorous acid': 'HClO2',
#  'D-Allose': 'C6H12O6',
#  'D-Apiose': 'C5H10O5',
#  'D-Iditol': 'C6H14O6',
#  'Ferulate': 'C10H10O4',
#  'Flavonol': 'C15H10O3',
#  'Geranial': 'C10H16O',
#  'Geraniol': 'C10H18O',
#  'Glucagon': 'C153H225N43O49S',
#  'o-Methoxyphenol': 'C7H8O2',
#  'Indanone': 'C9H8O',
#  'Kallidin': 'C56H85N17O12',
#  'L-Iditol': 'C6H14O6',
#  'L-Lyxose': 'C5H10O5',
#  'L-Xylose': 'C5H10O5',
#  'Loganate': 'C16H24O10',
#  'Lupinate': 'C13H18N6O3',
#  'Luteolin': 'C15H10O6',
#  'Morphine': 'C17H19NO3',
#  ...}

# %%
cmpd_id_formula_dict
# Out:
# {'C00001': 'H2O',
#  'C00002': 'C10H16N5O13P3',
#  'C00003': 'C21H28N7O14P2',
#  'C00004': 'C21H29N7O14P2',
#  'C00005': 'C21H30N7O17P3',
#  'C00006': 'C21H29N7O17P3',
#  'C00007': 'O2',
#  'C00008': 'C10H15N5O10P2',
#  'C00009': 'H3PO4',
#  'C00010': 'C21H36N7O16P3S',
#  'C00011': 'CO2',
#  'C00013': 'H4P2O7',
#  'C00014': 'NH3',
#  'C00015': 'C9H14N2O12P2',
#  'C00016': 'C27H33N9O15P2',
#  'C00018': 'C8H10NO6P',
#  'C00019': 'C15H22N6O5S',
#  'C00020': 'C10H14N5O7P',
#  'C00021': 'C14H20N6O5S',
#  'C00022': 'C3H4O3',
#  'C00023': 'Fe',
#  'C00024': 'C23H38N7O17P3S',
#  'C00025': 'C5H9NO4',
#  'C00026': 'C5H6O5',
#  'C00027': 'H2O2',
#  'C00029': 'C15H24N2O17P2',
#  'C00031': 'C6H12O6',
#  'C00032': 'C34H32FeN4O4',
#  'C00033': 'C2H4O2',
#  'C00034': 'Mn',
#  'C00035': 'C10H15N5O11P2',
#  'C00036': 'C4H4O5',
#  'C00037': 'C2H5NO2',
#  'C00038': 'Zn',
#  'C00041': 'C3H7NO2',
#  'C00042': 'C4H6O4',
#  'C00043': 'C17H27N3O17P2',
#  'C00044': 'C10H16N5O14P3',
#  'C00047': 'C6H14N2O2',
#  'C00048': 'C2H2O3',
#  'C00049': 'C4H7NO4',
#  'C00051': 'C10H17N3O6S',
#  'C00052': 'C15H24N2O17P2',
#  'C00053': 'C10H15N5O13P2S',
#  'C00054': 'C10H15N5O10P2',
#  'C00055': 'C9H14N3O8P',
#  'C00058': 'CH2O2',
#  'C00059': 'H2SO4',
#  'C00061': 'C17H21N4O9P',
#  'C00062': 'C6H14N4O2',
#  'C00063': 'C9H16N3O14P3',
#  'C00064': 'C5H10N2O3',
#  'C00065': 'C3H7NO3',
#  'C00067': 'CH2O',
#  'C00068': 'C12H19N4O7P2S',
#  'C00070': 'Cu',
#  'C00072': 'C6H8O6',
#  'C00073': 'C5H11NO2S',
#  'C00074': 'C3H5O6P',
#  'C00075': 'C9H15N2O15P3',
#  'C00076': 'Ca',
#  'C00077': 'C5H12N2O2',
#  'C00078': 'C11H12N2O2',
#  'C00079': 'C9H11NO2',
#  'C00080': 'H',
#  'C00081': 'C10H15N4O14P3',
#  'C00082': 'C9H11NO3',
#  'C00083': 'C24H38N7O19P3S',
#  'C00084': 'C2H4O',
#  'C00085': 'C6H13O9P',
#  'C00086': 'CH4N2O',
#  'C00087': 'S',
#  'C00088': 'HNO2',
#  'C00089': 'C12H22O11',
#  'C00090': 'C6H6O2',
#  'C00091': 'C25H40N7O19P3S',
#  'C00092': 'C6H13O9P',
#  'C00093': 'C3H9O6P',
#  'C00094': 'H2SO3',
#  'C00095': 'C6H12O6',
#  'C00096': 'C16H25N5O16P2',
#  'C00097': 'C3H7NO2S',
#  'C00099': 'C3H7NO2',
#  'C00100': 'C24H40N7O17P3S',
#  'C00101': 'C19H23N7O6',
#  'C00102': 'C12H7Cl2NO2',
#  'C00103': 'C6H13O9P',
#  'C00104': 'C10H14N4O11P2',
#  'C00105': 'C9H13N2O9P',
#  'C00106': 'C4H4N2O2',
#  'C00108': 'C7H7NO2',
#  'C00109': 'C4H6O3',
#  'C00111': 'C3H7O6P',
#  'C00112': 'C9H15N3O11P2',
#  'C00113': 'C14H6N2O8',
#  'C00114': 'C5H14NO',
#  'C00116': 'C3H8O3',
#  'C00117': 'C5H11O8P',
#  'C00118': 'C3H7O6P',
#  'C00119': 'C5H13O14P3',
#  'C00120': 'C10H16N2O3S',
#  'C00121': 'C5H10O5',
#  'C00122': 'C4H4O4',
#  'C00123': 'C6H13NO2',
#  'C00124': 'C6H12O6',
#  'C00127': 'C20H32N6O12S2',
#  'C00128': 'C20H31N4O16P',
#  'C00129': 'C5H12O7P2',
#  'C00130': 'C10H13N4O8P',
#  'C00131': 'C10H16N5O12P3',
#  'C00132': 'CH4O',
#  'C00133': 'C3H7NO2',
#  'C00134': 'C4H12N2',
#  'C00135': 'C6H9N3O2',
#  'C00136': 'C25H42N7O17P3S',
#  'C00137': 'C6H12O6',
#  'C00140': 'C8H15NO6',
#  'C00141': 'C5H8O3',
#  'C00143': 'C20H23N7O6',
#  'C00144': 'C10H14N5O8P',
#  'C00146': 'C6H6O',
#  'C00147': 'C5H5N5',
#  'C00148': 'C5H9NO2',
#  'C00149': 'C4H6O5',
#  'C00150': 'Mo',
#  'C00152': 'C4H8N2O3',
#  'C00153': 'C6H6N2O',
#  'C00154': 'C37H66N7O17P3S',
#  'C00155': 'C4H9NO2S',
#  'C00156': 'C7H6O3',
#  'C00158': 'C6H8O7',
#  'C00159': 'C6H12O6',
#  'C00160': 'C2H4O3',
#  'C00163': 'C3H6O2',
#  'C00164': 'C4H6O3',
#  'C00166': 'C9H8O3',
#  'C00167': 'C15H22N2O18P2',
#  'C00168': 'C3H4O4',
#  'C00169': 'CH4NO5P',
#  'C00170': 'C11H15N5O3S',
#  'C00175': 'Co',
#  'C00177': 'CN',
#  'C00178': 'C5H6N2O2',
#  'C00179': 'C5H14N4',
#  'C00180': 'C7H6O2',
#  'C00181': 'C5H10O5',
#  'C00182': 'C24H42O21',
#  'C00183': 'C5H11NO2',
#  'C00184': 'C3H6O3',
#  'C00185': 'C12H22O11',
#  'C00186': 'C3H6O3',
#  'C00187': 'C27H46O',
#  'C00188': 'C4H9NO3',
#  'C00189': 'C2H7NO',
#  'C00190': 'C14H22N2O16P2',
#  'C00191': 'C6H10O7',
#  'C00192': 'NH3O',
#  'C00193': 'C7H6O',
#  'C00194': 'C72H100CoN18O17P',
#  'C00196': 'C7H6O4',
#  'C00197': 'C3H7O7P',
#  'C00198': 'C6H10O6',
#  'C00199': 'C5H11O8P',
#  'C00202': 'C6H14FO3P',
#  'C00203': 'C17H27N3O17P2',
#  'C00204': 'C6H10O6',
#  'C00206': 'C10H15N5O9P2',
#  'C00207': 'C3H6O',
#  'C00208': 'C12H22O11',
#  'C00209': 'C2H2O4',
#  'C00210': 'C53H81CoN11O15P',
#  'C00212': 'C10H13N5O4',
#  'C00213': 'C3H7NO2',
#  'C00214': 'C10H14N2O5',
#  'C00216': 'C5H10O5',
#  'C00217': 'C5H9NO4',
#  'C00218': 'CH5N',
#  'C00219': 'C20H32O2',
#  'C00221': 'C6H12O6',
#  'C00222': 'C3H4O3',
#  'C00223': 'C30H42N7O18P3S',
#  'C00224': 'C10H14N5O10PS',
#  'C00227': 'C2H5O5P',
#  'C00230': 'C7H6O4',
#  'C00231': 'C5H11O8P',
#  'C00232': 'C4H6O3',
#  'C00233': 'C6H10O3',
#  'C00234': 'C20H23N7O7',
#  'C00235': 'C5H12O7P2',
#  'C00236': 'C3H8O10P2',
#  'C00237': 'CO',
#  'C00238': 'K',
#  'C00239': 'C9H14N3O7P',
#  'C00242': 'C5H5N5O',
#  'C00243': 'C12H22O11',
#  'C00244': 'HNO3',
#  'C00245': 'C2H7NO3S',
#  'C00246': 'C4H8O2',
#  'C00247': 'C6H12O6',
#  'C00248': 'C8H15NOS2',
#  'C00249': 'C16H32O2',
#  'C00250': 'C8H9NO3',
#  'C00251': 'C10H10O6',
#  'C00252': 'C12H22O11',
#  'C00253': 'C6H5NO2',
#  'C00254': 'C10H10O6',
#  'C00255': 'C17H20N4O6',
#  'C00256': 'C3H6O3',
#  'C00257': 'C6H12O7',
#  'C00258': 'C3H6O4',
#  'C00259': 'C5H10O5',
#  'C00261': 'C7H6O',
#  'C00262': 'C5H4N4O',
#  'C00263': 'C4H9NO3',
#  'C00265': 'C4H10O2S2',
#  'C00266': 'C2H4O2',
#  'C00267': 'C6H12O6',
#  'C00268': 'C9H13N5O3',
#  'C00270': 'C11H19NO9',
#  'C00272': 'C9H15N5O3',
#  'C00273': 'C6H10O6',
#  'C00275': 'C6H13O9P',
#  'C00279': 'C4H9O7P',
#  'C00280': 'C19H26O2',
#  'C00282': 'H2',
#  'C00283': 'H2S',
#  'C00284': 'C10H16N2O8',
#  'C00286': 'C10H16N5O13P3',
#  'C00288': 'HCO3',
#  'C00291': 'Ni',
#  'C00292': 'C6H7N',
#  'C00294': 'C10H12N4O5',
#  'C00295': 'C5H4N2O4',
#  'C00296': 'C7H12O6',
#  'C00299': 'C9H12N2O6',
#  'C00300': 'C4H9N3O2',
#  'C00301': 'C15H23N5O14P2',
#  'C00302': 'C5H9NO4',
#  'C00303': 'C5H10N2O3',
#  'C00305': 'Mg',
#  'C00306': 'C50H73N15O11',
#  'C00307': 'C14H26N4O11P2',
#  'C00308': 'C5H12N4O3',
#  'C00309': 'C5H10O5',
#  'C00310': 'C5H10O5',
#  'C00311': 'C6H8O7',
#  'C00312': 'C5H10O5',
#  'C00313': 'C23H36N7O19P3S',
#  'C00314': 'C8H11NO3',
#  'C00315': 'C7H19N3',
#  'C00317': 'C30H52O26',
#  'C00318': 'C7H15NO3',
#  'C00319': 'C18H37NO2',
#  'C00320': 'HS2O3',
#  'C00322': 'C6H8O5',
#  'C00323': 'C30H42N7O19P3S',
#  'C00324': 'C6FeN6',
#  'C00325': 'C16H25N5O15P2',
#  'C00327': 'C6H13N3O3',
#  'C00328': 'C10H12N2O3',
#  'C00329': 'C6H13NO5',
#  'C00330': 'C10H13N5O4',
#  'C00331': 'C11H9NO3',
#  'C00332': 'C25H40N7O18P3S',
#  'C00333': 'C6H10O7',
#  'C00334': 'C4H9NO2',
#  'C00337': 'C5H6N2O4',
#  'C00341': 'C10H20O7P2',
#  'C00345': 'C6H13O10P',
#  'C00346': 'C2H8NO4P',
#  'C00348': 'C55H91O4P',
#  'C00349': 'C4H6O3',
#  'C00352': 'C6H14NO8P',
#  'C00353': 'C20H36O7P2',
#  'C00354': 'C6H14O12P2',
#  'C00355': 'C9H11NO4',
#  'C00356': 'C27H44N7O20P3S',
#  'C00357': 'C8H16NO9P',
#  'C00360': 'C10H14N5O6P',
#  'C00361': 'C10H15N5O10P2',
#  'C00362': 'C10H14N5O7P',
#  'C00363': 'C10H16N2O11P2',
#  'C00364': 'C10H15N2O8P',
#  'C00365': 'C9H13N2O8P',
#  'C00366': 'C5H4N4O3',
#  'C00370': 'C17H28O',
#  'C00371': 'C10H13N5O',
#  'C00376': 'C20H28O',
#  'C00378': 'C12H17N4OS',
#  'C00379': 'C5H12O5',
#  'C00380': 'C4H5N3O',
#  'C00383': 'C3H4O4',
#  'C00385': 'C5H4N4O2',
#  'C00386': 'C9H14N4O3',
#  'C00387': 'C10H13N5O5',
#  'C00388': 'C5H9N3',
#  'C00389': 'C15H10O7',
#  'C00392': 'C6H14O6',
#  'C00394': 'C16H25N5O16P2',
#  'C00396': 'C4H4N2',
#  'C00397': 'C18H37N5O9',
#  'C00398': 'C10H12N2',
#  'C00400': 'C10H20O',
#  'C00402': 'C4H7NO4',
#  'C00406': 'C31H44N7O19P3S',
#  'C00407': 'C6H13NO2',
#  'C00408': 'C6H11NO2',
#  'C00409': 'CH4S',
#  'C00410': 'C21H30O2',
#  'C00411': 'C32H46N7O20P3S',
#  'C00412': 'C39H70N7O17P3S',
#  'C00413': 'C21H39N7O12',
#  'C00414': 'C6H10O',
#  'C00415': 'C19H21N7O6',
#  'C00417': 'C6H6O6',
#  'C00418': 'C6H12O4',
#  'C00423': 'C9H8O2',
#  'C00424': 'C3H6O2',
#  'C00427': 'C20H32O5',
#  'C00429': 'C4H6N2O2',
#  'C00430': 'C5H9NO3',
#  'C00431': 'C5H11NO2',
#  'C00433': 'C5H6O4',
#  'C00436': 'C5H13N3O',
#  'C00437': 'C7H14N2O3',
#  'C00438': 'C5H8N2O5',
#  'C00439': 'C6H10N2O4',
#  'C00440': 'C20H25N7O6',
#  'C00441': 'C4H7NO3',
#  'C00445': 'C20H22N7O6',
#  'C00446': 'C6H13O9P',
#  'C00447': 'C7H16O13P2',
#  'C00448': 'C15H28O7P2',
#  'C00449': 'C11H20N2O6',
#  'C00450': 'C6H9NO2',
#  'C00451': 'C6H8O7',
#  'C00455': 'C11H15N2O8P',
#  'C00458': 'C9H16N3O13P3',
#  'C00459': 'C10H17N2O14P3',
#  'C00460': 'C9H15N2O14P3',
#  'C00463': 'C8H7N',
#  'C00466': 'C4H8O2',
#  'C00468': 'C18H22O2',
#  'C00469': 'C2H6O',
#  'C00472': 'C6H4O2',
#  'C00473': 'C20H30O',
#  'C00474': 'C5H12O5',
#  'C00475': 'C9H13N3O5',
#  'C00476': 'C5H10O5',
#  'C00477': 'C27H44O6',
#  'C00478': 'C6H10O5',
#  'C00479': 'C3H6O',
#  'C00481': 'C3H4N2',
#  'C00482': 'C11H12O5',
#  'C00483': 'C8H11NO',
#  'C00486': 'C33H36N4O6',
#  'C00487': 'C7H16NO3',
#  'C00488': 'CH3NO',
#  'C00489': 'C5H8O4',
#  'C00490': 'C5H6O4',
#  'C00491': 'C6H12N2O4S2',
#  'C00492': 'C18H32O16',
#  'C00493': 'C7H10O5',
#  'C00494': 'C19H37N5O7',
#  'C00495': 'C17H16O7',
#  'C00497': 'C4H6O5',
#  'C00498': 'C16H25N5O15P2',
#  'C00499': 'C4H8N4O4',
#  'C00500': 'C33H34N4O6',
#  'C00501': 'C15H25N3O16P2',
#  'C00502': 'C5H10O6',
#  'C00503': 'C4H10O4',
#  'C00504': 'C19H19N7O6',
#  'C00506': 'C3H7NO5S',
#  'C00507': 'C6H12O5',
#  'C00508': 'C5H10O5',
#  'C00509': 'C15H12O5',
#  'C00510': 'C39H68N7O17P3S',
#  'C00511': 'C3H4O2',
#  'C00512': 'C28H40N7O17P3S',
#  'C00513': 'C12H21N3O13P2',
#  'C00514': 'C6H12O7',
#  'C00515': 'C5H12N2O2',
#  'C00517': 'C16H32O',
#  'C00519': 'C2H7NO2S',
#  'C00521': 'C10H16',
#  'C00522': 'C6H12O4',
#  'C00523': 'C19H30O2',
#  'C00525': 'C11H12N2O2',
#  'C00526': 'C9H12N2O5',
#  'C00527': 'C26H42N7O19P3S',
#  'C00528': 'C36H64N8O17',
#  'C00530': 'C6H6O2',
#  'C00531': 'C26H40N7O19P3S',
#  'C00532': 'C5H12O5',
#  'C00533': 'NO',
#  'C00534': 'C8H12N2O2',
#  'C00535': 'C19H28O2',
#  'C00536': 'H5P3O10',
#  'C00539': 'C7H6O2',
#  'C00540': 'C30H42N7O17P3S',
#  'C00541': 'C62H88CoN13O14P',
#  'C00542': 'C7H14N2O4S',
#  'C00543': 'C2H7N',
#  'C00544': 'C8H8O4',
#  'C00545': 'C5H10O6',
#  'C00546': 'C3H4O2',
#  'C00547': 'C8H11NO3',
#  'C00548': 'C8H8O2',
#  'C00552': 'C4H6O6',
#  'C00553': 'C10H20O',
#  'C00555': 'C4H9NO',
#  'C00556': 'C7H8O',
#  'C00557': 'C5H8O',
#  'C00558': 'C6H10O7',
#  'C00559': 'C10H13N5O3',
#  'C00561': 'C8H7NO',
#  'C00563': 'C23H34N3O10P',
#  'C00565': 'C3H9N',
#  'C00566': 'C27H42N7O22P3S',
#  'C00568': 'C7H7NO2',
#  'C00570': 'C11H20N4O11P2',
#  'C00571': 'C6H13N',
#  'C00575': 'C10H12N5O6P',
#  'C00576': 'C5H12NO',
#  'C00577': 'C3H6O3',
#  'C00579': 'C8H17NOS2',
#  'C00580': 'C2H6S',
#  'C00581': 'C3H7N3O2',
#  'C00582': 'C29H42N7O17P3S',
#  'C00583': 'C3H8O2',
#  'C00584': 'C20H32O5',
#  'C00586': 'C6H12O5',
#  'C00587': 'C7H6O3',
#  'C00588': 'C5H15NO4P',
#  'C00590': 'C10H12O3',
#  'C00593': 'C2H4O4S',
#  'C00596': 'C5H6O3',
#  'C00597': 'C3H7O7P',
#  'C00599': 'C27H44O',
#  'C00601': 'C8H8O',
#  'C00603': 'C3H6N2O4',
#  'C00604': 'C12H8N2',
#  'C00606': 'C3H7NO4S',
#  'C00611': 'C14H25NO11',
#  'C00612': 'C9H21N3O',
#  'C00616': 'C15H10O10S',
#  'C00617': 'C15H22N2O18P2',
#  'C00618': 'C6H10O7',
#  'C00619': 'C19H28O',
#  'C00620': 'C5H11O8P',
#  'C00623': 'C3H9O6P',
#  'C00624': 'C7H11NO5',
#  'C00627': 'C8H12NO6P',
#  'C00628': 'C7H6O4',
#  'C00630': 'C25H42N7O17P3S',
#  'C00631': 'C3H7O7P',
#  'C00632': 'C7H7NO3',
#  'C00633': 'C7H6O2',
#  'C00636': 'C6H13O9P',
#  'C00637': 'C10H9NO',
#  'C00639': 'C20H34O5',
#  'C00642': 'C8H8O3',
#  'C00643': 'C11H12N2O3',
#  'C00644': 'C6H15O9P',
#  'C00645': 'C8H15NO6',
#  'C00647': 'C8H13N2O5P',
#  'C00650': 'C8H7NO2',
#  'C00651': 'C6H9NO4',
#  'C00652': 'C5H8O5',
#  'C00655': 'C10H13N4O9P',
#  'C00659': 'C6H10O4',
#  'C00661': 'C3H7O6P',
#  'C00663': 'C6H13O9P',
#  'C00664': 'C20H24N8O6',
#  'C00665': 'C6H14O12P2',
#  'C00666': 'C7H14N2O4',
#  'C00668': 'C6H13O9P',
#  'C00669': 'C8H14N2O5S',
#  'C00670': 'C8H21NO6P',
#  'C00671': 'C6H10O3',
#  'C00672': 'C5H11O7P',
#  'C00673': 'C5H11O7P',
#  'C00674': 'C19H28O2',
#  'C00679': 'C6H8O7',
#  'C00680': 'C7H14N2O4',
#  'C00682': 'C6H6O4',
#  'C00683': 'C25H40N7O19P3S',
#  'C00684': 'C5H8O5',
#  'C00688': 'C16H24N2O15P2',
#  'C00689': 'C12H23O14P',
#  'C00691': 'C6H10O6',
#  'C00692': 'C28H43N5O23P2',
#  'C00695': 'C24H40O5',
#  'C00696': 'C20H32O5',
#  'C00697': 'N2',
#  'C00698': 'Cl',
#  'C00700': 'C10H15N4O15P3',
#  'C00704': 'O2',
#  'C00705': 'C9H15N3O10P2',
#  'C00708': 'I',
#  'C00711': 'C4H6O5',
#  'C00712': 'C18H34O2',
#  'C00713': 'C18H32O16',
#  'C00715': 'C6H5N5O',
#  'C00716': 'C3H7NO3',
#  'C00719': 'C5H11NO2',
#  'C00725': 'C8H14O2S2',
#  'C00727': 'C7H8O2',
#  'C00729': 'C8H15NO',
#  'C00732': 'C16H24N2O4',
#  'C00735': 'C21H30O5',
#  'C00736': 'C3H7NO2S',
#  'C00737': 'C6H12O6',
#  'C00738': 'C6H12O6',
#  'C00739': 'C6H14N2O2',
#  'C00740': 'C3H7NO3',
#  'C00741': 'C4H6O2',
#  'C00742': 'F',
#  'C00744': 'C45H75NO17',
#  'C00745': 'C10H14N2',
#  'C00746': 'C43H66N12O12S2',
#  'C00747': 'C5H5N',
#  'C00748': 'C42H44FeN4O16',
#  'C00750': 'C10H26N4',
#  'C00751': 'C30H50',
#  'C00753': 'W',
#  'C00755': 'C8H8O3',
#  'C00756': 'C8H18O',
#  'C00757': 'C20H18NO4',
#  'C00758': 'C11H6O4',
#  'C00761': 'C16H22O8',
#  'C00762': 'C21H28O5',
#  'C00763': 'C5H9NO2',
#  'C00764': 'C6H12O6',
#  'C00765': 'C56H92O29',
#  'C00766': 'C15H12O2',
#  'C00768': 'C6H9N3O2',
#  'C00770': 'C6H12O7',
#  'C00772': 'C6H10O4',
#  'C00773': 'C34H63N5O9',
#  'C00774': 'C15H14O5',
#  'C00777': 'C20H28O2',
#  'C00779': 'C10H10O4',
#  'C00780': 'C10H12N2O',
#  'C00783': 'C8H13NO',
#  'C00785': 'C6H6N2O2',
#  'C00786': 'C16H14O5',
#  'C00788': 'C9H13NO3',
#  'C00789': 'C14H25N3O15P2',
#  'C00791': 'C4H7N3O',
#  'C00792': 'C6H14N4O2',
#  'C00793': 'C3H7NO2S',
#  'C00794': 'C6H14O6',
#  'C00795': 'C6H12O6',
#  'C00796': 'C19H12O6',
#  'C00797': 'C2H7N',
#  'C00798': 'C22H36N7O17P3S',
#  'C00799': 'C15H10O2',
#  'C00800': 'C6H12O7',
#  'C00802': 'C3H4N2O4',
#  'C00803': 'C5H10O2',
#  'C00804': 'C3H2O2',
#  'C00805': 'C7H6O3',
#  'C00806': 'C11H12N2O2',
#  'C00808': 'C10H16O',
#  'C00809': 'C10H16O',
#  'C00810': 'C4H8O2',
#  'C00811': 'C9H8O3',
#  'C00813': 'C4H4N2O3',
#  'C00814': 'C16H12O5',
#  'C00815': 'C5H8O5',
#  'C00817': 'C6H12O7',
#  'C00818': 'C6H10O8',
#  'C00819': 'C5H10N2O3',
#  'C00820': 'C4H9NO3',
#  'C00822': 'C9H9NO4',
#  'C00823': 'C16H34O',
#  'C00825': 'C18H37N5O10',
#  'C00826': 'C10H13NO5',
#  'C00827': 'C24H40N7O18P3S',
#  'C00829': 'C10H8',
#  'C00830': 'C3H2O5',
#  'C00831': 'C11H22N2O4S',
#  'C00832': 'C23H45N5O14',
#  'C00835': 'C9H11N5O3',
#  'C00836': 'C18H39NO2',
#  'C00837': 'C8H18N6O4',
#  'C00841': 'C11H6O4',
#  'C00842': 'C16H26N2O16P2',
#  'C00843': 'C10H18O',
#  'C00844': 'C14H17NO6',
#  'C00845': 'C26H38N7O18P3S',
#  'C00846': 'C6H8O5',
#  'C00847': 'C8H9NO4',
#  'C00848': 'C10H16O2',
#  'C00849': 'C4H8O2',
#  'C00850': 'C6H6O4S',
#  'C00852': 'C16H18O9',
#  'C00853': 'C62H89CoN13O14P',
#  'C00854': 'C6H12O',
#  'C00855': 'C5H11NO2S',
#  'C00857': 'C21H27N6O15P2',
#  'C00858': 'C16H12O4',
#  'C00859': 'C19H24O6',
#  'C00860': 'C6H11N3O',
#  'C00861': 'C6H12O5',
#  'C00862': 'C34H44N4O15',
#  'C00864': 'C9H17NO5',
#  'C00869': 'C18H34O3',
#  'C00870': 'C6H5NO3',
#  'C00872': 'C3H5NO4',
#  'C00873': 'C62H89N17O14',
#  'C00876': 'C29H36N5O18P',
#  'C00877': 'C25H40N7O17P3S',
#  'C00878': 'C5H10O6',
#  'C00879': 'C6H10O8',
#  'C00880': 'C6H12O7',
#  'C00881': 'C9H13N3O4',
#  'C00882': 'C21H35N7O13P2S',
#  'C00883': 'C18H32O16',
#  'C00884': 'C10H16N4O3',
#  'C00885': 'C10H10O6',
#  'C00887': 'N2O',
#  'C00888': 'C26H44N7O17P3S',
#  'C00891': 'C21H34O',
#  'C00892': 'C21H36O',
#  'C00894': 'C24H38N7O17P3S',
#  'C00896': 'C14H21ClN2O3S',
#  'C00897': 'C12H22O11',
#  'C00898': 'C4H6O6',
#  'C00899': 'C20H30O',
#  'C00900': 'C5H8O4',
#  'C00902': 'C6H10O3',
#  'C00903': 'C9H8O',
#  'C00904': 'C26H42N7O20P3S',
#  'C00905': 'C6H10O7',
#  'C00906': 'C5H8N2O2',
#  'C00908': 'C19H39N5O7',
#  'C00909': 'C20H30O3',
#  'C00913': 'C6H7N5',
#  'C00915': 'C24H22N2',
#  'C00916': 'C16H21N3O8S',
#  'C00918': 'C11H12Cl2N2O5',
#  'C00919': 'C5H13NO4S',
#  'C00920': 'C31H51N10O22P3S2',
#  'C00921': 'C14H14N6O3',
#  'C00922': 'C6H8O4',
#  'C00927': 'C23H24N4O9',
#  'C00928': 'C2H6OS',
#  'C00931': 'C10H14N2O4',
#  'C00933': 'C16H24NO5',
#  'C00935': 'C14H22N2O16P2',
#  'C00936': 'C6H12O6',
#  'C00937': 'C3H6O2',
#  'C00939': 'C10H14N6O4',
#  'C00940': 'C5H7NO4',
#  'C00941': 'C9H12N3O7P',
#  'C00942': 'C10H12N5O7P',
#  'C00943': 'C10H11N4O7P',
#  'C00944': 'C7H10O6',
#  'C00946': 'C10H14N5O7P',
#  'C00950': 'C4H10O2S2',
#  'C00951': 'C18H24O2',
#  'C00954': 'C10H9NO2',
#  'C00955': 'C10H11NO',
#  'C00956': 'C6H11NO4',
#  'C00957': 'C3H4O3S',
#  'C00959': 'C20H32O4',
#  'C00961': 'C18H12O6',
#  'C00962': 'C6H12O6',
#  'C00964': 'C10H16O',
#  'C00966': 'C6H10O4',
#  'C00968': 'C10H12N5O5P',
#  'C00969': 'C3H6O2',
#  'C00971': 'C8H7NO3',
#  'C00974': 'C15H12O6',
#  'C00975': 'C4H4O6',
#  'C00976': 'C16H23N5O17P2',
#  'C00977': 'C11H13N3O',
#  'C00978': 'C12H14N2O2',
#  'C00979': 'C5H9NO4',
#  'C00982': 'C26H21N3O2',
#  'C00984': 'C6H12O6',
#  'C00986': 'C3H10N2',
#  'C00988': 'C2H5O6P',
#  'C00989': 'C4H8O3',
#  'C00990': 'C5H12N2O',
#  'C00992': 'C62H90CoN13O15P',
#  'C00993': 'C6H12N2O3',
#  'C00994': 'C13H14O8',
#  'C01001': 'C35H44N4O16',
#  'C01002': 'C6H13O9P',
#  'C01004': 'C7H7NO2',
#  'C01005': 'C3H8NO6P',
#  'C01007': 'C17H22N4O6',
#  'C01008': 'C3H9S',
#  'C01009': 'C15H24N2O16P2',
#  'C01010': 'C2H4N2O3',
#  'C01011': 'C26H42N7O20P3S',
#  'C01012': 'C6H10O3',
#  'C01013': 'C3H6O3',
#  'C01014': 'C9H12O2',
#  'C01015': 'C5H9NO3',
#  'C01017': 'C11H12N2O3',
#  'C01018': 'C6H12O5',
#  'C01019': 'C6H12O5',
#  'C01020': 'C6H5NO3',
#  'C01023': 'C21H41N7O12',
#  'C01024': 'C40H46N4O17',
#  'C01026': 'C4H9NO2',
#  'C01028': 'C6H14N2O3',
#  'C01029': 'C9H21N3O',
#  'C01031': 'C11H17N3O7S',
#  'C01033': 'C26H44N7O17P3S',
#  'C01034': 'C19H28O',
#  'C01035': 'C5H11N3O2',
#  'C01036': 'C8H8O6',
#  'C01037': 'C9H20N2O2',
#  'C01040': 'C6H10O6',
#  'C01041': 'C6H7O6',
#  'C01042': 'C6H9NO5',
#  'C01043': 'C4H8N2O3',
#  'C01044': 'C5H7NO5',
#  'C01045': 'C6H9NO5',
#  'C01046': 'C6H11NO4',
#  'C01047': 'C7H14N2O3',
#  'C01050': 'C20H31N3O19P2',
#  'C01051': 'C40H44N4O16',
#  'C01053': 'C6H10O4',
#  'C01054': 'C30H50O',
#  'C01056': 'C10H14N2O',
#  'C01059': 'C5H5NO2',
#  'C01060': 'C9H9I2NO3',
#  'C01061': 'C8H8O6',
#  'C01062': 'C6H10O7',
#  'C01063': 'C28H46N7O19P3S',
#  'C01066': 'C6H8O2',
#  'C01067': 'C6H12O9S',
#  'C01068': 'C5H13O8P',
#  'C01069': 'C14H19NO6S',
#  'C01073': 'C5H9NO3',
#  'C01075': 'C6H13NO8S',
#  'C01077': 'C6H11NO4',
#  'C01079': 'C34H40N4O4',
#  'C01080': 'C29H38N5O18P',
#  'C01081': 'C12H18N4O4PS',
#  'C01083': 'C12H22O11',
#  'C01087': 'C5H8O5',
#  'C01088': 'C6H10O5',
#  'C01089': 'C4H8O3',
#  'C01090': 'C19H32O2',
#  'C01091': 'C23H30N2O5',
#  'C01092': 'C9H17NO3',
#  'C01093': 'C12H20O11',
#  'C01094': 'C6H13O9P',
#  'C01095': 'C5H12O11P2',
#  'C01096': 'C6H15O9P',
#  'C01097': 'C6H13O9P',
#  'C01099': 'C6H13O8P',
#  'C01100': 'C6H12N3O4P',
#  'C01101': 'C5H11O8P',
#  'C01102': 'C4H10NO6P',
#  'C01103': 'C10H13N2O11P',
#  'C01104': 'C3H9NO',
#  'C01107': 'C6H13O7P',
#  'C01108': 'C6H6O3',
#  'C01109': 'C6H10N2O3',
#  'C01110': 'C5H9NO3',
#  'C01111': 'C10H7NO5',
#  'C01112': 'C5H11O8P',
#  'C01113': 'C6H13O9P',
#  'C01114': 'C5H8O5',
#  'C01115': 'C6H10O6',
#  'C01118': 'C8H13NO6',
#  'C01119': 'C4H8O2S2',
#  'C01120': 'C18H40NO5P',
#  'C01121': 'C8H19N6O7P',
#  'C01123': 'C10H16O',
#  'C01124': 'C21H30O5',
#  'C01125': 'C6H8O3',
#  'C01126': 'C15H26O',
#  'C01127': 'C5H6O6',
#  'C01131': 'C6H13O8P',
#  'C01132': 'C8H15NO6',
#  'C01133': 'C8H15NO7',
#  'C01134': 'C11H23N2O7PS',
#  'C01136': 'C10H19NO2S2',
#  'C01137': 'C14H23N6O3S',
#  'C01138': 'C21H40N7O15P',
#  'C01142': 'C6H14N2O2',
#  'C01143': 'C6H14O10P2',
#  'C01144': 'C25H42N7O18P3S',
#  'C01146': 'C3H4O4',
#  'C01147': 'C6H10O2',
#  'C01149': 'C7H16NO',
#  'C01151': 'C5H12O11P2',
#  'C01152': 'C7H11N3O2',
#  'C01155': 'C15H10O13S2',
#  'C01156': 'C15H10O13S2',
#  'C01157': 'C5H9NO3',
#  'C01158': 'C13H16O10',
#  'C01159': 'C3H8O10P2',
#  'C01161': 'C8H8O4',
#  'C01162': 'C6H9N3O2',
#  'C01163': 'C7H6O6',
#  'C01164': 'C27H44O',
#  'C01165': 'C5H9NO3',
#  'C01168': 'C9H13N2O9P',
#  'C01169': 'C12H21NO4S2',
#  'C01170': 'C17H27N3O17P2',
#  'C01171': 'C6H13O9P',
#  'C01172': 'C6H13O9P',
#  'C01173': 'C10H8O3',
#  'C01175': 'C17H22O10',
#  'C01176': 'C21H30O3',
#  'C01177': 'C6H13O9P',
#  'C01179': 'C9H8O4',
#  'C01180': 'C5H8O3S',
#  'C01181': 'C7H16NO2',
#  'C01182': 'C5H12O11P2',
#  'C01183': 'C8H11NO',
#  'C01185': 'C11H15NO9P',
#  'C01186': 'C6H14N2O2',
#  'C01187': 'C8H14O8',
#  'C01188': 'C4H8O3',
#  'C01189': 'C27H46O',
#  'C01192': 'C19H37O7P',
#  'C01197': 'C9H8O4',
#  'C01198': 'C9H10O3',
#  'C01201': 'C21H35N9O15P2',
#  'C01204': 'C6H18O24P6',
#  'C01205': 'C4H9NO2',
#  'C01207': 'C9H10O5',
#  'C01210': 'C3H10NO4P',
#  'C01212': 'C23H36N4O20P2',
#  'C01213': 'C25H40N7O19P3S',
#  'C01214': 'C6H13NO5',
#  'C01215': 'C7H9NO5',
#  'C01216': 'C6H10O6',
#  'C01217': 'C30H45N6O16P',
#  'C01218': 'C6H11O10P',
#  'C01219': 'C15H23N3O15P2',
#  'C01220': 'C6H14O12P2',
#  'C01221': 'C21H42N7O15P',
#  'C01222': 'C16H23N5O15P2',
#  'C01223': 'C9H16N3O3',
#  'C01225': 'C9H19O11P',
#  'C01226': 'C18H28O3',
#  'C01227': 'C19H28O2',
#  'C01228': 'C10H17N5O17P4',
#  'C01230': 'C30H52O7P2',
#  'C01231': 'C6H14O12P2',
#  'C01233': 'C5H14NO6P',
#  'C01234': 'C4H7NO2',
#  'C01235': 'C12H22O11',
#  'C01236': 'C6H11O9P',
#  'C01239': 'C8H16N2O5',
#  'C01243': 'C6H15O15P3',
#  'C01244': 'C9H6I2O4',
#  'C01245': 'C6H15O15P3',
#  'C01249': 'C10H9NO5',
#  'C01250': 'C7H11NO4',
#  'C01251': 'C7H10O7',
#  'C01252': 'C10H9NO4',
#  'C01255': 'C12H24N2O3',
#  'C01259': 'C9H21N2O3',
#  'C01260': 'C20H28N10O19P4',
#  'C01261': 'C20H28N10O21P4',
#  'C01262': 'C10H16N4O3',
#  'C01263': 'C15H12O5',
#  'C01265': 'C17H14O7',
#  'C01266': 'C21H42N7O14P',
#  'C01267': 'C6H9N2O5P',
#  'C01268': 'C9H15N4O9P',
#  'C01269': 'C10H13O10P',
#  'C01270': 'C7H7NO3',
#  'C01272': 'C6H16O18P4',
#  'C01273': 'C12H10O4',
#  'C01274': 'C31H45N6O17P',
#  'C01275': 'C11H8O5',
#  'C01278': 'C7H6O6',
#  'C01279': 'C6H9N3O',
#  'C01280': 'C21H43N7O18P2',
#  'C01283': 'C6H14NO8P',
#  'C01284': 'C6H17O21P5',
#  'C01285': 'C16H11Cl2NO2',
#  'C01286': 'C6H11O9P',
#  'C01289': 'C63H105NO12P2',
#  'C01291': 'C32H50N7O19P3S',
#  'C01292': 'C24H38O5',
#  'C01294': 'C7H16N3O8P',
#  'C01295': 'C7H12O6',
#  'C01297': 'C10H14N2O2',
#  'C01298': 'C7H16N4O4',
#  'C01300': 'C7H9N5O2',
#  'C01301': 'C27H46O4',
#  'C01302': 'C12H16NO9P',
#  'C01304': 'C9H16N5O8P',
#  'C01310': 'C14H21NO11',
#  'C01312': 'C20H32O5',
#  'C01313': 'C15H18N2O6S',
#  'C01314': 'C16H20N2O6S',
#  'C01315': 'C24H26N2O7S',
#  'C01316': 'C25H28N2O7S',
#  'C01324': 'Br',
#  'C01326': 'CHN',
#  'C01327': 'HCl',
#  'C01328': 'OH',
#  'C01330': 'Na',
#  'C01337': 'C10H14N4O12P2',
#  'C01341': 'C15H27N5O5',
#  'C01342': 'NH4',
#  'C01344': 'C10H14N4O10P2',
#  'C01345': 'C10H15N4O13P3',
#  'C01346': 'C9H14N2O11P2',
#  'C01347': 'C10H14N4O11P2',
#  'C01348': 'C10H15N4O14P3',
#  'C01349': 'C21H26O3',
#  'C01352': 'C27H35N9O15P2',
#  'C01353': 'H2CO3',
#  'C01359': 'C14H8N2O8',
#  'C01367': 'C10H14N5O7P',
#  'C01368': 'C9H13N2O9P',
#  'C01375': 'C44H69NO12',
#  'C01378': 'C15H12O6',
#  'C01380': 'C2H6O2',
#  'C01382': 'I2',
#  'C01384': 'C4H4O4',
#  'C01386': 'C10H9NO2',
#  'C01387': 'C8H18',
#  'C01389': 'C20H40O',
#  'C01390': 'C5H10O',
#  'C01394': 'C5H10O5',
#  'C01397': 'C21H31F3O',
#  'C01401': 'C3H7NO2',
#  'C01403': 'C7H8O',
#  'C01404': 'C8H18N4O2',
#  'C01405': 'C9H8O4',
#  'C01407': 'C6H6',
#  'C01408': 'C14H12O2',
#  'C01410': 'C9H16N2O5',
#  'C01411': 'C10H18O',
#  'C01412': 'C4H8O',
#  'C01414': 'C20H32',
#  'C01416': 'C17H21NO4',
#  'C01417': 'CHNO',
#  'C01418': 'C8H16N2O7',
#  'C01419': 'C5H10N2O3S',
#  'C01420': 'C6H12N2O4S2',
#  'C01421': 'C15H16O9',
#  'C01424': 'C7H6O5',
#  'C01425': 'C10H16N2O7',
#  'C01432': 'C3H6O3',
#  'C01433': 'C17H26O10',
#  'C01438': 'CH4',
#  'C01441': 'C12H26N4O6',
#  'C01443': 'C29H44O12',
#  'C01444': 'C2H3NO3',
#  'C01448': 'C16H12O5',
#  'C01449': 'C12H15N5O3',
#  'C01451': 'C13H18O7',
#  'C01452': 'C6H12O6',
#  'C01453': 'C13H14N2',
#  'C01454': 'C8H8O2',
#  'C01455': 'C7H8',
#  'C01456': 'C9H10O3',
#  'C01457': 'C46H77NO17',
#  'C01458': 'C11H15NO3',
#  'C01460': 'C21H20O10',
#  'C01464': 'C13H10O',
#  'C01467': 'C7H8O',
#  'C01468': 'C7H8O',
#  'C01470': 'C16H12O5',
#  'C01471': 'C3H4O',
#  'C01474': 'C14H8O4',
#  'C01477': 'C15H10O5',
#  'C01478': 'H3AsO4',
#  'C01479': 'C17H23NO3',
#  'C01481': 'C9H8O4',
#  'C01484': 'C15H12O',
#  'C01485': 'HClO3',
#  'C01486': 'HClO2',
#  'C01487': 'C6H12O6',
#  'C01488': 'C5H10O5',
#  'C01489': 'C6H14O6',
#  'C01494': 'C10H10O4',
#  'C01495': 'C15H10O3',
#  'C01499': 'C10H16O',
#  'C01500': 'C10H18O',
#  'C01501': 'C153H225N43O49S',
#  'C01502': 'C7H8O2',
#  'C01504': 'C9H8O',
#  'C01505': 'C56H85N17O12',
#  'C01507': 'C6H14O6',
#  'C01508': 'C5H10O5',
#  'C01510': 'C5H10O5',
#  'C01512': 'C16H24O10',
#  'C01513': 'C13H18N6O3',
#  'C01514': 'C15H10O6',
#  ...}

# %%
cmpd_id_pw_dict
# Out:
# {'C00022': ['map00010',
#   'map00020',
#   'map00030',
#   'map00040',
#   'map00053',
#   'map00250',
#   'map00260',
#   'map00270',
#   'map00290',
#   'map00330',
#   'map00350',
#   'map00360',
#   'map00362',
#   'map00430',
#   'map00440',
#   'map00473',
#   'map00620',
#   'map00621',
#   'map00622',
#   'map00630',
#   'map00650',
#   'map00660',
#   'map00680',
#   'map00710',
#   'map00720',
#   'map00730',
#   'map00750',
#   'map00760',
#   'map00770',
#   'map00900',
#   'map02060',
#   'map04066',
#   'map04911',
#   'map04930',
#   'ingenza00003'],
#  'C00024': ['map00010',
#   'map00020',
#   'map00061',
#   'map00062',
#   'map00071',
#   'map00072',
#   'map00253',
#   'map00254',
#   'map00280',
#   'map00290',
#   'map00300',
#   'map00310',
#   'map00360',
#   'map00362',
#   'map00380',
#   'map00410',
#   'map00430',
#   'map00480',
#   'map00562',
#   'map00620',
#   'map00621',
#   'map00622',
#   'map00625',
#   'map00630',
#   'map00640',
#   'map00642',
#   'map00650',
#   'map00680',
#   'map00720',
#   'map00900',
#   'map01056',
#   'map04066',
#   'map04725',
#   'map04976',
#   'ingenza00003'],
#  'C00031': ['map00010',
#   'map00030',
#   'map00052',
#   'map00500',
#   'map00520',
#   'map00521',
#   'map00524',
#   'map00901',
#   'map02010',
#   'map02020',
#   'map02060',
#   'map04066',
#   'map04068',
#   'map04113',
#   'map04910',
#   'map04911',
#   'map04917',
#   'map04930',
#   'map04932',
#   'map04973',
#   'map04976',
#   'map04978'],
#  'C00033': ['map00010',
#   'map00430',
#   'map00440',
#   'map00534',
#   'map00620',
#   'map00660',
#   'map00680',
#   'map00720',
#   'map00908',
#   'map00920',
#   'map04725',
#   'map04973',
#   'map04974'],
#  'C00036': ['map00010',
#   'map00020',
#   'map00250',
#   'map00362',
#   'map00620',
#   'map00630',
#   'map00680',
#   'map00710',
#   'map00720',
#   'map02020',
#   'map04964'],
#  'C00068': ['map00010',
#   'map00020',
#   'map00280',
#   'map00620',
#   'map00730',
#   'map04977'],
#  'C00074': ['map00010',
#   'map00020',
#   'map00400',
#   'map00440',
#   'map00620',
#   'map00680',
#   'map00710',
#   'map00720',
#   'map02060',
#   'map04964'],
#  'C00084': ['map00010',
#   'map00360',
#   'map00362',
#   'map00440',
#   'map00564',
#   'map00620',
#   'map00621',
#   'map00622',
#   'map00625'],
#  'C00103': ['map00010',
#   'map00040',
#   'map00052',
#   'map00500',
#   'map00520',
#   'map00521',
#   'map00523'],
#  'C00111': ['map00010',
#   'map00040',
#   'map00051',
#   'map00052',
#   'map00561',
#   'map00562',
#   'map00564',
#   'map00620',
#   'map00680',
#   'map00710',
#   'map00760',
#   'ingenza00001',
#   'ingenza00002'],
#  'C00118': ['map00010',
#   'map00030',
#   'map00051',
#   'map00052',
#   'map00331',
#   'map00562',
#   'map00680',
#   'map00710',
#   'map00730',
#   'map00750',
#   'map00900'],
#  'C00186': ['map00010', 'map00620', 'map00640', 'map00643', 'map04066'],
#  'C00197': ['map00010',
#   'map00260',
#   'map00561',
#   'map00630',
#   'map00680',
#   'map00710'],
#  'C00221': ['map00010', 'map00030', 'map00500'],
#  'C00236': ['map00010', 'map00710'],
#  'C00267': ['map00010',
#   'map00051',
#   'map00052',
#   'map00500',
#   'map00520',
#   'map04964'],
#  'C00469': ['map00010', 'map05034'],
#  'C00631': ['map00010', 'map00030', 'map00260', 'map00680'],
#  'C00668': ['map00010', 'map00030', 'map00052', 'map00500', 'map00520'],
#  'C01159': ['map00010'],
#  'C01172': ['map00010', 'map00030', 'map00500'],
#  'C01451': ['map00010', 'map02060'],
#  'C05125': ['map00010', 'map00020', 'map00620'],
#  'C05345': ['map00010', 'map00030', 'map00051', 'map00500', 'map00520'],
#  'C05378': ['map00010', 'map00030', 'map00051'],
#  'C06186': ['map00010', 'map02060'],
#  'C06187': ['map00010', 'map02060'],
#  'C06188': ['map00010', 'map02060'],
#  'C15972': ['map00010', 'map00020', 'map00280', 'map00620'],
#  'C15973': ['map00010', 'map00020', 'map00280', 'map00620'],
#  'C16255': ['map00010', 'map00020', 'map00620'],
#  'C00026': ['map00020',
#   'map00040',
#   'map00053',
#   'map00250',
#   'map00300',
#   'map00340',
#   'map00365',
#   'map00430',
#   'map00471',
#   'map00630',
#   'map00650',
#   'map00660',
#   'map00720',
#   'map00750',
#   'map04066',
#   'map04727',
#   'map04964',
#   'map04976'],
#  'C00042': ['map00020',
#   'map00190',
#   'map00250',
#   'map00350',
#   'map00360',
#   'map00361',
#   'map00623',
#   'map00630',
#   'map00640',
#   'map00650',
#   'map00720',
#   'map00920',
#   'map02020',
#   'map04727'],
#  'C00091': ['map00020',
#   'map00280',
#   'map00360',
#   'map00362',
#   'map00623',
#   'map00626',
#   'map00630',
#   'map00640',
#   'map00650',
#   'map00720',
#   'ingenza00005'],
#  'C00122': ['map00020',
#   'map00190',
#   'map00250',
#   'map00330',
#   'map00350',
#   'map00360',
#   'map00623',
#   'map00643',
#   'map00650',
#   'map00720',
#   'map00760',
#   'map02020',
#   'map05200',
#   'map05211'],
#  'C00149': ['map00020',
#   'map00620',
#   'map00630',
#   'map00680',
#   'map00710',
#   'map00720',
#   'map02020',
#   'map04964',
#   'map05200',
#   'map05211'],
#  'C00158': ['map00020', 'map00630', 'map00720', 'map02020'],
#  'C00311': ['map00020', 'map00630', 'map00720'],
#  'C00417': ['map00020', 'map00630', 'map00660', 'map00720'],
#  'C05379': ['map00020'],
#  'C05381': ['map00020'],
#  'C16254': ['map00020'],
#  'C00117': ['map00030', 'map00230', 'map00710', 'map04918'],
#  'C00119': ['map00030', 'map00230', 'map00240', 'map00340', 'map00400'],
#  'C00121': ['map00030', 'map02010', 'map02030'],
#  'C00198': ['map00030'],
#  'C00199': ['map00030',
#   'map00040',
#   'map00680',
#   'map00710',
#   'map00740',
#   'map00750'],
#  'C00204': ['map00030', 'map00040'],
#  'C00231': ['map00030',
#   'map00040',
#   'map00053',
#   'map00680',
#   'map00710',
#   'map04918'],
#  'C00257': ['map00030'],
#  'C00258': ['map00030', 'map00260', 'map00561', 'map00630', 'map00680'],
#  'C00279': ['map00030', 'map00400', 'map00710', 'map00750'],
#  'C00345': ['map00030'],
#  'C00577': ['map00030', 'map00051', 'map00561'],
#  'C00620': ['map00030', 'map00230'],
#  'C00672': ['map00030', 'map00240'],
#  'C00673': ['map00030'],
#  'C01151': ['map00030', 'map00440'],
#  'C01218': ['map00030'],
#  'C01236': ['map00030'],
#  'C01801': ['map00030'],
#  'C03752': ['map00030', 'map02060'],
#  'C04442': ['map00030'],
#  'C05382': ['map00030', 'map00540', 'map00710'],
#  'C06019': ['map00030', 'map00680'],
#  'C06473': ['map00030'],
#  'C20589': ['map00030', 'map02060'],
#  'C00029': ['map00040',
#   'map00052',
#   'map00053',
#   'map00240',
#   'map00500',
#   'map00520',
#   'map00561',
#   'map00908',
#   'map01051'],
#  'C00167': ['map00040', 'map00053', 'map00500', 'map00520'],
#  'C00181': ['map00040', 'map00500', 'map00520', 'map02010'],
#  'C00191': ['map00040', 'map00053', 'map00500', 'map00520', 'map00562'],
#  'C00259': ['map00040', 'map00053', 'map00520', 'map02010'],
#  'C00266': ['map00040', 'map00630', 'map00750', 'map00790'],
#  'C00309': ['map00040'],
#  'C00310': ['map00040'],
#  'C00312': ['map00040'],
#  'C00333': ['map00040', 'map00053', 'map00500', 'map00520', 'map02010'],
#  'C00379': ['map00040', 'map02010'],
#  'C00433': ['map00040', 'map00053', 'map00330'],
#  'C00470': ['map00040', 'map00500', 'map02010'],
#  'C00474': ['map00040', 'map00740'],
#  'C00476': ['map00040'],
#  'C00502': ['map00040'],
#  'C00508': ['map00040'],
#  'C00514': ['map00040'],
#  'C00532': ['map00040'],
#  'C00558': ['map00040'],
#  'C00618': ['map00040', 'map00053'],
#  'C00714': ['map00040', 'map00500', 'map00520', 'map04973'],
#  'C00789': ['map00040'],
#  'C00800': ['map00040', 'map00053'],
#  'C00817': ['map00040'],
#  'C00905': ['map00040'],
#  'C01068': ['map00040'],
#  'C01101': ['map00040', 'map00053'],
#  'C01508': ['map00040'],
#  'C01904': ['map00040'],
#  'C02266': ['map00040'],
#  'C02273': ['map00040', 'map02010'],
#  'C03033': ['map00040', 'map00500', 'map04976'],
#  'C03291': ['map00040', 'map00053'],
#  'C03826': ['map00040', 'map00053'],
#  'C04053': ['map00040'],
#  'C04349': ['map00040'],
#  'C04575': ['map00040', 'map00053'],
#  'C05385': ['map00040', 'map00053', 'map00520'],
#  'C05411': ['map00040', 'map00053'],
#  'C05412': ['map00040', 'map00053'],
#  'C06118': ['map00040'],
#  'C06441': ['map00040'],
#  'C14899': ['map00040', 'map00053'],
#  'C00095': ['map00051',
#   'map00052',
#   'map00500',
#   'map02010',
#   'map02060',
#   'map04973'],
#  'C00096': ['map00051', 'map00053', 'map00510', 'map00520'],
#  'C00159': ['map00051',
#   'map00052',
#   'map00520',
#   'map02010',
#   'map02060',
#   'map04142'],
#  'C00247': ['map00051'],
#  'C00275': ['map00051', 'map00520', 'map02060', 'map04142'],
#  'C00325': ['map00051', 'map00520'],
#  'C00392': ['map00051', 'map02010', 'map02060'],
#  'C00424': ['map00051', 'map00620', 'ingenza00002'],
#  'C00464': ['map00051'],
#  'C00507': ['map00051'],
#  'C00636': ['map00051', 'map00520'],
#  'C00644': ['map00051', 'map02060'],
#  'C00665': ['map00051'],
#  'C00794': ['map00051', 'map00052', 'map02010', 'map02060'],
#  'C00861': ['map00051'],
#  'C00937': ['map00051', 'map00620'],
#  'C00976': ['map00051', 'map00520'],
#  'C01019': ['map00051', 'map00520'],
#  'C01094': ['map00051', 'map00400', 'map02060'],
#  'C01096': ['map00051', 'map02060'],
#  'C01099': ['map00051'],
#  'C01131': ['map00051'],
#  'C01222': ['map00051', 'map00520'],
#  'C01355': ['map00051', 'map04973'],
#  'C01487': ['map00051', 'map02010'],
#  'C01680': ['map00051'],
#  'C01721': ['map00051'],
#  'C01768': ['map00051'],
#  'C01934': ['map00051'],
#  'C02431': ['map00051'],
#  'C02492': ['map00051'],
#  'C02888': ['map00051', 'map02060'],
#  'C02962': ['map00051'],
#  'C02977': ['map00051', 'map00520'],
#  'C02985': ['map00051', 'map00520'],
#  'C02991': ['map00051'],
#  'C03117': ['map00051', 'map00520'],
#  'C03267': ['map00051'],
#  'C03979': ['map00051'],
#  'C05392': ['map00051'],
#  'C06159': ['map00051'],
#  'C06192': ['map00051'],
#  'C11516': ['map00051'],
#  'C11544': ['map00051', 'map02060'],
#  'C18096': ['map00051'],
#  'C00052': ['map00052', 'map00520'],
#  'C00089': ['map00052',
#   'map00500',
#   'map02010',
#   'map02060',
#   'map04742',
#   'map04973'],
#  'C00116': ['map00052', 'map00561', 'map02010', 'map04723', 'ingenza00001'],
#  'C00124': ['map00052', 'map00520', 'map02030', 'map04973', 'map04978'],
#  'C00137': ['map00052',
#   'map00053',
#   'map00521',
#   'map00562',
#   'map02010',
#   'map04070'],
#  'C00243': ['map00052', 'map02010', 'map02060', 'map04973'],
#  'C00446': ['map00052', 'map00520'],
#  'C00492': ['map00052', 'map02010'],
#  'C00795': ['map00052'],
#  'C00880': ['map00052'],
#  'C01097': ['map00052'],
#  'C01113': ['map00052'],
#  'C01132': ['map00052', 'map02060'],
#  'C01216': ['map00052'],
#  'C01235': ['map00052'],
#  'C01286': ['map00052'],
#  'C01613': ['map00052'],
#  'C01697': ['map00052', 'map02060'],
#  'C02262': ['map00052', 'map02060'],
#  'C03383': ['map00052'],
#  'C03785': ['map00052'],
#  'C05396': ['map00052', 'map02060'],
#  'C05399': ['map00052'],
#  'C05400': ['map00052'],
#  'C05401': ['map00052', 'map00561'],
#  'C05402': ['map00052', 'map02010'],
#  'C05404': ['map00052'],
#  'C05796': ['map00052'],
#  'C06311': ['map00052', 'map02060'],
#  'C06376': ['map00052', 'map02060'],
#  'C06377': ['map00052', 'map02060'],
#  'C00072': ['map00053', 'map00480', 'map02060', 'map04066', 'map04977'],
#  'C00545': ['map00053'],
#  'C00679': ['map00053'],
#  'C00684': ['map00053'],
#  'C00818': ['map00053'],
#  'C00879': ['map00053'],
#  'C01040': ['map00053'],
#  'C01041': ['map00053'],
#  'C01114': ['map00053'],
#  'C01115': ['map00053'],
#  'C01146': ['map00053', 'map00630'],
#  'C01620': ['map00053'],
#  'C01825': ['map00053'],
#  'C02280': ['map00053', 'map00520'],
#  'C02670': ['map00053'],
#  'C03064': ['map00053'],
#  'C03289': ['map00053'],
#  'C03921': ['map00053'],
#  'C05406': ['map00053'],
#  'C05422': ['map00053', 'map00480'],
#  'C15923': ['map00053'],
#  'C15924': ['map00053'],
#  'C15925': ['map00053', 'map00520'],
#  'C15926': ['map00053'],
#  'C15930': ['map00053'],
#  'C16186': ['map00053', 'map02060'],
#  'C00083': ['map00061',
#   'map00062',
#   'map00253',
#   'map00254',
#   'map00360',
#   'map00410',
#   'map00522',
#   'map00620',
#   'map00640',
#   'map00720',
#   'map01055',
#   'map01056',
#   'map04920'],
#  'C00229': ['map00061', 'map00071', 'map00524', 'map00540', 'map00770'],
#  'C00249': ['map00061', 'map00062', 'map00071', 'map00073', 'map01040'],
#  'C00712': ['map00061', 'map00073', 'map01040'],
#  'C01203': ['map00061', 'map01040'],
#  'C01209': ['map00061', 'map00780'],
#  'C01530': ['map00061', 'map01040', 'map04745'],
#  'C01571': ['map00061'],
#  'C02679': ['map00061'],
#  'C03939': ['map00061'],
#  'C04088': ['map00061', 'map01040'],
#  'C04246': ['map00061'],
#  'C04419': ['map00061'],
#  'C04618': ['map00061'],
#  'C04619': ['map00061'],
#  'C04620': ['map00061'],
#  'C04633': ['map00061'],
#  'C04688': ['map00061'],
#  'C05223': ['map00061', 'map00540'],
#  'C05744': ['map00061'],
#  'C05745': ['map00061'],
#  'C05746': ['map00061'],
#  'C05747': ['map00061'],
#  'C05748': ['map00061'],
#  'C05749': ['map00061'],
#  'C05750': ['map00061'],
#  'C05751': ['map00061'],
#  'C05752': ['map00061', 'map00785'],
#  'C05753': ['map00061'],
#  'C05754': ['map00061'],
#  'C05755': ['map00061'],
#  'C05756': ['map00061'],
#  'C05757': ['map00061'],
#  'C05758': ['map00061'],
#  'C05759': ['map00061'],
#  'C05760': ['map00061'],
#  'C05761': ['map00061', 'map00540'],
#  'C05762': ['map00061'],
#  'C05763': ['map00061'],
#  'C05764': ['map00061', 'map01040'],
#  'C06250': ['map00061', 'map00780'],
#  'C06423': ['map00061'],
#  'C06424': ['map00061'],
#  'C08362': ['map00061'],
#  'C16219': ['map00061'],
#  'C16220': ['map00061'],
#  'C16221': ['map00061'],
#  'C16520': ['map00061'],
#  'C00040': ['map00062', 'map00561', 'map00564', 'map04920', 'map04975'],
#  'C00136': ['map00062', 'map00071', 'map00630', 'map00650', 'map01056'],
#  'C00154': ['map00062', 'map00071', 'map00563', 'map00600', 'map01040'],
#  'C00162': ['map00062',
#   'map00071',
#   'map00561',
#   'map04911',
#   'map04920',
#   'map04930',
#   'map04932',
#   'map04975',
#   'map04977'],
#  'C00264': ['map00062'],
#  'C00605': ['map00062'],
#  'C00638': ['map00062', 'map00071', 'map04920'],
#  'C00640': ['map00062'],
#  'C00658': ['map00062'],
#  'C01832': ['map00062', 'map00071'],
#  'C01944': ['map00062', 'map00071'],
#  'C02593': ['map00062', 'map00071'],
#  'C02843': ['map00062', 'map00073'],
#  'C03221': ['map00062', 'map00071'],
#  'C05258': ['map00062', 'map00071'],
#  'C05259': ['map00062', 'map00071'],
#  'C05260': ['map00062', 'map00071'],
#  'C05261': ['map00062', 'map00071'],
#  'C05262': ['map00062', 'map00071'],
#  'C05263': ['map00062', 'map00071'],
#  'C05264': ['map00062', 'map00071'],
#  'C05265': ['map00062', 'map00071'],
#  'C05266': ['map00062', 'map00071'],
#  'C05267': ['map00062', 'map00071'],
#  'C05268': ['map00062', 'map00071'],
#  'C05269': ['map00062', 'map00071'],
#  'C05270': ['map00062', 'map00071'],
#  'C05271': ['map00062', 'map00071'],
#  'C05272': ['map00062', 'map00071'],
#  'C05273': ['map00062', 'map00071'],
#  'C05274': ['map00062', 'map00071'],
#  'C05275': ['map00062', 'map00071'],
#  'C05276': ['map00062', 'map00071'],
#  'C00010': ['map00071', 'map00770', 'map04725', 'map04975', 'map04977'],
#  'C00071': ['map00071'],
#  'C00226': ['map00071', 'map00073'],
#  'C00332': ['map00071',
#   'map00072',
#   'map00280',
#   'map00310',
#   'map00362',
#   'map00380',
#   'map00620',
#   'map00630',
#   'map00640',
#   'map00650',
#   'map00720',
#   'map00900'],
#  'C00340': ['map00071'],
#  'C00435': ['map00071'],
#  'C00489': ['map00071', 'map00310'],
#  'C00517': ['map00071'],
#  'C00527': ['map00071', 'map00310', 'map00362', 'map00380'],
#  'C00823': ['map00071'],
#  'C00877': ['map00071',
#   'map00310',
#   'map00362',
#   'map00380',
#   'map00627',
#   'map00630',
#   'map00650',
#   'map00720'],
#  'C01144': ['map00071',
#   'map00310',
#   'map00362',
#   'map00380',
#   'map00627',
#   'map00650',
#   'map00720'],
#  'C01371': ['map00071', 'map00073'],
#  'C02990': ['map00071'],
#  'C03547': ['map00071'],
#  'C03561': ['map00071', 'map00630', 'map00650'],
#  'C05102': ['map00071'],
#  'C05279': ['map00071'],
#  'C05280': ['map00071'],
#  'C20683': ['map00071', 'map00780'],
#  'C00164': ['map00072',
#   'map00280',
#   'map00350',
#   'map00640',
#   'map00643',
#   'map00650',
#   'map02020'],
#  'C00207': ['map00072', 'map00640'],
#  'C00356': ['map00072', 'map00280', 'map00650', 'map00900', 'map07024'],
#  'C01089': ['map00072', 'map00650'],
#  'C00406': ['map00073',
#   'map00330',
#   'map00360',
#   'map00940',
#   'map00941',
#   'map00945'],
#  'C00609': ['map00073'],
#  'C01450': ['map00073'],
#  'C01612': ['map00073'],
#  'C01629': ['map00073'],
#  'C08281': ['map00073', 'map01040'],
#  'C08285': ['map00073'],
#  'C18217': ['map00073'],
#  'C18218': ['map00073'],
#  'C19418': ['map00073'],
#  'C19614': ['map00073'],
#  'C19615': ['map00073'],
#  'C19616': ['map00073'],
#  'C19617': ['map00073'],
#  'C19618': ['map00073'],
#  'C19620': ['map00073'],
#  'C19621': ['map00073'],
#  'C19622': ['map00073'],
#  'C19623': ['map00073'],
#  'C19624': ['map00073'],
#  'C19625': ['map00073'],
#  'C19630': ['map00073'],
#  'C00187': ['map00100',
#   'map00120',
#   'map00140',
#   'map00981',
#   'map00984',
#   'map04340',
#   'map04913',
#   'map04975',
#   'map04976',
#   'map04977',
#   'map05200',
#   'map05217'],
#  'C00448': ['map00100', 'map00900', 'map00906', 'map00909', 'map00981'],
#  'C00751': ['map00100', 'map00909'],
#  'C01054': ['map00100', 'map00909'],
#  'C01164': ['map00100', 'map00981'],
#  'C01189': ['map00100'],
#  'C01561': ['map00100', 'map05152'],
#  'C01673': ['map00100', 'map04961', 'map04978', 'map05152'],
#  'C01694': ['map00100'],
#  'C01724': ['map00100'],
#  'C01753': ['map00100'],
#  'C01789': ['map00100', 'map00905'],
#  'C01802': ['map00100'],
#  'C01902': ['map00100'],
#  'C01943': ['map00100'],
#  'C02141': ['map00100'],
#  'C02530': ['map00100', 'map04913', 'map04975', 'map04976', 'map04977'],
#  'C03428': ['map00100', 'map00906', 'map00909'],
#  'C03845': ['map00100'],
#  'C04525': ['map00100'],
#  'C05103': ['map00100'],
#  'C05107': ['map00100'],
#  'C05108': ['map00100'],
#  'C05109': ['map00100'],
#  'C05437': ['map00100'],
#  'C05439': ['map00100'],
#  'C05440': ['map00100'],
#  'C05441': ['map00100'],
#  'C05442': ['map00100'],
#  'C05443': ['map00100', 'map04977', 'map05323'],
#  'C07712': ['map00100'],
#  'C08821': ['map00100'],
#  'C08830': ['map00100'],
#  'C11455': ['map00100'],
#  'C11508': ['map00100'],
#  'C11522': ['map00100'],
#  'C11523': ['map00100'],
#  'C15776': ['map00100'],
#  'C15777': ['map00100'],
#  'C15778': ['map00100'],
#  'C15780': ['map00100'],
#  'C15781': ['map00100'],
#  'C15782': ['map00100'],
#  'C15783': ['map00100'],
#  'C15808': ['map00100'],
#  'C15816': ['map00100'],
#  'C15915': ['map00100'],
#  'C18231': ['map00100'],
#  'C00037': ['map00120',
#   'map00230',
#   'map00260',
#   'map00310',
#   'map00460',
#   'map00480',
#   'map00630',
#   'map00680',
#   'map00730',
#   'map00860',
#   'map00970',
#   'map02010',
#   'map04080',
#   'map04721',
#   'map04974',
#   'map04978'],
#  'C00245': ['map00120', 'map00430', 'map00920', 'map02010', 'map04080'],
#  'C00695': ['map00120', 'map00121', 'map04976'],
#  'C01301': ['map00120'],
#  'C01794': ['map00120'],
#  'C01921': ['map00120', 'map00121', 'map04976'],
#  'C02528': ['map00120', 'map00121', 'map04976'],
#  'C03594': ['map00120'],
#  'C04554': ['map00120'],
#  'C04722': ['map00120'],
#  'C05122': ['map00120', 'map00121', 'map00430', 'map04976'],
#  'C05337': ['map00120', 'map00121'],
#  'C05444': ['map00120'],
#  'C05445': ['map00120'],
#  'C05446': ['map00120'],
#  'C05447': ['map00120'],
#  'C05448': ['map00120'],
#  'C05449': ['map00120'],
#  'C05450': ['map00120'],
#  'C05451': ['map00120'],
#  'C05452': ['map00120'],
#  'C05453': ['map00120'],
#  'C05454': ['map00120'],
#  'C05455': ['map00120'],
#  'C05460': ['map00120'],
#  'C05465': ['map00120', 'map00121', 'map04976'],
#  'C05466': ['map00120', 'map00121', 'map04976'],
#  'C05467': ['map00120'],
#  'C05468': ['map00120'],
#  'C06341': ['map00120'],
#  'C13550': ['map00120'],
#  'C15518': ['map00120'],
#  'C15519': ['map00120'],
#  'C15520': ['map00120'],
#  'C15610': ['map00120'],
#  'C15613': ['map00120'],
#  'C17331': ['map00120'],
#  'C17332': ['map00120'],
#  'C17333': ['map00120'],
#  'C17335': ['map00120'],
#  'C17336': ['map00120'],
#  'C17337': ['map00120'],
#  'C17339': ['map00120'],
#  'C17343': ['map00120'],
#  'C17345': ['map00120'],
#  'C17346': ['map00120'],
#  'C03990': ['map00121', 'map04976'],
#  'C04483': ['map00121', 'map04976'],
#  'C07880': ['map00121'],
#  'C15515': ['map00121'],
#  'C15517': ['map00121'],
#  'C17644': ['map00121'],
#  'C17646': ['map00121'],
#  'C17647': ['map00121'],
#  'C17649': ['map00121'],
#  'C17650': ['map00121'],
#  'C17651': ['map00121'],
#  'C17654': ['map00121'],
#  'C17657': ['map00121'],
#  'C17658': ['map00121'],
#  'C17660': ['map00121'],
#  'C17661': ['map00121'],
#  'C17662': ['map00121'],
#  'C17664': ['map00121'],
#  'C17667': ['map00121'],
#  'C17668': ['map00121'],
#  'C17687': ['map00121'],
#  'C17689': ['map00121'],
#  'C17726': ['map00121'],
#  'C17727': ['map00121'],
#  'C17737': ['map00121'],
#  'C00082': ['map00130',
#   'map00231',
#   'map00350',
#   'map00360',
#   'map00400',
#   'map00401',
#   'map00460',
#   'map00730',
#   'map00940',
#   'map00950',
#   'map00965',
#   'map00966',
#   'map00970',
#   'map01055',
#   'map04728',
#   'map04916',
#   'map04917',
#   'map04974',
#   'map05012',
#   'map05030',
#   'map05031',
#   'map05034'],
#  'C00156': ['map00130',
#   'map00360',
#   'map00362',
#   'map00363',
#   'map00623',
#   'map00627',
#   'map07110'],
#  'C00223': ['map00130',
#   'map00330',
#   'map00360',
#   'map00940',
#   'map00941',
#   'map00945'],
#  'C00251': ['map00130', 'map00400', 'map00790', 'map01053'],
#  'C00341': ['map00130', 'map00900', 'map00902'],
#  'C00399': ['map00130', 'map00190', 'map02020'],
#  'C00544': ['map00130', 'map00350', 'map00643'],
#  'C00811': ['map00130', 'map00360', 'map00940'],
#  'C00828': ['map00130', 'map02020', 'map04977'],
#  'C00885': ['map00130', 'map01053'],
#  'C01179': ['map00130',
#   'map00350',
#   'map00400',
#   'map00401',
#   'map00680',
#   'map00950',
#   'map01055'],
#  'C01230': ['map00130', 'map00900'],
#  'C01967': ['map00130'],
#  'C02059': ['map00130', 'map04977'],
#  'C02477': ['map00130', 'map04977'],
#  'C02483': ['map00130'],
#  'C02730': ['map00130'],
#  'C02949': ['map00130', 'map00362', 'map00364', 'map00627'],
#  'C03160': ['map00130'],
#  'C03313': ['map00130'],
#  'C03657': ['map00130'],
#  'C03672': ['map00130', 'map00350'],
#  'C03885': ['map00130'],
#  'C03993': ['map00130'],
#  'C04145': ['map00130', 'map00900'],
#  'C04146': ['map00130', 'map00900'],
#  'C05200': ['map00130'],
#  'C05313': ['map00130'],
#  'C05427': ['map00130', 'map00900'],
#  'C05802': ['map00130'],
#  'C05803': ['map00130'],
#  'C05804': ['map00130'],
#  'C05805': ['map00130'],
#  'C05807': ['map00130'],
#  'C05809': ['map00130'],
#  'C05810': ['map00130'],
#  'C05811': ['map00130'],
#  'C05812': ['map00130'],
#  'C05813': ['map00130'],
#  'C05814': ['map00130'],
#  'C05815': ['map00130'],
#  'C05817': ['map00130'],
#  'C05818': ['map00130', 'map02020'],
#  'C05819': ['map00130'],
#  'C05847': ['map00130'],
#  'C05848': ['map00130'],
#  'C05849': ['map00130'],
#  'C06986': ['map00130'],
#  'C10385': ['map00130'],
#  'C10793': ['map00130'],
#  'C13309': ['map00130'],
#  'C13425': ['map00130'],
#  'C14151': ['map00130'],
#  'C14152': ['map00130'],
#  'C15547': ['map00130'],
#  'C15882': ['map00130'],
#  'C15883': ['map00130'],
#  'C16519': ['map00130'],
#  'C16999': ['map00130'],
#  'C17010': ['map00130'],
#  'C17017': ['map00130'],
#  'C17018': ['map00130'],
#  'C17412': ['map00130'],
#  'C17432': ['map00130', 'map00900'],
#  'C17551': ['map00130'],
#  'C17552': ['map00130'],
#  'C17554': ['map00130'],
#  'C17559': ['map00130'],
#  'C17560': ['map00130'],
#  'C17561': ['map00130'],
#  'C17562': ['map00130'],
#  'C17568': ['map00130'],
#  'C17569': ['map00130'],
#  'C17570': ['map00130'],
#  'C18131': ['map00130'],
#  'C18132': ['map00130'],
#  'C18133': ['map00130'],
#  'C18134': ['map00130'],
#  'C18135': ['map00130'],
#  'C20265': ['map00130'],
#  'C00280': ['map00140',
#   'map00984',
#   'map04913',
#   'map04917',
#   'map05200',
#   'map05215'],
#  'C00410': ['map00140',
#   'map04114',
#   'map04913',
#   'map04914',
#   'map04917',
#   'map05200',
#   'map05215',
#   'map07225',
#   'map07226'],
#  'C00468': ['map00140', 'map04913', 'map04917', 'map07226'],
#  'C00523': ['map00140'],
#  'C00535': ['map00140',
#   'map00984',
#   'map04913',
#   'map05200',
#   'map05215',
#   'map07226'],
#  'C00674': ['map00140', 'map00984'],
#  'C00735': ['map00140',
#   'map04080',
#   'map04960',
#   'map04976',
#   'map05200',
#   'map05215',
#   'map07225'],
#  'C00762': ['map00140', 'map04960', 'map05200', 'map05215', 'map07225'],
#  'C00951': ['map00140',
#   'map04913',
#   'map04915',
#   'map04917',
#   'map04961',
#   'map05200',
#   'map05215',
#   'map07226'],
#  'C01124': ['map00140'],
#  'C01176': ['map00140', 'map04913'],
#  'C01227': ['map00140', 'map00984', 'map04913', 'map05200', 'map05215'],
#  'C01780': ['map00140', 'map04960', 'map07225'],
#  'C01953': ['map00140', 'map04913'],
#  'C02140': ['map00140', 'map05020'],
#  'C02373': ['map00140'],
#  'C02537': ['map00140'],
#  'C02538': ['map00140', 'map04976'],
#  'C03205': ['map00140'],
#  'C03681': ['map00140'],
#  'C03747': ['map00140'],
#  'C03772': ['map00140'],
#  'C03852': ['map00140'],
#  'C03917': ['map00140', 'map05200', 'map05215'],
#  'C03935': ['map00140'],
#  'C04042': ['map00140'],
#  'C04295': ['map00140', 'map04913'],
#  'C04373': ['map00140'],
#  'C04518': ['map00140'],
#  'C04555': ['map00140', 'map04976'],
#  'C04676': ['map00140'],
#  'C05138': ['map00140', 'map04913'],
#  'C05139': ['map00140'],
#  'C05140': ['map00140'],
#  'C05141': ['map00140', 'map07226'],
#  'C05284': ['map00140'],
#  'C05285': ['map00140'],
#  'C05290': ['map00140'],
#  'C05291': ['map00140'],
#  'C05293': ['map00140'],
#  'C05294': ['map00140'],
#  'C05295': ['map00140'],
#  'C05296': ['map00140'],
#  'C05297': ['map00140'],
#  'C05298': ['map00140'],
#  'C05299': ['map00140'],
#  'C05300': ['map00140'],
#  'C05301': ['map00140', 'map04913'],
#  'C05302': ['map00140'],
#  'C05469': ['map00140'],
#  'C05470': ['map00140'],
#  'C05471': ['map00140'],
#  'C05472': ['map00140'],
#  'C05473': ['map00140'],
#  'C05474': ['map00140'],
#  'C05475': ['map00140'],
#  'C05476': ['map00140'],
#  'C05477': ['map00140'],
#  'C05478': ['map00140'],
#  'C05479': ['map00140'],
#  'C05480': ['map00140'],
#  'C05481': ['map00140'],
#  'C05482': ['map00140'],
#  'C05483': ['map00140'],
#  'C05484': ['map00140'],
#  'C05485': ['map00140'],
#  'C05487': ['map00140'],
#  'C05488': ['map00140'],
#  'C05489': ['map00140'],
#  'C05490': ['map00140'],
#  'C05497': ['map00140'],
#  'C05498': ['map00140'],
#  'C05499': ['map00140'],
#  'C05500': ['map00140'],
#  'C05501': ['map00140'],
#  'C05502': ['map00140'],
#  'C05503': ['map00140', 'map04976'],
#  'C05504': ['map00140'],
#  'C08357': ['map00140', 'map04976'],
#  'C08358': ['map00140'],
#  'C08359': ['map00140'],
#  'C11131': ['map00140'],
#  'C11132': ['map00140'],
#  'C11133': ['map00140'],
#  'C11134': ['map00140'],
#  'C11135': ['map00140'],
#  'C11136': ['map00140'],
#  'C13712': ['map00140'],
#  'C13713': ['map00140'],
#  'C18038': ['map00140'],
#  'C18039': ['map00140'],
#  'C18040': ['map00140'],
#  'C18041': ['map00140'],
#  'C18042': ['map00140'],
#  'C18043': ['map00140'],
#  'C18044': ['map00140'],
#  'C18045': ['map00140'],
#  'C18075': ['map00140'],
#  'C00001': ['map00190',
#   'map00195',
#   'map00710',
#   'map00740',
#   'map04918',
#   'map04962',
#   'map04964',
#   'map04966',
#   'map04970',
#   'map04971',
#   'map04972',
#   'map04976',
#   'map05014'],
#  'C00002': ['map00190',
#   'map00195',
#   'map00230',
#   'map00231',
#   'map00908',
#   'map03070',
#   'map04020',
#   'map04066',
#   'map04080',
#   'map04142',
#   'map04144',
#   'map04721',
#   'map04911',
#   'map04917',
#   'map04930',
#   'map05012',
#   'map05133',
#   'map05410'],
#  'C00003': ['map00190', 'map00760', 'map04977'],
#  'C00004': ['map00190', 'map04020'],
#  'C00007': ['map00190',
#   'map00195',
#   'map00630',
#   'map00740',
#   'map02020',
#   'map04066',
#   'map04145',
#   'map04918',
#   'map05211'],
#  'C00008': ['map00190',
#   'map00195',
#   'map00230',
#   'map00908',
#   'map04068',
#   'map04080',
#   'map04142',
#   'map04144',
#   'map05012'],
#  'C00009': ['map00190',
#   'map00195',
#   'map00550',
#   'map02010',
#   'map02020',
#   'map04111',
#   'map04978',
#   'map05012'],
#  'C00013': ['map00190', 'map05012'],
#  'C00061': ['map00190', 'map00524', 'map00740', 'map01057', 'map04977'],
#  'C00080': ['map00190',
#   'map00195',
#   'map00680',
#   'map04260',
#   'map04261',
#   'map04721',
#   'map04742',
#   'map04919',
#   'map04964',
#   'map04966',
#   'map04970',
#   'map04971',
#   'map04972',
#   'map04974',
#   'map04976',
#   'map04977',
#   'map04978',
#   'map05110',
#   'map05120',
#   'map05164',
#   'map05323'],
#  'C00390': ['map00190'],
#  'C00524': ['map00190', 'map00860'],
#  'C00536': ['map00190'],
#  'C00005': ['map00195', 'map00480', 'map04918'],
#  'C00006': ['map00195', 'map00480', 'map00760', 'map04918'],
#  'C00034': ['map00195', 'map02010', 'map02020'],
#  'C02061': ['map00195'],
#  'C02185': ['map00195'],
#  'C00011': ['map00230',
#   'map00260',
#   'map00330',
#   'map00361',
#   'map00460',
#   'map00625',
#   'map00630',
#   'map00680',
#   'map00710',
#   'map00720',
#   'map00791',
#   'map00910',
#   'map04964',
#   'map04966',
#   'map04970',
#   'map04971',
#   'map04972',
#   'map04973',
#   'map04974',
#   'map04976'],
#  'C00014': ['map00230',
#   'map00250',
#   'map00260',
#   'map00330',
#   'map00460',
#   'map00630',
#   'map00910',
#   'map04964',
#   'map04966',
#   'map04974',
#   'map05110',
#   'map05120'],
#  'C00020': ['map00230',
#   'map00908',
#   'map04068',
#   'map04150',
#   'map04151',
#   'map05012',
#   'map05032'],
#  'C00035': ['map00230', 'map03013', 'map04014', 'map04015'],
#  'C00039': ['map00230', 'map00240', 'map00312'],
#  'C00044': ['map00230',
#   'map00740',
#   'map00790',
#   'map03013',
#   'map04014',
#   'map04015',
#   'map04122'],
#  'C00046': ['map00230', 'map00240'],
#  'C00048': ['map00230',
#   'map00232',
#   'map00260',
#   'map00330',
#   'map00625',
#   'map00630',
#   'map00660',
#   'map00680',
#   'map00720'],
#  'C00053': ['map00230', 'map00532', 'map00534', 'map00920'],
#  'C00054': ['map00230', 'map00532', 'map00534', 'map00770', 'map00920'],
#  'C00059': ['map00230', 'map00270', 'map00920', 'map02010'],
#  'C00064': ['map00230',
#   'map00240',
#   'map00250',
#   'map00330',
#   'map00471',
#   'map00630',
#   'map00910',
#   'map00970',
#   'map02010',
#   'map02020',
#   'map04724',
#   'map04727',
#   'map04964',
#   'map04974',
#   'map04978'],
#  'C00081': ['map00230'],
#  'C00086': ['map00230',
#   'map00240',
#   'map00330',
#   'map00780',
#   'map00791',
#   'map02010',
#   'map05120'],
#  'C00104': ['map00230'],
#  'C00130': ['map00230', 'map04742'],
#  'C00131': ['map00230'],
#  'C00144': ['map00230', 'map04742', 'map04744'],
#  'C00147': ['map00230', 'map00908'],
#  'C00169': ['map00230', 'map00240', 'map00250', 'map00330', 'map00910'],
#  'C00206': ['map00230'],
#  'C00212': ['map00230',
#   'map04080',
#   'map04270',
#   'map05012',
#   'map05032',
#   'map05034'],
#  'C00224': ['map00230', 'map00920'],
#  'C00242': ['map00230'],
#  'C00262': ['map00230'],
#  'C00286': ['map00230'],
#  'C00294': ['map00230'],
#  'C00301': ['map00230'],
#  'C00330': ['map00230'],
#  'C00360': ['map00230'],
#  'C00361': ['map00230'],
#  'C00362': ['map00230'],
#  'C00366': ['map00230', 'map04976'],
#  'C00385': ['map00230', 'map00232'],
#  'C00387': ['map00230'],
#  'C00499': ['map00230'],
#  'C00559': ['map00230'],
#  'C00575': ['map00230',
#   'map04010',
#   'map04014',
#   'map04015',
#   'map04020',
#   'map04062',
#   'map04111',
#   'map04113',
#   'map04114',
#   'map04261',
#   'map04270',
#   'map04540',
#   'map04670',
#   'map04710',
#   'map04713',
#   'map04720',
#   'map04723',
#   'map04724',
#   'map04725',
#   'map04726',
#   'map04727',
#   'map04728',
#   'map04740',
#   'map04742',
#   'map04910',
#   'map04911',
#   'map04912',
#   'map04913',
#   'map04914',
#   'map04915',
#   'map04916',
#   'map04918',
#   'map04919',
#   'map04960',
#   'map04961',
#   'map04962',
#   'map04970',
#   'map04971',
#   'map04972',
#   'map04976',
#   'map05012',
#   'map05020',
#   'map05030',
#   'map05031',
#   'map05032',
#   'map05034',
#   'map05110',
#   'map05111',
#   'map05133',
#   'map05142',
#   'map05146',
#   'map05166',
#   'map05414'],
#  'C00603': ['map00230'],
#  'C00655': ['map00230'],
#  'C00700': ['map00230'],
#  'C00802': ['map00230'],
#  'C00942': ['map00230',
#   'map04270',
#   'map04540',
#   'map04713',
#   'map04730',
#   'map04740',
#   'map04742',
#   'map04744',
#   'map04970',
#   'map04976'],
#  'C01228': ['map00230'],
#  'C01260': ['map00230'],
#  'C01261': ['map00230'],
#  'C01344': ['map00230'],
#  'C01345': ['map00230'],
#  'C01367': ['map00230'],
#  'C01762': ['map00230', 'map00232'],
#  'C02091': ['map00230'],
#  'C02348': ['map00230'],
#  'C02350': ['map00230'],
#  'C02353': ['map00230'],
#  'C02718': ['map00230'],
#  'C03090': ['map00230', 'map00250'],
#  'C03373': ['map00230', 'map00730'],
#  'C03483': ['map00230'],
#  'C03614': ['map00230'],
#  'C03794': ['map00230', 'map00250'],
#  'C03838': ['map00230'],
#  'C04051': ['map00230'],
#  'C04376': ['map00230'],
#  'C04392': ['map00230'],
#  'C04494': ['map00230'],
#  'C04640': ['map00230'],
#  'C04677': ['map00230', 'map00340', 'map04150'],
#  'C04734': ['map00230'],
#  'C04751': ['map00230'],
#  'C04823': ['map00230'],
#  'C05239': ['map00230'],
#  'C05512': ['map00230'],
#  'C05513': ['map00230'],
#  'C05515': ['map00230'],
#  'C05516': ['map00230'],
#  'C05993': ['map00230', 'map00620'],
#  'C06193': ['map00230'],
#  'C06194': ['map00230'],
#  'C06195': ['map00230'],
#  'C06196': ['map00230'],
#  'C06197': ['map00230'],
#  'C06433': ['map00230'],
#  'C06435': ['map00230'],
#  'C11821': ['map00230'],
#  'C12248': ['map00230'],
#  'C15667': ['map00230'],
#  'C01610': ['map00231'],
#  'C07024': ['map00231'],
#  'C07025': ['map00231'],
#  'C07026': ['map00231'],
#  'C07027': ['map00231'],
#  'C07028': ['map00231'],
#  'C07029': ['map00231'],
#  'C07030': ['map00231'],
#  'C07031': ['map00231'],
#  'C07032': ['map00231'],
#  'C07130': ['map00232'],
#  'C07480': ['map00232'],
#  'C07481': ['map00232'],
#  'C13747': ['map00232'],
#  'C16352': ['map00232'],
#  'C16353': ['map00232'],
#  'C16355': ['map00232'],
#  'C16356': ['map00232'],
#  'C16357': ['map00232'],
#  'C16358': ['map00232'],
#  'C16359': ['map00232'],
#  'C16360': ['map00232'],
#  'C16361': ['map00232'],
#  'C16362': ['map00232'],
#  'C16363': ['map00232'],
#  'C16364': ['map00232'],
#  'C16365': ['map00232'],
#  'C16366': ['map00232'],
#  'C00015': ['map00240', 'map00908', 'map04080'],
#  'C00055': ['map00240'],
#  'C00063': ['map00240'],
#  'C00075': ['map00240', 'map04080'],
#  'C00099': ['map00240',
#   'map00410',
#   'map00640',
#   'map00770',
#   'map04080',
#   'map04974',
#   'ingenza00009'],
#  'C00105': ['map00240', 'map00550'],
#  'C00106': ['map00240', 'map00410', 'map00770'],
#  'C00112': ['map00240'],
#  'C00178': ['map00240'],
#  'C00214': ['map00240'],
#  'C00222': ['map00240',
#   'map00410',
#   'map00562',
#   'map00625',
#   'map00640',
#   'map00720'],
#  'C00239': ['map00240'],
#  'C00295': ['map00240'],
#  'C00299': ['map00240'],
#  'C00337': ['map00240'],
#  'C00342': ['map00240'],
#  'C00343': ['map00240'],
#  'C00363': ['map00240'],
#  'C00364': ['map00240'],
#  'C00365': ['map00240'],
#  'C00380': ['map00240'],
#  'C00383': ['map00240', 'map00410'],
#  'C00429': ['map00240', 'map00410', 'map00770'],
#  'C00438': ['map00240', 'map00250'],
#  'C00458': ['map00240'],
#  'C00459': ['map00240'],
#  'C00460': ['map00240'],
#  'C00475': ['map00240'],
#  'C00526': ['map00240'],
#  'C00705': ['map00240'],
#  'C00813': ['map00240'],
#  'C00881': ['map00240'],
#  'C00906': ['map00240'],
#  'C01013': ['map00240', 'map00410', 'map00640', 'map00720'],
#  'C01103': ['map00240'],
#  'C01168': ['map00240'],
#  'C01346': ['map00240'],
#  'C01368': ['map00240'],
#  'C01563': ['map00240', 'map00910'],
#  'C02067': ['map00240'],
#  'C02170': ['map00240', 'map00280', 'map00640'],
#  'C02354': ['map00240'],
#  'C02355': ['map00240'],
#  'C02376': ['map00240'],
#  'C02642': ['map00240', 'map00410', 'map00770'],
#  'C03997': ['map00240'],
#  'C05100': ['map00240'],
#  'C05145': ['map00240'],
#  'C05281': ['map00240'],
#  'C05822': ['map00240'],
#  'C06198': ['map00240'],
#  'C11038': ['map00240'],
#  'C11039': ['map00240'],
#  'C15607': ['map00240'],
#  'C20231': ['map00240'],
#  'C20249': ['map00240'],
#  'C20253': ['map00240'],
#  'C20254': ['map00240'],
#  'C00025': ['map00250',
#   'map00330',
#   'map00340',
#   'map00430',
#   'map00471',
#   'map00480',
#   'map00524',
#   'map00630',
#   'map00650',
#   'map00660',
#   'map00860',
#   'map00910',
#   'map00970',
#   'map02010',
#   'map02020',
#   'map04068',
#   'map04080',
#   'map04540',
#   'map04713',
#   'map04720',
#   'map04721',
#   'map04723',
#   'map04724',
#   'map04727',
#   'map04730',
#   'map04742',
#   'map04964',
#   'map04974',
#   'map05014',
#   'map05016',
#   'map05030',
#   'map05031',
#   'map05033',
#   'map05034'],
#  'C00041': ['map00250',
#   'map00270',
#   'map00430',
#   'map00450',
#   'map00473',
#   'map00710',
#   'map00970',
#   'map02010',
#   'map04122',
#   'map04974',
#   'map04978'],
#  'C00049': ['map00250',
#   'map00260',
#   'map00270',
#   'map00300',
#   'map00330',
#   'map00340',
#   'map00410',
#   'map00460',
#   'map00710',
#   'map00760',
#   'map00770',
#   'map00970',
#   'map02010',
#   'map02020',
#   'map02030',
#   'map04080',
#   'map04974',
#   'ingenza00009'],
#  'C00152': ['map00250', 'map00460', 'map00970', 'map04974', 'map04978'],
#  'C00232': ['map00250',
#   'map00350',
#   'map00650',
#   'map00720',
#   'map00750',
#   'map00760'],
#  'C00334': ['map00250',
#   'map00330',
#   'map00410',
#   'map00650',
#   'map04080',
#   'map04721',
#   'map04723',
#   'map04727',
#   'map04915',
#   'map05032',
#   'map05033'],
#  'C00352': ['map00250', 'map00520', 'map02060'],
#  'C00402': ['map00250'],
#  'C00940': ['map00250'],
#  'C01042': ['map00250'],
#  'C02362': ['map00250'],
#  'C03406': ['map00250', 'map00330'],
#  'C03912': ['map00250', 'map00330'],
#  'C02811': ['map00253', 'map01057'],
#  'C03206': ['map00253', 'map01057'],
#  'C06570': ['map00253', 'map01057', 'map04976'],
#  'C06571': ['map00253', 'map01057'],
#  'C06624': ['map00253', 'map01057'],
#  'C06625': ['map00253', 'map01056'],
#  'C06626': ['map00253', 'map01057'],
#  'C06627': ['map00253', 'map01057'],
#  'C06628': ['map00253', 'map01057'],
#  'C06629': ['map00253', 'map01057'],
#  'C06654': ['map00253', 'map01057'],
#  'C12441': ['map00253', 'map01056'],
#  'C12442': ['map00253', 'map01056'],
#  'C18293': ['map00253', 'map01056', 'map01057'],
#  'C18294': ['map00253', 'map01057'],
#  'C18295': ['map00253', 'map01057'],
#  'C18296': ['map00253', 'map01057'],
#  'C18297': ['map00253', 'map01057'],
#  'C18298': ['map00253', 'map01057'],
#  'C18299': ['map00253', 'map01057'],
#  'C00961': ['map00254'],
#  'C03683': ['map00254'],
#  'C03686': ['map00254'],
#  'C03944': ['map00254'],
#  'C06800': ['map00254', 'map00980', 'map05204'],
#  'C16753': ['map00254'],
#  'C16754': ['map00254'],
#  'C16755': ['map00254'],
#  'C20444': ['map00254'],
#  'C20445': ['map00254'],
#  'C20452': ['map00254'],
#  'C20453': ['map00254'],
#  'C20499': ['map00254'],
#  'C20500': ['map00254'],
#  'C20501': ['map00254'],
#  'C20502': ['map00254'],
#  'C20503': ['map00254'],
#  'C20504': ['map00254'],
#  'C20505': ['map00254'],
#  'C20506': ['map00254'],
#  'C20507': ['map00254'],
#  'C20508': ['map00254'],
#  'C20574': ['map00254'],
#  'C20575': ['map00254'],
#  'C20583': ['map00254'],
#  'C00065': ['map00260',
#   'map00270',
#   'map00460',
#   'map00600',
#   'map00630',
#   'map00680',
#   'map00920',
#   'map00970',
#   'map02010',
#   'map04974',
#   'map04978'],
#  'C00078': ['map00260',
#   'map00380',
#   'map00400',
#   'map00901',
#   'map00966',
#   'map00970',
#   'map04726',
#   'map04974',
#   'map04978',
#   'map05143'],
#  'C00097': ['map00260',
#   'map00270',
#   'map00311',
#   'map00430',
#   'map00480',
#   'map00730',
#   'map00770',
#   'map00920',
#   'map00970',
#   'map04122',
#   'map04974'],
#  'C00101': ['map00260',
#   'map00670',
#   'map00680',
#   'map00720',
#   'map00790',
#   'map00970'],
#  'C00109': ['map00260',
#   'map00270',
#   'map00290',
#   'map00640',
#   'map00660',
#   'ingenza00007'],
#  'C00114': ['map00260', 'map00564', 'map02010', 'map04725', 'map04976'],
#  'C00143': ['map00260', 'map00670', 'map00680', 'map00720'],
#  'C00168': ['map00260', 'map00630', 'map00680'],
#  'C00188': ['map00260',
#   'map00290',
#   'map00860',
#   'map00970',
#   'map02010',
#   'map04974',
#   'map04978',
#   'ingenza00007'],
#  'C00213': ['map00260', 'map00330'],
#  'C00263': ['map00260', 'map00270', 'map00300', 'map00920'],
#  'C00300': ['map00260', 'map00330'],
#  'C00430': ['map00260', 'map00860', 'map02010'],
#  'C00441': ['map00260', 'map00270', 'map00300', 'map00330', 'map00400'],
#  'C00546': ['map00260', 'map00620', 'ingenza00002'],
#  'C00576': ['map00260'],
#  'C00581': ['map00260', 'map00330'],
#  'C00719': ['map00260', 'map02010'],
#  'C00740': ['map00260'],
#  'C00986': ['map00260', 'map00330', 'map00410'],
#  'C01005': ['map00260', 'map00270', 'map00680', 'map00970'],
#  'C01026': ['map00260'],
#  'C01102': ['map00260'],
#  'C01242': ['map00260'],
#  'C01726': ['map00260'],
#  'C01888': ['map00260'],
#  'C02051': ['map00260'],
#  'C02291': ['map00260', 'map00270'],
#  'C02737': ['map00260', 'map00564', 'map05140', 'map05146', 'map05322'],
#  'C02855': ['map00260'],
#  'C02972': ['map00260'],
#  'C03082': ['map00260', 'map00270', 'map00300'],
#  'C03194': ['map00260', 'map00860'],
#  'C03232': ['map00260', 'map00680'],
#  'C03283': ['map00260'],
#  'C03508': ['map00260'],
#  'C05235': ['map00260', 'ingenza00002'],
#  'C05519': ['map00260'],
#  'C06231': ['map00260'],
#  'C06442': ['map00260'],
#  'C16432': ['map00260'],
#  'C19929': ['map00260'],
#  'C00019': ['map00270', 'map00330', 'map00908', 'map04122'],
#  'C00021': ['map00270'],
#  'C00051': ['map00270', 'map00480', 'map02010', 'map04918', 'map04976'],
#  'C00073': ['map00270', 'map00966', 'map00970', 'map04974', 'map04978'],
#  'C00094': ['map00270', 'map00430', 'map00920'],
#  'C00155': ['map00270', 'map00920'],
#  'C00170': ['map00270', 'map00908'],
#  'C00283': ['map00270', 'map00920'],
#  'C00320': ['map00270', 'map00920', 'map02010'],
#  'C00409': ['map00270', 'map00920'],
#  'C00491': ['map00270', 'map02010', 'map04974'],
#  'C00506': ['map00270', 'map00430', 'map04080'],
#  'C00606': ['map00270', 'map00430'],
#  'C00793': ['map00270'],
#  'C00957': ['map00270'],
#  'C00979': ['map00270', 'map00908', 'map00920'],
#  'C01077': ['map00270'],
#  'C01118': ['map00270', 'map00920'],
#  'C01137': ['map00270', 'map00330'],
#  'C01180': ['map00270', 'map00966'],
#  'C01234': ['map00270', 'map00640'],
#  'C01817': ['map00270'],
#  'C01962': ['map00270'],
#  'C02218': ['map00270'],
#  'C02989': ['map00270'],
#  'C03089': ['map00270'],
#  'C03145': ['map00270'],
#  'C03539': ['map00270'],
#  'C04188': ['map00270'],
#  'C04582': ['map00270'],
#  'C05524': ['map00270'],
#  'C05526': ['map00270'],
#  'C05527': ['map00270'],
#  'C05528': ['map00270', 'map00680'],
#  'C05823': ['map00270'],
#  'C05824': ['map00270'],
#  'C06547': ['map00270', 'map00625', 'map04075', 'map05204'],
#  'C08276': ['map00270', 'map00920'],
#  'C09306': ['map00270'],
#  'C11481': ['map00270'],
#  'C11499': ['map00270'],
#  'C11537': ['map00270', 'map00680'],
#  'C15606': ['map00270'],
#  'C15650': ['map00270'],
#  'C15651': ['map00270'],
#  'C00100': ['map00280',
#   'map00410',
#   'map00522',
#   'map00561',
#   'map00630',
#   'map00640',
#   'map00660',
#   'map00720',
#   'map01056'],
#  'C00123': ['map00280',
#   'map00290',
#   'map00966',
#   'map00970',
#   'map02010',
#   'map04974',
#   'map04978',
#   'ingenza00006'],
#  'C00141': ['map00280',
#   'map00290',
#   'map00770',
#   'map00966',
#   'ingenza00003',
#   'ingenza00004'],
#  'C00183': ['map00280',
#   'map00290',
#   'map00311',
#   'map00460',
#   'map00640',
#   'map00770',
#   'map00966',
#   'map00970',
#   'map02010',
#   'map04974',
#   'map04978'],
#  'C00233': ['map00280', 'map00290', 'map00966', 'ingenza00006'],
#  'C00407': ['map00280',
#   'map00290',
#   'map00460',
#   'map00960',
#   'map00966',
#   'map00970',
#   'map02010',
#   'map04974',
#   'map04978',
#   'ingenza00007'],
#  'C00630': ['map00280', 'map00360', 'map00522', 'ingenza00004'],
#  'C00671': ['map00280', 'map00290', 'map00966', 'ingenza00007'],
#  'C00683': ['map00280',
#   'map00522',
#   'map00630',
#   'map00640',
#   'map00720',
#   'ingenza00005'],
#  'C01213': ['map00280', 'map00630', 'map00640', 'map00720', 'ingenza00005'],
#  'C02486': ['map00280'],
#  'C02939': ['map00280'],
#  'C03069': ['map00280', 'map00281'],
#  'C03231': ['map00280'],
#  'C03284': ['map00280'],
#  'C03344': ['map00280'],
#  'C03345': ['map00280'],
#  'C03460': ['map00280', 'ingenza00004'],
#  'C03467': ['map00280'],
#  'C04405': ['map00280'],
#  'C05996': ['map00280', 'map04974'],
#  'C05998': ['map00280'],
#  'C06000': ['map00280', 'ingenza00005'],
#  'C06001': ['map00280', 'ingenza00005'],
#  'C06002': ['map00280', 'map00633', 'map00640', 'ingenza00005'],
#  'C15974': ['map00280'],
#  'C15975': ['map00280'],
#  'C15976': ['map00280'],
#  ...}

# %%
len(cmpd_id_formula_dict)
# Out:
# 14761

# %%
len(cmpd_id_pw_dict)
# Out:
# 7843

# %%
data = {
    'pw_dict': pw_dict,
    'pathway_cmpd_dict': pathway_cmpd_dict,
    'cmpd_formula_dict': cmpd_formula_dict,
    'cmpd_id_formula_dict': cmpd_id_formula_dict,
    'cmpd_id_pw_dict': cmpd_id_pw_dict
}

# %%
json_file = '/home/joewandy/git/PALS/data/kegg.json'
save_json(data, json_file)

# %% [markdown]
# ### Regenerate PiMP compound XML file

# %%
def get_kegg_info(compound_id):
        s = KEGG()
        res = s.get(compound_id)
        return s.parse(res)
    
def get_all_kegg_compound_ids():
    s = KEGG()
    compound_ids = []
    for compound_id in s.compoundIds:
        compound_ids.append(compound_id.split(':')[1])
    return compound_ids

def get_all_kegg_compound_info():
    compound_ids = get_all_kegg_compound_ids()
    compound_info = {}
    for i in range(len(compound_ids)):
        cid = compound_ids[i]
        cinfo = get_kegg_info(cid)
        print('%d/%d %s' % (i+1, len(compound_ids), cinfo['ENTRY']))        
        compound_info[cid] = cinfo
    return compound_info

# %%
json_file = '/home/joewandy/git/PALS/data/all_kegg_compounds.json'

# %%
if os.path.exists(json_file):
    data = load_json(json_file)
else:
    all_kegg_compound_info = get_all_kegg_compound_info()
    data = {
        'cmpd_info': all_kegg_compound_info
    }
    save_json(data, json_file)

# %%
data['cmpd_info']['C00135']
